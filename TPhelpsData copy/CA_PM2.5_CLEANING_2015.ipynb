# %%
#import dependencies
import pandas as pd
import requests as req
#create separate file with individual log in credentials to be imported

from config import (user_id_aqs, password_aqs, Plotkey, Plotuser)
import csv
import matplotlib.pyplot as plt

# %%
codes = []
countycodes = ["{0:03}".format(i) for i in range(117) if i%2 > 0]

for countycode in countycodes:
    codes.append(countycode)
#codes

# %%
#API REQUEST
URL_new = f"https://aqs.epa.gov/api/rawData?user={user_id_aqs}&pw={password_aqs}&format=DMCSV&param=88101&bdate=20150101&edate=20151231&state=06&county="
list_2015 = []

for x in codes:
    url_loop = URL_new + x
    print(f"fetching county code {x}")
    response1 = req.get(url_loop)
    print(f"Got API Response for {x}")
    wrapper = csv.reader(response1.text.strip().split('\n'))
    header = next(wrapper)
    for record in wrapper:
        list_2015.append(record)
    print(f"Appended List with {x} API Response")
# Out:
# fetching county code 001
# Got API Response for 001
# Appended List with 001 API Response
# fetching county code 003
# Got API Response for 003
# Appended List with 003 API Response
# fetching county code 005
# Got API Response for 005
# Appended List with 005 API Response
# fetching county code 007
# Got API Response for 007
# Appended List with 007 API Response
# fetching county code 009
# Got API Response for 009
# Appended List with 009 API Response
# fetching county code 011
# Got API Response for 011
# Appended List with 011 API Response
# fetching county code 013
# Got API Response for 013
# Appended List with 013 API Response
# fetching county code 015
# Got API Response for 015
# Appended List with 015 API Response
# fetching county code 017
# Got API Response for 017
# Appended List with 017 API Response
# fetching county code 019
# Got API Response for 019
# Appended List with 019 API Response
# fetching county code 021
# Got API Response for 021
# Appended List with 021 API Response
# fetching county code 023
# Got API Response for 023
# Appended List with 023 API Response
# fetching county code 025
# Got API Response for 025
# Appended List with 025 API Response
# fetching county code 027
# Got API Response for 027
# Appended List with 027 API Response
# fetching county code 029
# Got API Response for 029
# Appended List with 029 API Response
# fetching county code 031
# Got API Response for 031
# Appended List with 031 API Response
# fetching county code 033
# Got API Response for 033
# Appended List with 033 API Response
# fetching county code 035
# Got API Response for 035
# Appended List with 035 API Response
# fetching county code 037
# Got API Response for 037
# Appended List with 037 API Response
# fetching county code 039
# Got API Response for 039
# Appended List with 039 API Response
# fetching county code 041
# Got API Response for 041
# Appended List with 041 API Response
# fetching county code 043
# Got API Response for 043
# Appended List with 043 API Response
# fetching county code 045
# Got API Response for 045
# Appended List with 045 API Response
# fetching county code 047
# Got API Response for 047
# Appended List with 047 API Response
# fetching county code 049
# Got API Response for 049
# Appended List with 049 API Response
# fetching county code 051
# Got API Response for 051
# Appended List with 051 API Response
# fetching county code 053
# Got API Response for 053
# Appended List with 053 API Response
# fetching county code 055
# Got API Response for 055
# Appended List with 055 API Response
# fetching county code 057
# Got API Response for 057
# Appended List with 057 API Response
# fetching county code 059
# Got API Response for 059
# Appended List with 059 API Response
# fetching county code 061
# Got API Response for 061
# Appended List with 061 API Response
# fetching county code 063
# Got API Response for 063
# Appended List with 063 API Response
# fetching county code 065
# Got API Response for 065
# Appended List with 065 API Response
# fetching county code 067
# Got API Response for 067
# Appended List with 067 API Response
# fetching county code 069
# Got API Response for 069
# Appended List with 069 API Response
# fetching county code 071
# Got API Response for 071
# Appended List with 071 API Response
# fetching county code 073
# Got API Response for 073
# Appended List with 073 API Response
# fetching county code 075
# Got API Response for 075
# Appended List with 075 API Response
# fetching county code 077
# Got API Response for 077
# Appended List with 077 API Response
# fetching county code 079
# Got API Response for 079
# Appended List with 079 API Response
# fetching county code 081
# Got API Response for 081
# Appended List with 081 API Response
# fetching county code 083
# Got API Response for 083
# Appended List with 083 API Response
# fetching county code 085
# Got API Response for 085
# Appended List with 085 API Response
# fetching county code 087
# Got API Response for 087
# Appended List with 087 API Response
# fetching county code 089
# Got API Response for 089
# Appended List with 089 API Response
# fetching county code 091
# Got API Response for 091
# Appended List with 091 API Response
# fetching county code 093
# Got API Response for 093
# Appended List with 093 API Response
# fetching county code 095
# Got API Response for 095
# Appended List with 095 API Response
# fetching county code 097
# Got API Response for 097
# Appended List with 097 API Response
# fetching county code 099
# Got API Response for 099
# Appended List with 099 API Response
# fetching county code 101
# Got API Response for 101
# Appended List with 101 API Response
# fetching county code 103
# Got API Response for 103
# Appended List with 103 API Response
# fetching county code 105
# Got API Response for 105
# Appended List with 105 API Response
# fetching county code 107
# Got API Response for 107
# Appended List with 107 API Response
# fetching county code 109
# Got API Response for 109
# Appended List with 109 API Response
# fetching county code 111
# Got API Response for 111
# Appended List with 111 API Response
# fetching county code 113
# Got API Response for 113
# Appended List with 113 API Response
# fetching county code 115
# Got API Response for 115
# Appended List with 115 API Response

# %%
#Create DF and append FIPS column with county code and 06 (state code) to create FIPS code
data_2015 = pd.DataFrame(list_2015, columns = header)
data_2015["FIPS"] = "06" + data_2015["County Code"]
data_2015
# Out:
#            Latitude    Longitude  Datum Horizontal Accuracy State Code  \
# 0         37.814781  -122.282347  WGS84                   6         06
# 1         37.793624  -122.263376  WGS84                   1         06
# 2         37.687526  -121.784217  WGS84           109305.56         06
# 3         37.743065  -122.169935  WGS84                   6         06
# 4         37.814781  -122.282347  WGS84                   6         06
# 5         37.793624  -122.263376  WGS84                   1         06
# 6         37.687526  -121.784217  WGS84           109305.56         06
# 7         37.743065  -122.169935  WGS84                   6         06
# 8         37.814781  -122.282347  WGS84                   6         06
# 9         37.793624  -122.263376  WGS84                   1         06
# 10        37.687526  -121.784217  WGS84           109305.56         06
# 11        37.743065  -122.169935  WGS84                   6         06
# 12        37.814781  -122.282347  WGS84                   6         06
# 13        37.793624  -122.263376  WGS84                   1         06
# 14        37.687526  -121.784217  WGS84           109305.56         06
# 15        37.743065  -122.169935  WGS84                   6         06
# 16        37.814781  -122.282347  WGS84                   6         06
# 17        37.793624  -122.263376  WGS84                   1         06
# 18        37.687526  -121.784217  WGS84           109305.56         06
# 19        37.743065  -122.169935  WGS84                   6         06
# 20        37.814781  -122.282347  WGS84                   6         06
# 21        37.793624  -122.263376  WGS84                   1         06
# 22        37.687526  -121.784217  WGS84           109305.56         06
# 23        37.743065  -122.169935  WGS84                   6         06
# 24        37.814781  -122.282347  WGS84                   6         06
# 25        37.793624  -122.263376  WGS84                   1         06
# 26        37.687526  -121.784217  WGS84           109305.56         06
# 27        37.743065  -122.169935  WGS84                   6         06
# 28        37.814781  -122.282347  WGS84                   6         06
# 29        37.793624  -122.263376  WGS84                   1         06
# ...             ...          ...    ...                 ...        ...
# 543990     38.66121   -121.73269  WGS84              151.82         06
# 543991     38.66121   -121.73269  WGS84              151.82         06
# 543992     38.66121   -121.73269  WGS84              151.82         06
# 543993     38.66121   -121.73269  WGS84              151.82         06
# 543994     38.66121   -121.73269  WGS84              151.82         06
# 543995     38.66121   -121.73269  WGS84              151.82         06
# 543996     38.66121   -121.73269  WGS84              151.82         06
# 543997     38.66121   -121.73269  WGS84              151.82         06
# 543998     38.66121   -121.73269  WGS84              151.82         06
# 543999     38.66121   -121.73269  WGS84              151.82         06
# 544000     38.66121   -121.73269  WGS84              151.82         06
# 544001     38.66121   -121.73269  WGS84              151.82         06
# 544002     38.66121   -121.73269  WGS84              151.82         06
# 544003     38.66121   -121.73269  WGS84              151.82         06
# 544004     38.66121   -121.73269  WGS84              151.82         06
# 544005     38.66121   -121.73269  WGS84              151.82         06
# 544006     38.66121   -121.73269  WGS84              151.82         06
# 544007     38.66121   -121.73269  WGS84              151.82         06
# 544008     38.66121   -121.73269  WGS84              151.82         06
# 544009     38.66121   -121.73269  WGS84              151.82         06
# 544010     38.66121   -121.73269  WGS84              151.82         06
# 544011     38.66121   -121.73269  WGS84              151.82         06
# 544012     38.66121   -121.73269  WGS84              151.82         06
# 544013     38.66121   -121.73269  WGS84              151.82         06
# 544014     38.66121   -121.73269  WGS84              151.82         06
# 544015     38.66121   -121.73269  WGS84              151.82         06
# 544016     38.66121   -121.73269  WGS84              151.82         06
# 544017     38.66121   -121.73269  WGS84              151.82         06
# 544018  END OF FILE         None   None                None       None
# 544019  END OF FILE         None   None                None       None
#
#        County Code Site Num Parameter Code   POC        AQS Parameter Desc  \
# 0              001     0011          88101     3  PM2.5 - Local Conditions
# 1              001     0012          88101     3  PM2.5 - Local Conditions
# 2              001     0007          88101     3  PM2.5 - Local Conditions
# 3              001     0009          88101     3  PM2.5 - Local Conditions
# 4              001     0011          88101     3  PM2.5 - Local Conditions
# 5              001     0012          88101     3  PM2.5 - Local Conditions
# 6              001     0007          88101     3  PM2.5 - Local Conditions
# 7              001     0009          88101     3  PM2.5 - Local Conditions
# 8              001     0011          88101     3  PM2.5 - Local Conditions
# 9              001     0012          88101     3  PM2.5 - Local Conditions
# 10             001     0007          88101     3  PM2.5 - Local Conditions
# 11             001     0009          88101     3  PM2.5 - Local Conditions
# 12             001     0011          88101     3  PM2.5 - Local Conditions
# 13             001     0012          88101     3  PM2.5 - Local Conditions
# 14             001     0007          88101     3  PM2.5 - Local Conditions
# 15             001     0009          88101     3  PM2.5 - Local Conditions
# 16             001     0011          88101     3  PM2.5 - Local Conditions
# 17             001     0012          88101     3  PM2.5 - Local Conditions
# 18             001     0007          88101     3  PM2.5 - Local Conditions
# 19             001     0009          88101     3  PM2.5 - Local Conditions
# 20             001     0011          88101     3  PM2.5 - Local Conditions
# 21             001     0012          88101     3  PM2.5 - Local Conditions
# 22             001     0007          88101     3  PM2.5 - Local Conditions
# 23             001     0009          88101     3  PM2.5 - Local Conditions
# 24             001     0011          88101     3  PM2.5 - Local Conditions
# 25             001     0012          88101     3  PM2.5 - Local Conditions
# 26             001     0007          88101     3  PM2.5 - Local Conditions
# 27             001     0009          88101     3  PM2.5 - Local Conditions
# 28             001     0011          88101     3  PM2.5 - Local Conditions
# 29             001     0012          88101     3  PM2.5 - Local Conditions
# ...            ...      ...            ...   ...                       ...
# 543990         113     1003          88101     1  PM2.5 - Local Conditions
# 543991         113     1003          88101     1  PM2.5 - Local Conditions
# 543992         113     1003          88101     1  PM2.5 - Local Conditions
# 543993         113     1003          88101     1  PM2.5 - Local Conditions
# 543994         113     1003          88101     1  PM2.5 - Local Conditions
# 543995         113     1003          88101     1  PM2.5 - Local Conditions
# 543996         113     1003          88101     1  PM2.5 - Local Conditions
# 543997         113     1003          88101     1  PM2.5 - Local Conditions
# 543998         113     1003          88101     1  PM2.5 - Local Conditions
# 543999         113     1003          88101     1  PM2.5 - Local Conditions
# 544000         113     1003          88101     1  PM2.5 - Local Conditions
# 544001         113     1003          88101     1  PM2.5 - Local Conditions
# 544002         113     1003          88101     1  PM2.5 - Local Conditions
# 544003         113     1003          88101     1  PM2.5 - Local Conditions
# 544004         113     1003          88101     1  PM2.5 - Local Conditions
# 544005         113     1003          88101     1  PM2.5 - Local Conditions
# 544006         113     1003          88101     1  PM2.5 - Local Conditions
# 544007         113     1003          88101     1  PM2.5 - Local Conditions
# 544008         113     1003          88101     1  PM2.5 - Local Conditions
# 544009         113     1003          88101     1  PM2.5 - Local Conditions
# 544010         113     1003          88101     1  PM2.5 - Local Conditions
# 544011         113     1003          88101     1  PM2.5 - Local Conditions
# 544012         113     1003          88101     1  PM2.5 - Local Conditions
# 544013         113     1003          88101     1  PM2.5 - Local Conditions
# 544014         113     1003          88101     1  PM2.5 - Local Conditions
# 544015         113     1003          88101     1  PM2.5 - Local Conditions
# 544016         113     1003          88101     1  PM2.5 - Local Conditions
# 544017         113     1003          88101     1  PM2.5 - Local Conditions
# 544018        None     None           None  None                      None
# 544019        None     None           None  None                      None
#
#         ...   Sample Measurement             Units of Measure Sample Duration  \
# 0       ...                   14  Micrograms/cubic meter (LC)          1 HOUR
# 1       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 2       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 3       ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 4       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 5       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 6       ...                   14  Micrograms/cubic meter (LC)          1 HOUR
# 7       ...                    8  Micrograms/cubic meter (LC)          1 HOUR
# 8       ...                   15  Micrograms/cubic meter (LC)          1 HOUR
# 9       ...                   22  Micrograms/cubic meter (LC)          1 HOUR
# 10      ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 11      ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 12      ...                   16  Micrograms/cubic meter (LC)          1 HOUR
# 13      ...                   12  Micrograms/cubic meter (LC)          1 HOUR
# 14      ...                   16  Micrograms/cubic meter (LC)          1 HOUR
# 15      ...                   12  Micrograms/cubic meter (LC)          1 HOUR
# 16      ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 17      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 18      ...                   17  Micrograms/cubic meter (LC)          1 HOUR
# 19      ...                    9  Micrograms/cubic meter (LC)          1 HOUR
# 20      ...                   11  Micrograms/cubic meter (LC)          1 HOUR
# 21      ...                   20  Micrograms/cubic meter (LC)          1 HOUR
# 22      ...                   15  Micrograms/cubic meter (LC)          1 HOUR
# 23      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 24      ...                   11  Micrograms/cubic meter (LC)          1 HOUR
# 25      ...                   12  Micrograms/cubic meter (LC)          1 HOUR
# 26      ...                   11  Micrograms/cubic meter (LC)          1 HOUR
# 27      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 28      ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 29      ...                   14  Micrograms/cubic meter (LC)          1 HOUR
# ...     ...                  ...                          ...             ...
# 543990  ...                 16.9  Micrograms/cubic meter (LC)         24 HOUR
# 543991  ...                    8  Micrograms/cubic meter (LC)         24 HOUR
# 543992  ...                  6.5  Micrograms/cubic meter (LC)         24 HOUR
# 543993  ...                  3.4  Micrograms/cubic meter (LC)         24 HOUR
# 543994  ...                 14.9  Micrograms/cubic meter (LC)         24 HOUR
# 543995  ...                  4.4  Micrograms/cubic meter (LC)         24 HOUR
# 543996  ...                 17.3  Micrograms/cubic meter (LC)         24 HOUR
# 543997  ...                 11.8  Micrograms/cubic meter (LC)         24 HOUR
# 543998  ...                  3.9  Micrograms/cubic meter (LC)         24 HOUR
# 543999  ...                    2  Micrograms/cubic meter (LC)         24 HOUR
# 544000  ...                  9.7  Micrograms/cubic meter (LC)         24 HOUR
# 544001  ...                  7.7  Micrograms/cubic meter (LC)         24 HOUR
# 544002  ...                  5.5  Micrograms/cubic meter (LC)         24 HOUR
# 544003  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 544004  ...                 13.2  Micrograms/cubic meter (LC)         24 HOUR
# 544005  ...                    3  Micrograms/cubic meter (LC)         24 HOUR
# 544006  ...                    6  Micrograms/cubic meter (LC)         24 HOUR
# 544007  ...                  4.5  Micrograms/cubic meter (LC)         24 HOUR
# 544008  ...                  5.5  Micrograms/cubic meter (LC)         24 HOUR
# 544009  ...                  4.8  Micrograms/cubic meter (LC)         24 HOUR
# 544010  ...                  6.8  Micrograms/cubic meter (LC)         24 HOUR
# 544011  ...                  8.8  Micrograms/cubic meter (LC)         24 HOUR
# 544012  ...                  3.6  Micrograms/cubic meter (LC)         24 HOUR
# 544013  ...                  4.6  Micrograms/cubic meter (LC)         24 HOUR
# 544014  ...                  5.2  Micrograms/cubic meter (LC)         24 HOUR
# 544015  ...                  7.1  Micrograms/cubic meter (LC)         24 HOUR
# 544016  ...                  2.1  Micrograms/cubic meter (LC)         24 HOUR
# 544017  ...                  3.5  Micrograms/cubic meter (LC)         24 HOUR
# 544018  ...                 None                         None            None
# 544019  ...                 None                         None            None
#
#        Sample Frequency Detection Limit Measurement Uncertainty  \
# 0                                     5
# 1                                     5
# 2                                     5
# 3                                     5
# 4                                     5
# 5                                     5
# 6                                     5
# 7                                     5
# 8                                     5
# 9                                     5
# 10                                    5
# 11                                    5
# 12                                    5
# 13                                    5
# 14                                    5
# 15                                    5
# 16                                    5
# 17                                    5
# 18                                    5
# 19                                    5
# 20                                    5
# 21                                    5
# 22                                    5
# 23                                    5
# 24                                    5
# 25                                    5
# 26                                    5
# 27                                    5
# 28                                    5
# 29                                    5
# ...                 ...             ...                     ...
# 543990                                2
# 543991                                2
# 543992                                2
# 543993                                2
# 543994                                2
# 543995                                2
# 543996                                2
# 543997                                2
# 543998                                2
# 543999                                2
# 544000                                2
# 544001                                2
# 544002                                2
# 544003                                2
# 544004                                2
# 544005                                2
# 544006                                2
# 544007                                2
# 544008                                2
# 544009                                2
# 544010                                2
# 544011                                2
# 544012                                2
# 544013                                2
# 544014                                2
# 544015                                2
# 544016                                2
# 544017                                2
# 544018             None            None                    None
# 544019             None            None                    None
#
#        Qualifier Description Method Type  \
# 0                             Equivalent
# 1                             Equivalent
# 2                             Equivalent
# 3                             Equivalent
# 4                             Equivalent
# 5                             Equivalent
# 6                             Equivalent
# 7                             Equivalent
# 8                             Equivalent
# 9                             Equivalent
# 10                            Equivalent
# 11                            Equivalent
# 12                            Equivalent
# 13                            Equivalent
# 14                            Equivalent
# 15                            Equivalent
# 16                            Equivalent
# 17                            Equivalent
# 18                            Equivalent
# 19                            Equivalent
# 20                            Equivalent
# 21                            Equivalent
# 22                            Equivalent
# 23                            Equivalent
# 24                            Equivalent
# 25                            Equivalent
# 26                            Equivalent
# 27                            Equivalent
# 28                            Equivalent
# 29                            Equivalent
# ...                      ...         ...
# 543990                         Reference
# 543991                         Reference
# 543992        Wildfire-U. S.   Reference
# 543993                         Reference
# 543994                         Reference
# 543995                         Reference
# 543996                         Reference
# 543997        Wildfire-U. S.   Reference
# 543998                         Reference
# 543999                         Reference
# 544000                         Reference
# 544001                         Reference
# 544002        Wildfire-U. S.   Reference
# 544003                         Reference
# 544004                         Reference
# 544005                         Reference
# 544006                         Reference
# 544007                         Reference
# 544008        Wildfire-U. S.   Reference
# 544009                         Reference
# 544010            High Winds   Reference
# 544011        Wildfire-U. S.   Reference
# 544012            High Winds   Reference
# 544013                         Reference
# 544014                         Reference
# 544015                         Reference
# 544016                         Reference
# 544017        Wildfire-U. S.   Reference
# 544018                  None        None
# 544019                  None        None
#
#                                        Method Description   FIPS
# 0       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 1       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 2       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 3       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 4       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 5       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 6       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 7       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 8       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 9       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 10      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 11      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 12      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 13      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 14      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 15      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 16      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 17      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 18      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 19      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 20      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 21      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 22      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 23      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 24      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 25      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 26      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 27      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 28      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 29      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# ...                                                   ...    ...
# 543990  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543991  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543992  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543993  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543994  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543995  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543996  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543997  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543998  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 543999  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544000  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544001  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544002  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544003  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544004  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544005  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544006  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544007  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544008  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544009  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544010  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544011  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544012  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544013  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544014  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544015  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544016  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544017  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 544018                                               None    NaN
# 544019                                               None    NaN
#
# [544020 rows x 26 columns]

# %%
countyname = { "001": "Alameda", "003": "Apline", "005": "Amador", "007":"Butte", "009":"Calaveras", "011": "Colusa", "013":"Contra Costa", "015":"Del Norte", "017":"El Dorado", "019": "Fresno", "021": "Glenn", "023": "Humboldt", "025": "Imperial", "027": "Inyo", "029": "Kern", "031": "Kings", "033":"Lake", "035": "Lassen", "037": "Los Angeles", "039": "Madera", "041": "Marin", "043": "Mariposa", "045": "Mendicino", "047": "Merced", "049": "Modoc", "051": "Mono", "053": "Monterey", "055": "Napa", "057": "Nevada", "059": "Orange", "061": "Placer", "063": "Plumas", "065": "Riverside", "067": "Sacramento", "069": "San Benito", "071": "San Bernardino", "073": "San Diego", "075": "San Francisco", "077": "San Joaquin", "079": "San Luis Obispo", "081": "San Mateo", "083": "Santa Barbara", "085": "Santa Clara", "087": "Santa Cruz", "089": "Shasta", "091": "Sierra", "093": "Siskiyou", "095": "Solano", "097": "Sonoma", "099": "Stanislaus", "101": "Sutter", "103": "Tehama", "105": "Trinity", "107": "Tulare", "109": "Tuolumne", "111": "Ventura", "113": "Yolo", "115": "Yuba"}

df_trim = data_2015[['County Code','Date Local','24 Hour Local','Date GMT','Sample Measurement', "Sample Frequency",'Units of Measure','Sample Duration', "Latitude", "Longitude", "FIPS"]]
df_trim["County Names"] = df_trim["County Code"].map(countyname)
df_trim
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#        County Code  Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 0              001  2015-01-29         23:00  2015-01-30                 14
# 1              001  2015-01-29         23:00  2015-01-30                 13
# 2              001  2015-01-29         23:00  2015-01-30                 13
# 3              001  2015-01-29         23:00  2015-01-30                  7
# 4              001  2015-01-29         22:00  2015-01-30                 13
# 5              001  2015-01-29         22:00  2015-01-30                 13
# 6              001  2015-01-29         22:00  2015-01-30                 14
# 7              001  2015-01-29         22:00  2015-01-30                  8
# 8              001  2015-01-29         00:00  2015-01-29                 15
# 9              001  2015-01-29         00:00  2015-01-29                 22
# 10             001  2015-01-29         00:00  2015-01-29                 13
# 11             001  2015-01-29         00:00  2015-01-29                 13
# 12             001  2015-01-29         20:00  2015-01-30                 16
# 13             001  2015-01-29         20:00  2015-01-30                 12
# 14             001  2015-01-29         20:00  2015-01-30                 16
# 15             001  2015-01-29         20:00  2015-01-30                 12
# 16             001  2015-01-29         19:00  2015-01-30                 13
# 17             001  2015-01-29         19:00  2015-01-30                 10
# 18             001  2015-01-29         19:00  2015-01-30                 17
# 19             001  2015-01-29         19:00  2015-01-30                  9
# 20             001  2015-01-29         21:00  2015-01-30                 11
# 21             001  2015-01-29         21:00  2015-01-30                 20
# 22             001  2015-01-29         21:00  2015-01-30                 15
# 23             001  2015-01-29         21:00  2015-01-30                 10
# 24             001  2015-01-29         18:00  2015-01-30                 11
# 25             001  2015-01-29         18:00  2015-01-30                 12
# 26             001  2015-01-29         18:00  2015-01-30                 11
# 27             001  2015-01-29         18:00  2015-01-30                 10
# 28             001  2015-01-29         17:00  2015-01-30                  7
# 29             001  2015-01-29         17:00  2015-01-30                 14
# ...            ...         ...           ...         ...                ...
# 543990         113  2015-01-06         00:00  2015-01-06               16.9
# 543991         113  2015-11-20         00:00  2015-11-20                  8
# 543992         113  2015-09-03         00:00  2015-09-03                6.5
# 543993         113  2015-07-11         00:00  2015-07-11                3.4
# 543994         113  2015-11-08         00:00  2015-11-08               14.9
# 543995         113  2015-02-11         00:00  2015-02-11                4.4
# 543996         113  2015-12-02         00:00  2015-12-02               17.3
# 543997         113  2015-08-26         00:00  2015-08-26               11.8
# 543998         113  2015-03-31         00:00  2015-03-31                3.9
# 543999         113  2015-03-25         00:00  2015-03-25                  2
# 544000         113  2015-10-09         00:00  2015-10-09                9.7
# 544001         113  2015-05-08         00:00  2015-05-08                7.7
# 544002         113  2015-08-10         00:00  2015-08-10                5.5
# 544003         113  2015-11-02         00:00  2015-11-02                  1
# 544004         113  2015-10-27         00:00  2015-10-27               13.2
# 544005         113  2015-12-20         00:00  2015-12-20                  3
# 544006         113  2015-06-11         00:00  2015-06-11                  6
# 544007         113  2015-05-18         00:00  2015-05-18                4.5
# 544008         113  2015-09-27         00:00  2015-09-27                5.5
# 544009         113  2015-04-24         00:00  2015-04-24                4.8
# 544010         113  2015-04-30         00:00  2015-04-30                6.8
# 544011         113  2015-07-29         00:00  2015-07-29                8.8
# 544012         113  2015-10-29         00:00  2015-10-29                3.6
# 544013         113  2015-05-12         00:00  2015-05-12                4.6
# 544014         113  2015-01-30         00:00  2015-01-30                5.2
# 544015         113  2015-04-18         00:00  2015-04-18                7.1
# 544016         113  2015-12-14         00:00  2015-12-14                2.1
# 544017         113  2015-08-28         00:00  2015-08-28                3.5
# 544018        None        None          None        None               None
# 544019        None        None          None        None               None
#
#        Sample Frequency             Units of Measure Sample Duration  \
# 0                        Micrograms/cubic meter (LC)          1 HOUR
# 1                        Micrograms/cubic meter (LC)          1 HOUR
# 2                        Micrograms/cubic meter (LC)          1 HOUR
# 3                        Micrograms/cubic meter (LC)          1 HOUR
# 4                        Micrograms/cubic meter (LC)          1 HOUR
# 5                        Micrograms/cubic meter (LC)          1 HOUR
# 6                        Micrograms/cubic meter (LC)          1 HOUR
# 7                        Micrograms/cubic meter (LC)          1 HOUR
# 8                        Micrograms/cubic meter (LC)          1 HOUR
# 9                        Micrograms/cubic meter (LC)          1 HOUR
# 10                       Micrograms/cubic meter (LC)          1 HOUR
# 11                       Micrograms/cubic meter (LC)          1 HOUR
# 12                       Micrograms/cubic meter (LC)          1 HOUR
# 13                       Micrograms/cubic meter (LC)          1 HOUR
# 14                       Micrograms/cubic meter (LC)          1 HOUR
# 15                       Micrograms/cubic meter (LC)          1 HOUR
# 16                       Micrograms/cubic meter (LC)          1 HOUR
# 17                       Micrograms/cubic meter (LC)          1 HOUR
# 18                       Micrograms/cubic meter (LC)          1 HOUR
# 19                       Micrograms/cubic meter (LC)          1 HOUR
# 20                       Micrograms/cubic meter (LC)          1 HOUR
# 21                       Micrograms/cubic meter (LC)          1 HOUR
# 22                       Micrograms/cubic meter (LC)          1 HOUR
# 23                       Micrograms/cubic meter (LC)          1 HOUR
# 24                       Micrograms/cubic meter (LC)          1 HOUR
# 25                       Micrograms/cubic meter (LC)          1 HOUR
# 26                       Micrograms/cubic meter (LC)          1 HOUR
# 27                       Micrograms/cubic meter (LC)          1 HOUR
# 28                       Micrograms/cubic meter (LC)          1 HOUR
# 29                       Micrograms/cubic meter (LC)          1 HOUR
# ...                 ...                          ...             ...
# 543990                   Micrograms/cubic meter (LC)         24 HOUR
# 543991                   Micrograms/cubic meter (LC)         24 HOUR
# 543992                   Micrograms/cubic meter (LC)         24 HOUR
# 543993                   Micrograms/cubic meter (LC)         24 HOUR
# 543994                   Micrograms/cubic meter (LC)         24 HOUR
# 543995                   Micrograms/cubic meter (LC)         24 HOUR
# 543996                   Micrograms/cubic meter (LC)         24 HOUR
# 543997                   Micrograms/cubic meter (LC)         24 HOUR
# 543998                   Micrograms/cubic meter (LC)         24 HOUR
# 543999                   Micrograms/cubic meter (LC)         24 HOUR
# 544000                   Micrograms/cubic meter (LC)         24 HOUR
# 544001                   Micrograms/cubic meter (LC)         24 HOUR
# 544002                   Micrograms/cubic meter (LC)         24 HOUR
# 544003                   Micrograms/cubic meter (LC)         24 HOUR
# 544004                   Micrograms/cubic meter (LC)         24 HOUR
# 544005                   Micrograms/cubic meter (LC)         24 HOUR
# 544006                   Micrograms/cubic meter (LC)         24 HOUR
# 544007                   Micrograms/cubic meter (LC)         24 HOUR
# 544008                   Micrograms/cubic meter (LC)         24 HOUR
# 544009                   Micrograms/cubic meter (LC)         24 HOUR
# 544010                   Micrograms/cubic meter (LC)         24 HOUR
# 544011                   Micrograms/cubic meter (LC)         24 HOUR
# 544012                   Micrograms/cubic meter (LC)         24 HOUR
# 544013                   Micrograms/cubic meter (LC)         24 HOUR
# 544014                   Micrograms/cubic meter (LC)         24 HOUR
# 544015                   Micrograms/cubic meter (LC)         24 HOUR
# 544016                   Micrograms/cubic meter (LC)         24 HOUR
# 544017                   Micrograms/cubic meter (LC)         24 HOUR
# 544018             None                         None            None
# 544019             None                         None            None
#
#            Latitude    Longitude   FIPS County Names
# 0         37.814781  -122.282347  06001      Alameda
# 1         37.793624  -122.263376  06001      Alameda
# 2         37.687526  -121.784217  06001      Alameda
# 3         37.743065  -122.169935  06001      Alameda
# 4         37.814781  -122.282347  06001      Alameda
# 5         37.793624  -122.263376  06001      Alameda
# 6         37.687526  -121.784217  06001      Alameda
# 7         37.743065  -122.169935  06001      Alameda
# 8         37.814781  -122.282347  06001      Alameda
# 9         37.793624  -122.263376  06001      Alameda
# 10        37.687526  -121.784217  06001      Alameda
# 11        37.743065  -122.169935  06001      Alameda
# 12        37.814781  -122.282347  06001      Alameda
# 13        37.793624  -122.263376  06001      Alameda
# 14        37.687526  -121.784217  06001      Alameda
# 15        37.743065  -122.169935  06001      Alameda
# 16        37.814781  -122.282347  06001      Alameda
# 17        37.793624  -122.263376  06001      Alameda
# 18        37.687526  -121.784217  06001      Alameda
# 19        37.743065  -122.169935  06001      Alameda
# 20        37.814781  -122.282347  06001      Alameda
# 21        37.793624  -122.263376  06001      Alameda
# 22        37.687526  -121.784217  06001      Alameda
# 23        37.743065  -122.169935  06001      Alameda
# 24        37.814781  -122.282347  06001      Alameda
# 25        37.793624  -122.263376  06001      Alameda
# 26        37.687526  -121.784217  06001      Alameda
# 27        37.743065  -122.169935  06001      Alameda
# 28        37.814781  -122.282347  06001      Alameda
# 29        37.793624  -122.263376  06001      Alameda
# ...             ...          ...    ...          ...
# 543990     38.66121   -121.73269  06113         Yolo
# 543991     38.66121   -121.73269  06113         Yolo
# 543992     38.66121   -121.73269  06113         Yolo
# 543993     38.66121   -121.73269  06113         Yolo
# 543994     38.66121   -121.73269  06113         Yolo
# 543995     38.66121   -121.73269  06113         Yolo
# 543996     38.66121   -121.73269  06113         Yolo
# 543997     38.66121   -121.73269  06113         Yolo
# 543998     38.66121   -121.73269  06113         Yolo
# 543999     38.66121   -121.73269  06113         Yolo
# 544000     38.66121   -121.73269  06113         Yolo
# 544001     38.66121   -121.73269  06113         Yolo
# 544002     38.66121   -121.73269  06113         Yolo
# 544003     38.66121   -121.73269  06113         Yolo
# 544004     38.66121   -121.73269  06113         Yolo
# 544005     38.66121   -121.73269  06113         Yolo
# 544006     38.66121   -121.73269  06113         Yolo
# 544007     38.66121   -121.73269  06113         Yolo
# 544008     38.66121   -121.73269  06113         Yolo
# 544009     38.66121   -121.73269  06113         Yolo
# 544010     38.66121   -121.73269  06113         Yolo
# 544011     38.66121   -121.73269  06113         Yolo
# 544012     38.66121   -121.73269  06113         Yolo
# 544013     38.66121   -121.73269  06113         Yolo
# 544014     38.66121   -121.73269  06113         Yolo
# 544015     38.66121   -121.73269  06113         Yolo
# 544016     38.66121   -121.73269  06113         Yolo
# 544017     38.66121   -121.73269  06113         Yolo
# 544018  END OF FILE         None    NaN          NaN
# 544019  END OF FILE         None    NaN          NaN
#
# [544020 rows x 12 columns]

# %%
#Create 2 dataframes to hold records for sampling done by 24 hour duration and 1 hour duration
hour1_df = df_trim.loc[(df_trim["Sample Duration"]== "1 HOUR")]
hour24_df = df_trim.loc[(df_trim["Sample Duration"]== "24 HOUR")]

#See which sampling duration has more unique counties
hour1_df["County Names"].nunique()
hour24_df["County Names"].nunique()
# Out:
# 28

# %%
#Convert 'Date Local' column to datetime to extract month #
hour1_df['Date Local'] = pd.to_datetime(hour1_df['Date Local'])

#Creating column for Month # for 1hour sample duration df
hour1_df['Month'] = pd.DatetimeIndex(hour1_df['Date Local']).month
hour1_df["Month"].fillna(0)
hour1_df["Month"].astype(float)
hour1_df.fillna(0)
hour1_df["County Names"].dtype

#Convert 'Date Local' column to datetime to extract month #
hour24_df['Date Local'] = pd.to_datetime(hour24_df['Date Local'])

#Creating column for Month # for 24 hour sample duration df
hour24_df['Month'] = pd.DatetimeIndex(hour24_df['Date Local']).month
hour24_df["Month"].fillna(0)
hour24_df["Month"].astype(float)
hour24_df.fillna(0)
hour24_df.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       County Code Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 34093         007 2015-01-29         00:00  2015-01-29               13.8
# 34094         007 2015-02-16         00:00  2015-02-16                6.1
# 34095         007 2015-05-25         00:00  2015-05-25                6.6
# 34096         007 2015-07-03         00:00  2015-07-03                8.3
# 34097         007 2015-07-04         00:00  2015-07-04                6.2
#
#       Sample Frequency             Units of Measure Sample Duration  Latitude  \
# 34093                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 34094                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 34095                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 34096                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 34097                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
#
#         Longitude   FIPS County Names  Month
# 34093  -121.84047  06007        Butte      1
# 34094  -121.84047  06007        Butte      2
# 34095  -121.84047  06007        Butte      5
# 34096  -121.84047  06007        Butte      7
# 34097  -121.84047  06007        Butte      7

# %%
#extract only relevant columns and create a groupby df (for 24 hour sample duration)
mday_df = hour24_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mday_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuff24 = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuff24
mday_df["PM2.5 Values 2015"] = tuff24
finalday = mday_df
finalday.drop(columns="Sample Measurement")
#finalday
finalday.to_csv("2015CA24hrPM2.5.csv")
finalday.head()
# Out:
#       County Names  Month Sample Measurement  Latitude   Longitude   FIPS  \
# 34093        Butte      1               13.8  39.76168  -121.84047  06007
# 34094        Butte      2                6.1  39.76168  -121.84047  06007
# 34095        Butte      5                6.6  39.76168  -121.84047  06007
# 34096        Butte      7                8.3  39.76168  -121.84047  06007
# 34097        Butte      7                6.2  39.76168  -121.84047  06007
#
#        PM2.5 Values 2015
# 34093               13.8
# 34094                6.1
# 34095                6.6
# 34096                8.3
# 34097                6.2

# %%
#groupby to graph results
county_date24hr = pd.DataFrame(finalday.groupby(['County Names', 'Month']).mean())
county_date24hr.head()
# Out:
#                     PM2.5 Values 2015
# County Names Month
# Butte        1              23.786957
#              2               8.759259
#              3               5.709677
#              4               5.100000
#              5               6.338462

# %%
county_date24hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2015 (24hr Sampling Duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2015 PM2.5 AVG (24hr Sampling).png", bbox_inches='tight')
plt.figure()

# %%
# extract only relevant columns and create a groupby df
mhour_df = hour1_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mhour_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mhour_df["Sample Measurement"], errors='coerce')
tuffhour_df
mhour_df["PM2.5 Values 2015"] = tuffhour_df
finalhour = mhour_df
finalhour.drop(columns="Sample Measurement")

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuffhour_df
mday_df["PM2.5 Values 2015"] = tuffhour_df
finalhour = mday_df
finalhour.drop(columns="Sample Measurement")

finalhour.to_csv("2015CA1hrPM2.5.csv")

# %%
#groupby to graph results
county_1hr = pd.DataFrame(finalhour.groupby(['County Names', 'Month']).mean())
county_1hr.head()
# Out:
#                     PM2.5 Values 2015
# County Names Month
# Butte        1              23.786957
#              2               8.759259
#              3               5.709677
#              4               5.100000
#              5               6.338462

# %%
county_1hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2015 (1Hr Sampling duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2015 PM2.5 AVG (1hrSampling).png", bbox_inches='tight')
plt.figure()

# %%
#Find Max for 24hr sampling group
max_pm25 = county_date24hr['PM2.5 Values 2015'].max()
max_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2015'] == max_pm25,:]
max_county24hr

#Find Max for 1hr sampling group
max_pm25 = county_1hr['PM2.5 Values 2015'].max()
max_1hr = county_1hr.loc[county_1hr['PM2.5 Values 2015'] == max_pm25,:]
max_1hr
# Out:
#                     PM2.5 Values 2015
# County Names Month
# Tulare       1              41.828571

# %%
#Find Min
min_pm25 = county_date24hr['PM2.5 Values 2015'].min()
min_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2015'] == min_pm25,:]
min_county24hr

min_pm25 = county_1hr['PM2.5 Values 2015'].min()
min_county1hr = county_1hr.loc[county_1hr['PM2.5 Values 2015'] == min_pm25,:]
min_county1hr
# Out:
#                     PM2.5 Values 2015
# County Names Month
# Lake         11                  2.04

# %%
# create a df with only the Max & Min, and SD/LA for ref counties
minmax_df = finalday.loc[(finalday['County Names']=='Tulare') | (finalday['County Names']=='Lake') | (finalday['County Names']=='San Diego') | (finalday['County Names']=='Los Angeles'),:]
minmax_df.head()
# Out:
#        County Names  Month Sample Measurement Latitude   Longitude   FIPS  \
# 154393         Lake     11                2.5  39.0327  -122.92229  06033
# 154394         Lake      6                3.7  39.0327  -122.92229  06033
# 154395         Lake      7                4.6  39.0327  -122.92229  06033
# 154396         Lake     10                3.1  39.0327  -122.92229  06033
# 154397         Lake      9                4.5  39.0327  -122.92229  06033
#
#         PM2.5 Values 2015
# 154393                2.5
# 154394                3.7
# 154395                4.6
# 154396                3.1
# 154397                4.5

# %%
mm_mean_df = minmax_df.loc[:, ['County Names', 'Month', 'PM2.5 Values 2015']]
mm_df = pd.DataFrame(mm_mean_df.groupby(['County Names', 'Month']).mean())
mm_df.head()
# Out:
#                     PM2.5 Values 2015
# County Names Month
# Lake         1               2.760000
#              2               2.750000
#              3               2.683333
#              4               3.280000
#              5               3.740000

# %%
mm_df.unstack(0).plot(figsize = (10,10))
plt.title("Graph of PM2.5 Max & Min in CA + San Diego & Los Angeles 2015")
plt.xlabel('Month')
plt.ylabel('PM2.5 Mean/Month')
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("2015_CA_MaxMin_SDLA.png", bbox_inches='tight') 
plt.figure()

# %%
county_final = pd.DataFrame(finalday.groupby(['FIPS']).mean())
county_sum = county_final.drop(columns=["Month"], )
#county_sum.to_csv('2015_CA_PM25_Mean.csv')
county_sum
county_sum.sort_values(by=["PM2.5 Values 2015"], ascending=False)
#county_sum.to_csv('2015_CA_PM25_Sum.csv')
# Out:
#        PM2.5 Values 2015
# FIPS
# 06031          35.754545
# 06107          16.119231
# 06029          15.513798
# 06019          14.017726
# 06047          12.712931
# 06099          12.555172
# 06063          12.131507
# 06039          11.730833
# 06071          11.475239
# 06037          11.028634
# 06065          10.750690
# 06085          10.625641
# 06067          10.004333
# 06101           9.660909
# 06025           9.369204
# 06007           9.169578
# 06059           8.877073
# 06073           8.634233
# 06011           8.407273
# 06061           8.093056
# 06113           7.625424
# 06093           7.474074
# 06089           7.452632
# 06027           5.590909
# 06023           5.310460
# 06053           4.991667
# 06057           4.941053
# 06033           3.845000

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
plotly.tools.set_credentials_file(username=Plotuser, api_key=Plotkey)

# %%
#create lists of values to graph in plotly
values = county_sum["PM2.5 Values 2015"].tolist()
fips = county_sum.index.values
print(values)
# Out:
# [9.169578313253009, 8.407272727272728, 14.017725752508374, 5.310460251046022, 9.369204152249145, 5.590909090909091, 15.513798449612388, 35.75454545454546, 3.8449999999999993, 11.028634146341481, 11.730833333333333, 12.712931034482757, 4.991666666666668, 4.941052631578949, 8.8770731707317, 8.093055555555557, 12.131506849315064, 10.750689972401082, 10.00433333333335, 11.475239398084792, 8.634233128834339, 10.625641025641022, 7.4526315789473685, 7.474074074074076, 12.555172413793105, 9.66090909090909, 16.11923076923076, 7.62542372881356]

# %%
#send FIPS codes and corresponding PM2.5 values to plotly to graph
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['CA'],
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='PM2.5 by County', title='California PM2.5 2015 By County'
)
py.iplot(fig, filename='CA_PM2.5 2015')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tonyphelps/10.embed" height="450px" width="900px"></iframe>
