# %%
#import dependencies
import pandas as pd
import requests as req
#create separate file with individual log in credentials to be imported

from config import (user_id_aqs, password_aqs, Plotkey, Plotuser)
import csv
import matplotlib.pyplot as plt

# %%
codes = []
countycodes = ["{0:03}".format(i) for i in range(117) if i%2 > 0]

for countycode in countycodes:
    codes.append(countycode)
#codes

# %%
#API REQUEST
URL_new = f"https://aqs.epa.gov/api/rawData?user={user_id_aqs}&pw={password_aqs}&format=DMCSV&param=88101&bdate=20160101&edate=20161231&state=06&county="
list_2016 = []

for x in codes:
    url_loop = URL_new + x
    print(f"fetching county code {x}")
    response1 = req.get(url_loop)
    print(f"Got API Response for {x}")
    wrapper = csv.reader(response1.text.strip().split('\n'))
    header = next(wrapper)
    for record in wrapper:
        list_2016.append(record)
    print(f"Appended List with {x} API Response")
# Out:
# fetching county code 001
# Got API Response for 001
# Appended List with 001 API Response
# fetching county code 003
# Got API Response for 003
# Appended List with 003 API Response
# fetching county code 005
# Got API Response for 005
# Appended List with 005 API Response
# fetching county code 007
# Got API Response for 007
# Appended List with 007 API Response
# fetching county code 009
# Got API Response for 009
# Appended List with 009 API Response
# fetching county code 011
# Got API Response for 011
# Appended List with 011 API Response
# fetching county code 013
# Got API Response for 013
# Appended List with 013 API Response
# fetching county code 015
# Got API Response for 015
# Appended List with 015 API Response
# fetching county code 017
# Got API Response for 017
# Appended List with 017 API Response
# fetching county code 019
# Got API Response for 019
# Appended List with 019 API Response
# fetching county code 021
# Got API Response for 021
# Appended List with 021 API Response
# fetching county code 023
# Got API Response for 023
# Appended List with 023 API Response
# fetching county code 025
# Got API Response for 025
# Appended List with 025 API Response
# fetching county code 027
# Got API Response for 027
# Appended List with 027 API Response
# fetching county code 029
# Got API Response for 029
# Appended List with 029 API Response
# fetching county code 031
# Got API Response for 031
# Appended List with 031 API Response
# fetching county code 033
# Got API Response for 033
# Appended List with 033 API Response
# fetching county code 035
# Got API Response for 035
# Appended List with 035 API Response
# fetching county code 037
# Got API Response for 037
# Appended List with 037 API Response
# fetching county code 039
# Got API Response for 039
# Appended List with 039 API Response
# fetching county code 041
# Got API Response for 041
# Appended List with 041 API Response
# fetching county code 043
# Got API Response for 043
# Appended List with 043 API Response
# fetching county code 045
# Got API Response for 045
# Appended List with 045 API Response
# fetching county code 047
# Got API Response for 047
# Appended List with 047 API Response
# fetching county code 049
# Got API Response for 049
# Appended List with 049 API Response
# fetching county code 051
# Got API Response for 051
# Appended List with 051 API Response
# fetching county code 053
# Got API Response for 053
# Appended List with 053 API Response
# fetching county code 055
# Got API Response for 055
# Appended List with 055 API Response
# fetching county code 057
# Got API Response for 057
# Appended List with 057 API Response
# fetching county code 059
# Got API Response for 059
# Appended List with 059 API Response
# fetching county code 061
# Got API Response for 061
# Appended List with 061 API Response
# fetching county code 063
# Got API Response for 063
# Appended List with 063 API Response
# fetching county code 065
# Got API Response for 065
# Appended List with 065 API Response
# fetching county code 067
# Got API Response for 067
# Appended List with 067 API Response
# fetching county code 069
# Got API Response for 069
# Appended List with 069 API Response
# fetching county code 071
# Got API Response for 071
# Appended List with 071 API Response
# fetching county code 073
# Got API Response for 073
# Appended List with 073 API Response
# fetching county code 075
# Got API Response for 075
# Appended List with 075 API Response
# fetching county code 077
# Got API Response for 077
# Appended List with 077 API Response
# fetching county code 079
# Got API Response for 079
# Appended List with 079 API Response
# fetching county code 081
# Got API Response for 081
# Appended List with 081 API Response
# fetching county code 083
# Got API Response for 083
# Appended List with 083 API Response
# fetching county code 085
# Got API Response for 085
# Appended List with 085 API Response
# fetching county code 087
# Got API Response for 087
# Appended List with 087 API Response
# fetching county code 089
# Got API Response for 089
# Appended List with 089 API Response
# fetching county code 091
# Got API Response for 091
# Appended List with 091 API Response
# fetching county code 093
# Got API Response for 093
# Appended List with 093 API Response
# fetching county code 095
# Got API Response for 095
# Appended List with 095 API Response
# fetching county code 097
# Got API Response for 097
# Appended List with 097 API Response
# fetching county code 099
# Got API Response for 099
# Appended List with 099 API Response
# fetching county code 101
# Got API Response for 101
# Appended List with 101 API Response
# fetching county code 103
# Got API Response for 103
# Appended List with 103 API Response
# fetching county code 105
# Got API Response for 105
# Appended List with 105 API Response
# fetching county code 107
# Got API Response for 107
# Appended List with 107 API Response
# fetching county code 109
# Got API Response for 109
# Appended List with 109 API Response
# fetching county code 111
# Got API Response for 111
# Appended List with 111 API Response
# fetching county code 113
# Got API Response for 113
# Appended List with 113 API Response
# fetching county code 115
# Got API Response for 115
# Appended List with 115 API Response

# %%
#Create DF and append FIPS column with county code and 06 (state code) to create FIPS code
data_2016 = pd.DataFrame(list_2016, columns = header)
data_2016["FIPS"] = "06" + data_2016["County Code"]
data_2016
# Out:
#            Latitude    Longitude  Datum Horizontal Accuracy State Code  \
# 0         37.793624  -122.263376  WGS84                   1         06
# 1         37.814781  -122.282347  WGS84                   6         06
# 2         37.687526  -121.784217  WGS84           109305.56         06
# 3         37.743065  -122.169935  WGS84                   6         06
# 4         37.793624  -122.263376  WGS84                   1         06
# 5         37.814781  -122.282347  WGS84                   6         06
# 6         37.687526  -121.784217  WGS84           109305.56         06
# 7         37.743065  -122.169935  WGS84                   6         06
# 8         37.793624  -122.263376  WGS84                   1         06
# 9         37.814781  -122.282347  WGS84                   6         06
# 10        37.687526  -121.784217  WGS84           109305.56         06
# 11        37.743065  -122.169935  WGS84                   6         06
# 12        37.793624  -122.263376  WGS84                   1         06
# 13        37.814781  -122.282347  WGS84                   6         06
# 14        37.687526  -121.784217  WGS84           109305.56         06
# 15        37.743065  -122.169935  WGS84                   6         06
# 16        37.793624  -122.263376  WGS84                   1         06
# 17        37.814781  -122.282347  WGS84                   6         06
# 18        37.687526  -121.784217  WGS84           109305.56         06
# 19        37.743065  -122.169935  WGS84                   6         06
# 20        37.793624  -122.263376  WGS84                   1         06
# 21        37.814781  -122.282347  WGS84                   6         06
# 22        37.687526  -121.784217  WGS84           109305.56         06
# 23        37.743065  -122.169935  WGS84                   6         06
# 24        37.793624  -122.263376  WGS84                   1         06
# 25        37.814781  -122.282347  WGS84                   6         06
# 26        37.687526  -121.784217  WGS84           109305.56         06
# 27        37.743065  -122.169935  WGS84                   6         06
# 28        37.793624  -122.263376  WGS84                   1         06
# 29        37.814781  -122.282347  WGS84                   6         06
# ...             ...          ...    ...                 ...        ...
# 587411     38.66121   -121.73269  WGS84              151.82         06
# 587412     38.66121   -121.73269  WGS84              151.82         06
# 587413     38.66121   -121.73269  WGS84              151.82         06
# 587414     38.66121   -121.73269  WGS84              151.82         06
# 587415     38.66121   -121.73269  WGS84              151.82         06
# 587416     38.66121   -121.73269  WGS84              151.82         06
# 587417     38.66121   -121.73269  WGS84              151.82         06
# 587418     38.66121   -121.73269  WGS84              151.82         06
# 587419     38.66121   -121.73269  WGS84              151.82         06
# 587420     38.66121   -121.73269  WGS84              151.82         06
# 587421     38.66121   -121.73269  WGS84              151.82         06
# 587422     38.66121   -121.73269  WGS84              151.82         06
# 587423     38.66121   -121.73269  WGS84              151.82         06
# 587424     38.66121   -121.73269  WGS84              151.82         06
# 587425     38.66121   -121.73269  WGS84              151.82         06
# 587426     38.66121   -121.73269  WGS84              151.82         06
# 587427     38.66121   -121.73269  WGS84              151.82         06
# 587428     38.66121   -121.73269  WGS84              151.82         06
# 587429     38.66121   -121.73269  WGS84              151.82         06
# 587430     38.66121   -121.73269  WGS84              151.82         06
# 587431     38.66121   -121.73269  WGS84              151.82         06
# 587432     38.66121   -121.73269  WGS84              151.82         06
# 587433     38.66121   -121.73269  WGS84              151.82         06
# 587434     38.66121   -121.73269  WGS84              151.82         06
# 587435     38.66121   -121.73269  WGS84              151.82         06
# 587436     38.66121   -121.73269  WGS84              151.82         06
# 587437     38.66121   -121.73269  WGS84              151.82         06
# 587438     38.66121   -121.73269  WGS84              151.82         06
# 587439  END OF FILE         None   None                None       None
# 587440  END OF FILE         None   None                None       None
#
#        County Code Site Num Parameter Code   POC        AQS Parameter Desc  \
# 0              001     0012          88101     3  PM2.5 - Local Conditions
# 1              001     0011          88101     3  PM2.5 - Local Conditions
# 2              001     0007          88101     3  PM2.5 - Local Conditions
# 3              001     0009          88101     3  PM2.5 - Local Conditions
# 4              001     0012          88101     3  PM2.5 - Local Conditions
# 5              001     0011          88101     3  PM2.5 - Local Conditions
# 6              001     0007          88101     3  PM2.5 - Local Conditions
# 7              001     0009          88101     3  PM2.5 - Local Conditions
# 8              001     0012          88101     3  PM2.5 - Local Conditions
# 9              001     0011          88101     3  PM2.5 - Local Conditions
# 10             001     0007          88101     3  PM2.5 - Local Conditions
# 11             001     0009          88101     3  PM2.5 - Local Conditions
# 12             001     0012          88101     3  PM2.5 - Local Conditions
# 13             001     0011          88101     3  PM2.5 - Local Conditions
# 14             001     0007          88101     3  PM2.5 - Local Conditions
# 15             001     0009          88101     3  PM2.5 - Local Conditions
# 16             001     0012          88101     3  PM2.5 - Local Conditions
# 17             001     0011          88101     3  PM2.5 - Local Conditions
# 18             001     0007          88101     3  PM2.5 - Local Conditions
# 19             001     0009          88101     3  PM2.5 - Local Conditions
# 20             001     0012          88101     3  PM2.5 - Local Conditions
# 21             001     0011          88101     3  PM2.5 - Local Conditions
# 22             001     0007          88101     3  PM2.5 - Local Conditions
# 23             001     0009          88101     3  PM2.5 - Local Conditions
# 24             001     0012          88101     3  PM2.5 - Local Conditions
# 25             001     0011          88101     3  PM2.5 - Local Conditions
# 26             001     0007          88101     3  PM2.5 - Local Conditions
# 27             001     0009          88101     3  PM2.5 - Local Conditions
# 28             001     0012          88101     3  PM2.5 - Local Conditions
# 29             001     0011          88101     3  PM2.5 - Local Conditions
# ...            ...      ...            ...   ...                       ...
# 587411         113     1003          88101     1  PM2.5 - Local Conditions
# 587412         113     1003          88101     1  PM2.5 - Local Conditions
# 587413         113     1003          88101     1  PM2.5 - Local Conditions
# 587414         113     1003          88101     1  PM2.5 - Local Conditions
# 587415         113     1003          88101     1  PM2.5 - Local Conditions
# 587416         113     1003          88101     1  PM2.5 - Local Conditions
# 587417         113     1003          88101     1  PM2.5 - Local Conditions
# 587418         113     1003          88101     1  PM2.5 - Local Conditions
# 587419         113     1003          88101     1  PM2.5 - Local Conditions
# 587420         113     1003          88101     1  PM2.5 - Local Conditions
# 587421         113     1003          88101     1  PM2.5 - Local Conditions
# 587422         113     1003          88101     1  PM2.5 - Local Conditions
# 587423         113     1003          88101     1  PM2.5 - Local Conditions
# 587424         113     1003          88101     1  PM2.5 - Local Conditions
# 587425         113     1003          88101     1  PM2.5 - Local Conditions
# 587426         113     1003          88101     1  PM2.5 - Local Conditions
# 587427         113     1003          88101     1  PM2.5 - Local Conditions
# 587428         113     1003          88101     1  PM2.5 - Local Conditions
# 587429         113     1003          88101     1  PM2.5 - Local Conditions
# 587430         113     1003          88101     1  PM2.5 - Local Conditions
# 587431         113     1003          88101     1  PM2.5 - Local Conditions
# 587432         113     1003          88101     1  PM2.5 - Local Conditions
# 587433         113     1003          88101     1  PM2.5 - Local Conditions
# 587434         113     1003          88101     1  PM2.5 - Local Conditions
# 587435         113     1003          88101     1  PM2.5 - Local Conditions
# 587436         113     1003          88101     1  PM2.5 - Local Conditions
# 587437         113     1003          88101     1  PM2.5 - Local Conditions
# 587438         113     1003          88101     1  PM2.5 - Local Conditions
# 587439        None     None           None  None                      None
# 587440        None     None           None  None                      None
#
#         ...   Sample Measurement             Units of Measure Sample Duration  \
# 0       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 1       ...                   18  Micrograms/cubic meter (LC)          1 HOUR
# 2       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 3       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 4       ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 5       ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 6       ...                   15  Micrograms/cubic meter (LC)          1 HOUR
# 7       ...                    9  Micrograms/cubic meter (LC)          1 HOUR
# 8       ...                    4  Micrograms/cubic meter (LC)          1 HOUR
# 9       ...                   11  Micrograms/cubic meter (LC)          1 HOUR
# 10      ...                   36  Micrograms/cubic meter (LC)          1 HOUR
# 11      ...                   17  Micrograms/cubic meter (LC)          1 HOUR
# 12      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 13      ...                   17  Micrograms/cubic meter (LC)          1 HOUR
# 14      ...                   23  Micrograms/cubic meter (LC)          1 HOUR
# 15      ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 16      ...                    8  Micrograms/cubic meter (LC)          1 HOUR
# 17      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 18      ...                   11  Micrograms/cubic meter (LC)          1 HOUR
# 19      ...                    4  Micrograms/cubic meter (LC)          1 HOUR
# 20      ...                    8  Micrograms/cubic meter (LC)          1 HOUR
# 21      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 22      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 23      ...                    9  Micrograms/cubic meter (LC)          1 HOUR
# 24      ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 25      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 26      ...                   10  Micrograms/cubic meter (LC)          1 HOUR
# 27      ...                    2  Micrograms/cubic meter (LC)          1 HOUR
# 28      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 29      ...                    6  Micrograms/cubic meter (LC)          1 HOUR
# ...     ...                  ...                          ...             ...
# 587411  ...                    6  Micrograms/cubic meter (LC)         24 HOUR
# 587412  ...                  6.8  Micrograms/cubic meter (LC)         24 HOUR
# 587413  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 587414  ...                  5.1  Micrograms/cubic meter (LC)         24 HOUR
# 587415  ...                  9.1  Micrograms/cubic meter (LC)         24 HOUR
# 587416  ...                    4  Micrograms/cubic meter (LC)         24 HOUR
# 587417  ...                  6.4  Micrograms/cubic meter (LC)         24 HOUR
# 587418  ...                  5.6  Micrograms/cubic meter (LC)         24 HOUR
# 587419  ...                  3.5  Micrograms/cubic meter (LC)         24 HOUR
# 587420  ...                    7  Micrograms/cubic meter (LC)         24 HOUR
# 587421  ...                  9.5  Micrograms/cubic meter (LC)         24 HOUR
# 587422  ...                  3.3  Micrograms/cubic meter (LC)         24 HOUR
# 587423  ...                  3.8  Micrograms/cubic meter (LC)         24 HOUR
# 587424  ...                 10.9  Micrograms/cubic meter (LC)         24 HOUR
# 587425  ...                  3.2  Micrograms/cubic meter (LC)         24 HOUR
# 587426  ...                  6.9  Micrograms/cubic meter (LC)         24 HOUR
# 587427  ...                 10.9  Micrograms/cubic meter (LC)         24 HOUR
# 587428  ...                  9.8  Micrograms/cubic meter (LC)         24 HOUR
# 587429  ...                  6.6  Micrograms/cubic meter (LC)         24 HOUR
# 587430  ...                 16.4  Micrograms/cubic meter (LC)         24 HOUR
# 587431  ...                  6.5  Micrograms/cubic meter (LC)         24 HOUR
# 587432  ...                 10.5  Micrograms/cubic meter (LC)         24 HOUR
# 587433  ...                 12.3  Micrograms/cubic meter (LC)         24 HOUR
# 587434  ...                  3.9  Micrograms/cubic meter (LC)         24 HOUR
# 587435  ...                  8.8  Micrograms/cubic meter (LC)         24 HOUR
# 587436  ...                 13.3  Micrograms/cubic meter (LC)         24 HOUR
# 587437  ...                    7  Micrograms/cubic meter (LC)         24 HOUR
# 587438  ...                 10.9  Micrograms/cubic meter (LC)         24 HOUR
# 587439  ...                 None                         None            None
# 587440  ...                 None                         None            None
#
#        Sample Frequency Detection Limit Measurement Uncertainty  \
# 0                                     5
# 1                                     5
# 2                                     5
# 3                                     5
# 4                                     5
# 5                                     5
# 6                                     5
# 7                                     5
# 8                                     5
# 9                                     5
# 10                                    5
# 11                                    5
# 12                                    5
# 13                                    5
# 14                                    5
# 15                                    5
# 16                                    5
# 17                                    5
# 18                                    5
# 19                                    5
# 20                                    5
# 21                                    5
# 22                                    5
# 23                                    5
# 24                                    5
# 25                                    5
# 26                                    5
# 27                                    5
# 28                                    5
# 29                                    5
# ...                 ...             ...                     ...
# 587411                                2
# 587412                                2
# 587413                                2
# 587414                                2
# 587415                                2
# 587416                                2
# 587417                                2
# 587418                                2
# 587419                                2
# 587420                                2
# 587421                                2
# 587422                                2
# 587423                                2
# 587424                                2
# 587425                                2
# 587426                                2
# 587427                                2
# 587428                                2
# 587429                                2
# 587430                                2
# 587431                                2
# 587432                                2
# 587433                                2
# 587434                                2
# 587435                                2
# 587436                                2
# 587437                                2
# 587438                                2
# 587439             None            None                    None
# 587440             None            None                    None
#
#        Qualifier Description Method Type  \
# 0                             Equivalent
# 1                             Equivalent
# 2                             Equivalent
# 3                             Equivalent
# 4                             Equivalent
# 5                             Equivalent
# 6                             Equivalent
# 7                             Equivalent
# 8                             Equivalent
# 9                             Equivalent
# 10                            Equivalent
# 11                            Equivalent
# 12                            Equivalent
# 13                            Equivalent
# 14                            Equivalent
# 15                            Equivalent
# 16                            Equivalent
# 17                            Equivalent
# 18                            Equivalent
# 19                            Equivalent
# 20                            Equivalent
# 21                            Equivalent
# 22                            Equivalent
# 23                            Equivalent
# 24                            Equivalent
# 25                            Equivalent
# 26                            Equivalent
# 27                            Equivalent
# 28                            Equivalent
# 29                            Equivalent
# ...                      ...         ...
# 587411                         Reference
# 587412                         Reference
# 587413                         Reference
# 587414                         Reference
# 587415                         Reference
# 587416                         Reference
# 587417                         Reference
# 587418        Wildfire-U. S.   Reference
# 587419                         Reference
# 587420                         Reference
# 587421                         Reference
# 587422                         Reference
# 587423                         Reference
# 587424                         Reference
# 587425                         Reference
# 587426        Wildfire-U. S.   Reference
# 587427        Wildfire-U. S.   Reference
# 587428        Wildfire-U. S.   Reference
# 587429        Wildfire-U. S.   Reference
# 587430                         Reference
# 587431                         Reference
# 587432        Wildfire-U. S.   Reference
# 587433                         Reference
# 587434                         Reference
# 587435                         Reference
# 587436        Wildfire-U. S.   Reference
# 587437                         Reference
# 587438        Wildfire-U. S.   Reference
# 587439                  None        None
# 587440                  None        None
#
#                                        Method Description   FIPS
# 0       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 1       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 2       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 3       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 4       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 5       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 6       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 7       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 8       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 9       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 10      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 11      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 12      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 13      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 14      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 15      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 16      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 17      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 18      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 19      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 20      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 21      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 22      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 23      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 24      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 25      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 26      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 27      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 28      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 29      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# ...                                                   ...    ...
# 587411  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587412  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587413  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587414  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587415  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587416  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587417  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587418  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587419  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587420  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587421  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587422  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587423  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587424  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587425  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587426  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587427  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587428  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587429  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587430  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587431  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587432  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587433  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587434  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587435  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587436  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587437  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587438  R & P Model 2025 PM-2.5 Sequential Air Sampler...  06113
# 587439                                               None    NaN
# 587440                                               None    NaN
#
# [587441 rows x 26 columns]

# %%
countyname = { "001": "Alameda", "003": "Apline", "005": "Amador", "007":"Butte", "009":"Calaveras", "011": "Colusa", "013":"Contra Costa", "015":"Del Norte", "017":"El Dorado", "019": "Fresno", "021": "Glenn", "023": "Humboldt", "025": "Imperial", "027": "Inyo", "029": "Kern", "031": "Kings", "033":"Lake", "035": "Lassen", "037": "Los Angeles", "039": "Madera", "041": "Marin", "043": "Mariposa", "045": "Mendicino", "047": "Merced", "049": "Modoc", "051": "Mono", "053": "Monterey", "055": "Napa", "057": "Nevada", "059": "Orange", "061": "Placer", "063": "Plumas", "065": "Riverside", "067": "Sacramento", "069": "San Benito", "071": "San Bernardino", "073": "San Diego", "075": "San Francisco", "077": "San Joaquin", "079": "San Luis Obispo", "081": "San Mateo", "083": "Santa Barbara", "085": "Santa Clara", "087": "Santa Cruz", "089": "Shasta", "091": "Sierra", "093": "Siskiyou", "095": "Solano", "097": "Sonoma", "099": "Stanislaus", "101": "Sutter", "103": "Tehama", "105": "Trinity", "107": "Tulare", "109": "Tuolumne", "111": "Ventura", "113": "Yolo", "115": "Yuba"}

df_trim = data_2016[['County Code','Date Local','24 Hour Local','Date GMT','Sample Measurement', "Sample Frequency",'Units of Measure','Sample Duration', "Latitude", "Longitude", "FIPS"]]
df_trim["County Names"] = df_trim["County Code"].map(countyname)
df_trim
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#        County Code  Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 0              001  2016-01-01         23:00  2016-01-02                 13
# 1              001  2016-01-01         23:00  2016-01-02                 18
# 2              001  2016-01-01         23:00  2016-01-02                 13
# 3              001  2016-01-01         23:00  2016-01-02                 13
# 4              001  2016-01-01         22:00  2016-01-02                 10
# 5              001  2016-01-01         22:00  2016-01-02                 10
# 6              001  2016-01-01         22:00  2016-01-02                 15
# 7              001  2016-01-01         22:00  2016-01-02                  9
# 8              001  2016-01-01         00:00  2016-01-01                  4
# 9              001  2016-01-01         00:00  2016-01-01                 11
# 10             001  2016-01-01         00:00  2016-01-01                 36
# 11             001  2016-01-01         00:00  2016-01-01                 17
# 12             001  2016-01-01         20:00  2016-01-02                 10
# 13             001  2016-01-01         20:00  2016-01-02                 17
# 14             001  2016-01-01         20:00  2016-01-02                 23
# 15             001  2016-01-01         20:00  2016-01-02                  7
# 16             001  2016-01-01         19:00  2016-01-02                  8
# 17             001  2016-01-01         19:00  2016-01-02                  5
# 18             001  2016-01-01         19:00  2016-01-02                 11
# 19             001  2016-01-01         19:00  2016-01-02                  4
# 20             001  2016-01-01         21:00  2016-01-02                  8
# 21             001  2016-01-01         21:00  2016-01-02                 10
# 22             001  2016-01-01         21:00  2016-01-02                 10
# 23             001  2016-01-01         21:00  2016-01-02                  9
# 24             001  2016-01-01         18:00  2016-01-02                  7
# 25             001  2016-01-01         18:00  2016-01-02                  5
# 26             001  2016-01-01         18:00  2016-01-02                 10
# 27             001  2016-01-01         18:00  2016-01-02                  2
# 28             001  2016-01-01         17:00  2016-01-02                  5
# 29             001  2016-01-01         17:00  2016-01-02                  6
# ...            ...         ...           ...         ...                ...
# 587411         113  2016-11-08         00:00  2016-11-08                  6
# 587412         113  2016-07-13         00:00  2016-07-13                6.8
# 587413         113  2016-12-08         00:00  2016-12-08                  1
# 587414         113  2016-12-26         00:00  2016-12-26                5.1
# 587415         113  2016-10-21         00:00  2016-10-21                9.1
# 587416         113  2016-10-03         00:00  2016-10-03                  4
# 587417         113  2016-07-17         00:00  2016-07-17                6.4
# 587418         113  2016-08-16         00:00  2016-08-16                5.6
# 587419         113  2016-11-02         00:00  2016-11-02                3.5
# 587420         113  2016-07-05         00:00  2016-07-05                  7
# 587421         113  2016-08-04         00:00  2016-08-04                9.5
# 587422         113  2016-12-02         00:00  2016-12-02                3.3
# 587423         113  2016-10-27         00:00  2016-10-27                3.8
# 587424         113  2016-12-20         00:00  2016-12-20               10.9
# 587425         113  2016-10-19         00:00  2016-10-19                3.2
# 587426         113  2016-09-21         00:00  2016-09-21                6.9
# 587427         113  2016-09-27         00:00  2016-09-27               10.9
# 587428         113  2016-09-15         00:00  2016-09-15                9.8
# 587429         113  2016-08-28         00:00  2016-08-28                6.6
# 587430         113  2016-12-14         00:00  2016-12-14               16.4
# 587431         113  2016-07-23         00:00  2016-07-23                6.5
# 587432         113  2016-09-09         00:00  2016-09-09               10.5
# 587433         113  2016-11-14         00:00  2016-11-14               12.3
# 587434         113  2016-11-20         00:00  2016-11-20                3.9
# 587435         113  2016-08-10         00:00  2016-08-10                8.8
# 587436         113  2016-10-09         00:00  2016-10-09               13.3
# 587437         113  2016-11-26         00:00  2016-11-26                  7
# 587438         113  2016-09-03         00:00  2016-09-03               10.9
# 587439        None        None          None        None               None
# 587440        None        None          None        None               None
#
#        Sample Frequency             Units of Measure Sample Duration  \
# 0                        Micrograms/cubic meter (LC)          1 HOUR
# 1                        Micrograms/cubic meter (LC)          1 HOUR
# 2                        Micrograms/cubic meter (LC)          1 HOUR
# 3                        Micrograms/cubic meter (LC)          1 HOUR
# 4                        Micrograms/cubic meter (LC)          1 HOUR
# 5                        Micrograms/cubic meter (LC)          1 HOUR
# 6                        Micrograms/cubic meter (LC)          1 HOUR
# 7                        Micrograms/cubic meter (LC)          1 HOUR
# 8                        Micrograms/cubic meter (LC)          1 HOUR
# 9                        Micrograms/cubic meter (LC)          1 HOUR
# 10                       Micrograms/cubic meter (LC)          1 HOUR
# 11                       Micrograms/cubic meter (LC)          1 HOUR
# 12                       Micrograms/cubic meter (LC)          1 HOUR
# 13                       Micrograms/cubic meter (LC)          1 HOUR
# 14                       Micrograms/cubic meter (LC)          1 HOUR
# 15                       Micrograms/cubic meter (LC)          1 HOUR
# 16                       Micrograms/cubic meter (LC)          1 HOUR
# 17                       Micrograms/cubic meter (LC)          1 HOUR
# 18                       Micrograms/cubic meter (LC)          1 HOUR
# 19                       Micrograms/cubic meter (LC)          1 HOUR
# 20                       Micrograms/cubic meter (LC)          1 HOUR
# 21                       Micrograms/cubic meter (LC)          1 HOUR
# 22                       Micrograms/cubic meter (LC)          1 HOUR
# 23                       Micrograms/cubic meter (LC)          1 HOUR
# 24                       Micrograms/cubic meter (LC)          1 HOUR
# 25                       Micrograms/cubic meter (LC)          1 HOUR
# 26                       Micrograms/cubic meter (LC)          1 HOUR
# 27                       Micrograms/cubic meter (LC)          1 HOUR
# 28                       Micrograms/cubic meter (LC)          1 HOUR
# 29                       Micrograms/cubic meter (LC)          1 HOUR
# ...                 ...                          ...             ...
# 587411                   Micrograms/cubic meter (LC)         24 HOUR
# 587412                   Micrograms/cubic meter (LC)         24 HOUR
# 587413                   Micrograms/cubic meter (LC)         24 HOUR
# 587414                   Micrograms/cubic meter (LC)         24 HOUR
# 587415                   Micrograms/cubic meter (LC)         24 HOUR
# 587416                   Micrograms/cubic meter (LC)         24 HOUR
# 587417                   Micrograms/cubic meter (LC)         24 HOUR
# 587418                   Micrograms/cubic meter (LC)         24 HOUR
# 587419                   Micrograms/cubic meter (LC)         24 HOUR
# 587420                   Micrograms/cubic meter (LC)         24 HOUR
# 587421                   Micrograms/cubic meter (LC)         24 HOUR
# 587422                   Micrograms/cubic meter (LC)         24 HOUR
# 587423                   Micrograms/cubic meter (LC)         24 HOUR
# 587424                   Micrograms/cubic meter (LC)         24 HOUR
# 587425                   Micrograms/cubic meter (LC)         24 HOUR
# 587426                   Micrograms/cubic meter (LC)         24 HOUR
# 587427                   Micrograms/cubic meter (LC)         24 HOUR
# 587428                   Micrograms/cubic meter (LC)         24 HOUR
# 587429                   Micrograms/cubic meter (LC)         24 HOUR
# 587430                   Micrograms/cubic meter (LC)         24 HOUR
# 587431                   Micrograms/cubic meter (LC)         24 HOUR
# 587432                   Micrograms/cubic meter (LC)         24 HOUR
# 587433                   Micrograms/cubic meter (LC)         24 HOUR
# 587434                   Micrograms/cubic meter (LC)         24 HOUR
# 587435                   Micrograms/cubic meter (LC)         24 HOUR
# 587436                   Micrograms/cubic meter (LC)         24 HOUR
# 587437                   Micrograms/cubic meter (LC)         24 HOUR
# 587438                   Micrograms/cubic meter (LC)         24 HOUR
# 587439             None                         None            None
# 587440             None                         None            None
#
#            Latitude    Longitude   FIPS County Names
# 0         37.793624  -122.263376  06001      Alameda
# 1         37.814781  -122.282347  06001      Alameda
# 2         37.687526  -121.784217  06001      Alameda
# 3         37.743065  -122.169935  06001      Alameda
# 4         37.793624  -122.263376  06001      Alameda
# 5         37.814781  -122.282347  06001      Alameda
# 6         37.687526  -121.784217  06001      Alameda
# 7         37.743065  -122.169935  06001      Alameda
# 8         37.793624  -122.263376  06001      Alameda
# 9         37.814781  -122.282347  06001      Alameda
# 10        37.687526  -121.784217  06001      Alameda
# 11        37.743065  -122.169935  06001      Alameda
# 12        37.793624  -122.263376  06001      Alameda
# 13        37.814781  -122.282347  06001      Alameda
# 14        37.687526  -121.784217  06001      Alameda
# 15        37.743065  -122.169935  06001      Alameda
# 16        37.793624  -122.263376  06001      Alameda
# 17        37.814781  -122.282347  06001      Alameda
# 18        37.687526  -121.784217  06001      Alameda
# 19        37.743065  -122.169935  06001      Alameda
# 20        37.793624  -122.263376  06001      Alameda
# 21        37.814781  -122.282347  06001      Alameda
# 22        37.687526  -121.784217  06001      Alameda
# 23        37.743065  -122.169935  06001      Alameda
# 24        37.793624  -122.263376  06001      Alameda
# 25        37.814781  -122.282347  06001      Alameda
# 26        37.687526  -121.784217  06001      Alameda
# 27        37.743065  -122.169935  06001      Alameda
# 28        37.793624  -122.263376  06001      Alameda
# 29        37.814781  -122.282347  06001      Alameda
# ...             ...          ...    ...          ...
# 587411     38.66121   -121.73269  06113         Yolo
# 587412     38.66121   -121.73269  06113         Yolo
# 587413     38.66121   -121.73269  06113         Yolo
# 587414     38.66121   -121.73269  06113         Yolo
# 587415     38.66121   -121.73269  06113         Yolo
# 587416     38.66121   -121.73269  06113         Yolo
# 587417     38.66121   -121.73269  06113         Yolo
# 587418     38.66121   -121.73269  06113         Yolo
# 587419     38.66121   -121.73269  06113         Yolo
# 587420     38.66121   -121.73269  06113         Yolo
# 587421     38.66121   -121.73269  06113         Yolo
# 587422     38.66121   -121.73269  06113         Yolo
# 587423     38.66121   -121.73269  06113         Yolo
# 587424     38.66121   -121.73269  06113         Yolo
# 587425     38.66121   -121.73269  06113         Yolo
# 587426     38.66121   -121.73269  06113         Yolo
# 587427     38.66121   -121.73269  06113         Yolo
# 587428     38.66121   -121.73269  06113         Yolo
# 587429     38.66121   -121.73269  06113         Yolo
# 587430     38.66121   -121.73269  06113         Yolo
# 587431     38.66121   -121.73269  06113         Yolo
# 587432     38.66121   -121.73269  06113         Yolo
# 587433     38.66121   -121.73269  06113         Yolo
# 587434     38.66121   -121.73269  06113         Yolo
# 587435     38.66121   -121.73269  06113         Yolo
# 587436     38.66121   -121.73269  06113         Yolo
# 587437     38.66121   -121.73269  06113         Yolo
# 587438     38.66121   -121.73269  06113         Yolo
# 587439  END OF FILE         None    NaN          NaN
# 587440  END OF FILE         None    NaN          NaN
#
# [587441 rows x 12 columns]

# %%
#Create 2 dataframes to hold records for sampling done by 24 hour duration and 1 hour duration
hour1_df = df_trim.loc[(df_trim["Sample Duration"]== "1 HOUR")]
hour24_df = df_trim.loc[(df_trim["Sample Duration"]== "24 HOUR")]

#See which sampling duration has more unique counties
hour1_df["County Names"].nunique()
hour24_df["County Names"].nunique()
# Out:
# 28

# %%
#Convert 'Date Local' column to datetime to extract month #
hour1_df['Date Local'] = pd.to_datetime(hour1_df['Date Local'])

#Creating column for Month # for 1hour sample duration df
hour1_df['Month'] = pd.DatetimeIndex(hour1_df['Date Local']).month
hour1_df["Month"].fillna(0)
hour1_df["Month"].astype(float)
hour1_df.fillna(0)
hour1_df["County Names"].dtype

#Convert 'Date Local' column to datetime to extract month #
hour24_df['Date Local'] = pd.to_datetime(hour24_df['Date Local'])

#Creating column for Month # for 24 hour sample duration df
hour24_df['Month'] = pd.DatetimeIndex(hour24_df['Date Local']).month
hour24_df["Month"].fillna(0)
hour24_df["Month"].astype(float)
hour24_df.fillna(0)
hour24_df.head()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#       County Code Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 37694         007 2016-01-01         00:00  2016-01-01               16.3
# 37695         007 2016-01-18         00:00  2016-01-18                  1
# 37696         007 2016-02-15         00:00  2016-02-15                2.3
# 37697         007 2016-07-04         00:00  2016-07-04               11.4
# 37698         007 2016-09-05         00:00  2016-09-05                9.9
#
#       Sample Frequency             Units of Measure Sample Duration  Latitude  \
# 37694                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 37695                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 37696                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 37697                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 37698                   Micrograms/cubic meter (LC)         24 HOUR  39.76168
#
#         Longitude   FIPS County Names  Month
# 37694  -121.84047  06007        Butte      1
# 37695  -121.84047  06007        Butte      1
# 37696  -121.84047  06007        Butte      2
# 37697  -121.84047  06007        Butte      7
# 37698  -121.84047  06007        Butte      9

# %%
#extract only relevant columns and create a groupby df (for 24 hour sample duration)
mday_df = hour24_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mday_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuff24 = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuff24
mday_df["PM2.5 Values 2016"] = tuff24
finalday = mday_df
finalday.drop(columns="Sample Measurement")
#finalday
finalday.to_csv("2016CA24hrPM2.5.csv")
finalday.head()
# Out:
#       County Names  Month Sample Measurement  Latitude   Longitude   FIPS  \
# 37694        Butte      1               16.3  39.76168  -121.84047  06007
# 37695        Butte      1                  1  39.76168  -121.84047  06007
# 37696        Butte      2                2.3  39.76168  -121.84047  06007
# 37697        Butte      7               11.4  39.76168  -121.84047  06007
# 37698        Butte      9                9.9  39.76168  -121.84047  06007
#
#        PM2.5 Values 2016
# 37694               16.3
# 37695                1.0
# 37696                2.3
# 37697               11.4
# 37698                9.9

# %%
#groupby to graph results
county_date24hr = pd.DataFrame(finalday.groupby(['County Names', 'Month']).mean())
county_date24hr.head()
# Out:
#                     PM2.5 Values 2016
# County Names Month
# Butte        1               8.246667
#              2               7.450000
#              3               3.521429
#              4               4.320000
#              5               4.469231

# %%
county_date24hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2016 (24hr Sampling Duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2016 PM2.5 AVG (24hr Sampling).png", bbox_inches='tight')
plt.figure()

# %%
# extract only relevant columns and create a groupby df
mhour_df = hour1_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mhour_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mhour_df["Sample Measurement"], errors='coerce')
tuffhour_df
mhour_df["PM2.5 Values 2016"] = tuffhour_df
finalhour = mhour_df
finalhour.drop(columns="Sample Measurement")

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuffhour_df
mday_df["PM2.5 Values 2016"] = tuffhour_df
finalhour = mday_df
finalhour.drop(columns="Sample Measurement")

finalhour.to_csv("2016CA1hrPM2.5.csv")

# %%
#groupby to graph results
county_1hr = pd.DataFrame(finalhour.groupby(['County Names', 'Month']).mean())
county_1hr.head()
# Out:
#                     PM2.5 Values 2016
# County Names Month
# Butte        1               8.246667
#              2               7.450000
#              3               3.521429
#              4               4.320000
#              5               4.469231

# %%
county_1hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2016 (1Hr Sampling duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2016 PM2.5 AVG (1hrSampling).png", bbox_inches='tight')
plt.figure()

# %%
#Find Max for 24hr sampling group
max_pm25 = county_date24hr['PM2.5 Values 2016'].max()
max_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2016'] == max_pm25,:]
max_county24hr

#Find Max for 1hr sampling group
max_pm25 = county_1hr['PM2.5 Values 2016'].max()
max_1hr = county_1hr.loc[county_1hr['PM2.5 Values 2016'] == max_pm25,:]
max_1hr
# Out:
#                     PM2.5 Values 2016
# County Names Month
# Tulare       11             26.890909

# %%
#Find Min
min_pm25 = county_date24hr['PM2.5 Values 2016'].min()
min_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2016'] == min_pm25,:]
min_county24hr

#min_pm25 = county_1hr['PM2.5 Values 2016'].min()
#min_county1hr = county_1hr.loc[county_1hr['PM2.5 Values 2016'] == min_pm25,:]
#min_county1hr
# Out:
#                     PM2.5 Values 2016
# County Names Month
# Lake         1                   1.55

# %%
# create a df with only the Max & Min, and SD/LA for ref counties
minmax_df = finalday.loc[(finalday['County Names']=='Tulare') | (finalday['County Names']=='Lake') | (finalday['County Names']=='San Diego') | (finalday['County Names']=='Los Angeles'),:]
minmax_df.head()
# Out:
#        County Names  Month Sample Measurement Latitude   Longitude   FIPS  \
# 158953         Lake      1                1.5  39.0327  -122.92229  06033
# 158954         Lake      6                3.4  39.0327  -122.92229  06033
# 158955         Lake     11                2.4  39.0327  -122.92229  06033
# 158956         Lake      4                2.5  39.0327  -122.92229  06033
# 158957         Lake     10                2.8  39.0327  -122.92229  06033
#
#         PM2.5 Values 2016
# 158953                1.5
# 158954                3.4
# 158955                2.4
# 158956                2.5
# 158957                2.8

# %%
mm_mean_df = minmax_df.loc[:, ['County Names', 'Month', 'PM2.5 Values 2016']]
mm_df = pd.DataFrame(mm_mean_df.groupby(['County Names', 'Month']).mean())
mm_df.head()
# Out:
#                     PM2.5 Values 2016
# County Names Month
# Lake         1               1.550000
#              2               2.375000
#              3               2.166667
#              4               2.440000
#              5               3.440000

# %%
mm_df.unstack(0).plot(figsize = (10,10))
plt.title("Graph of PM2.5 Max & Min in CA + San Diego & Los Angeles 2016")
plt.xlabel('Month')
plt.ylabel('PM2.5 Mean/Month')
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("2016_CA_MaxMin_SDLA.png", bbox_inches='tight') 
plt.figure()

# %%
county_final = pd.DataFrame(finalday.groupby(['FIPS']).mean())
county_sum = county_final.drop(columns=["Month"], )
#county_sum.to_csv('2016_CA_PM25_Mean.csv')
county_sum
county_sum.sort_values(by=["PM2.5 Values 2016"], ascending=False)
#county_sum.to_csv('2016_CA_PM25_Sum.csv')
# Out:
#        PM2.5 Values 2016
# FIPS
# 06107          14.706780
# 06031          14.583193
# 06029          14.239331
# 06071          13.021145
# 06019          12.535623
# 06025          11.664553
# 06065          11.423962
# 06047          11.255172
# 06037          10.778960
# 06039          10.332143
# 06063          10.085714
# 06059           8.874678
# 06073           8.824295
# 06099           8.645161
# 06067           8.253974
# 06101           8.118519
# 06085           8.045263
# 06007           7.600915
# 06061           7.170455
# 06113           6.316667
# 06011           6.281667
# 06053           6.168421
# 06057           5.712717
# 06089           5.050000
# 06027           4.947826
# 06093           4.936207
# 06023           4.763404
# 06033           2.985246

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
plotly.tools.set_credentials_file(username=Plotuser, api_key=Plotkey)

# %%
#create lists of values to graph in plotly
values = county_sum["PM2.5 Values 2016"].tolist()
fips = county_sum.index.values
print(values)
# Out:
# [7.600914634146346, 6.28166666666667, 12.53562300319488, 4.763404255319148, 11.66455284552845, 4.947826086956522, 14.239331210191084, 14.583193277310928, 2.985245901639343, 10.77896015549078, 10.332142857142859, 11.255172413793101, 6.1684210526315795, 5.71271676300578, 8.87467811158799, 7.170454545454544, 10.085714285714296, 11.423961937716275, 8.253973509933783, 13.02114467408586, 8.824295302013402, 8.045263157894736, 5.05, 4.936206896551723, 8.645161290322582, 8.118518518518524, 14.706779661016943, 6.316666666666666]

# %%
#send FIPS codes and corresponding PM2.5 values to plotly to graph
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['CA'],
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='PM2.5 by County', title='California PM2.5 2016 By County'
)
py.iplot(fig, filename='dayxCA_PM2.5 2016')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tonyphelps/14.embed" height="450px" width="900px"></iframe>
