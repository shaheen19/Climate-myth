# %%
#import dependencies
import pandas as pd
import requests as req
#create separate file with individual log in credentials to be imported

from config import (user_id_aqs, password_aqs, Plotkey, Plotuser)
import csv
import matplotlib.pyplot as plt

# %%
codes = []
countycodes = ["{0:03}".format(i) for i in range(117) if i%2 > 0]

for countycode in countycodes:
    codes.append(countycode)
#codes

# %%
#API REQUEST
URL_new = f"https://aqs.epa.gov/api/rawData?user={user_id_aqs}&pw={password_aqs}&format=DMCSV&param=88101&bdate=20130101&edate=20131231&state=06&county="
list_2013 = []

for x in codes:
    url_loop = URL_new + x
    print(f"fetching county code {x}")
    response1 = req.get(url_loop)
    print(f"Got API Response for {x}")
    wrapper = csv.reader(response1.text.strip().split('\n'))
    header = next(wrapper)
    for record in wrapper:
        list_2013.append(record)
    print(f"Appended List with {x} API Response")
# Out:
# fetching county code 001
# Got API Response for 001
# Appended List with 001 API Response
# fetching county code 003
# Got API Response for 003
# Appended List with 003 API Response
# fetching county code 005
# Got API Response for 005
# Appended List with 005 API Response
# fetching county code 007
# Got API Response for 007
# Appended List with 007 API Response
# fetching county code 009
# Got API Response for 009
# Appended List with 009 API Response
# fetching county code 011
# Got API Response for 011
# Appended List with 011 API Response
# fetching county code 013
# Got API Response for 013
# Appended List with 013 API Response
# fetching county code 015
# Got API Response for 015
# Appended List with 015 API Response
# fetching county code 017
# Got API Response for 017
# Appended List with 017 API Response
# fetching county code 019
# Got API Response for 019
# Appended List with 019 API Response
# fetching county code 021
# Got API Response for 021
# Appended List with 021 API Response
# fetching county code 023
# Got API Response for 023
# Appended List with 023 API Response
# fetching county code 025
# Got API Response for 025
# Appended List with 025 API Response
# fetching county code 027
# Got API Response for 027
# Appended List with 027 API Response
# fetching county code 029
# Got API Response for 029
# Appended List with 029 API Response
# fetching county code 031
# Got API Response for 031
# Appended List with 031 API Response
# fetching county code 033
# Got API Response for 033
# Appended List with 033 API Response
# fetching county code 035
# Got API Response for 035
# Appended List with 035 API Response
# fetching county code 037
# Got API Response for 037
# Appended List with 037 API Response
# fetching county code 039
# Got API Response for 039
# Appended List with 039 API Response
# fetching county code 041
# Got API Response for 041
# Appended List with 041 API Response
# fetching county code 043
# Got API Response for 043
# Appended List with 043 API Response
# fetching county code 045
# Got API Response for 045
# Appended List with 045 API Response
# fetching county code 047
# Got API Response for 047
# Appended List with 047 API Response
# fetching county code 049
# Got API Response for 049
# Appended List with 049 API Response
# fetching county code 051
# Got API Response for 051
# Appended List with 051 API Response
# fetching county code 053
# Got API Response for 053
# Appended List with 053 API Response
# fetching county code 055
# Got API Response for 055
# Appended List with 055 API Response
# fetching county code 057
# Got API Response for 057
# Appended List with 057 API Response
# fetching county code 059
# Got API Response for 059
# Appended List with 059 API Response
# fetching county code 061
# Got API Response for 061
# Appended List with 061 API Response
# fetching county code 063
# Got API Response for 063
# Appended List with 063 API Response
# fetching county code 065
# Got API Response for 065
# Appended List with 065 API Response
# fetching county code 067
# Got API Response for 067
# Appended List with 067 API Response
# fetching county code 069
# Got API Response for 069
# Appended List with 069 API Response
# fetching county code 071
# Got API Response for 071
# Appended List with 071 API Response
# fetching county code 073
# Got API Response for 073
# Appended List with 073 API Response
# fetching county code 075
# Got API Response for 075
# Appended List with 075 API Response
# fetching county code 077
# Got API Response for 077
# Appended List with 077 API Response
# fetching county code 079
# Got API Response for 079
# Appended List with 079 API Response
# fetching county code 081
# Got API Response for 081
# Appended List with 081 API Response
# fetching county code 083
# Got API Response for 083
# Appended List with 083 API Response
# fetching county code 085
# Got API Response for 085
# Appended List with 085 API Response
# fetching county code 087
# Got API Response for 087
# Appended List with 087 API Response
# fetching county code 089
# Got API Response for 089
# Appended List with 089 API Response
# fetching county code 091
# Got API Response for 091
# Appended List with 091 API Response
# fetching county code 093
# Got API Response for 093
# Appended List with 093 API Response
# fetching county code 095
# Got API Response for 095
# Appended List with 095 API Response
# fetching county code 097
# Got API Response for 097
# Appended List with 097 API Response
# fetching county code 099
# Got API Response for 099
# Appended List with 099 API Response
# fetching county code 101
# Got API Response for 101
# Appended List with 101 API Response
# fetching county code 103
# Got API Response for 103
# Appended List with 103 API Response
# fetching county code 105
# Got API Response for 105
# Appended List with 105 API Response
# fetching county code 107
# Got API Response for 107
# Appended List with 107 API Response
# fetching county code 109
# Got API Response for 109
# Appended List with 109 API Response
# fetching county code 111
# Got API Response for 111
# Appended List with 111 API Response
# fetching county code 113
# Got API Response for 113
# Appended List with 113 API Response
# fetching county code 115
# Got API Response for 115
# Appended List with 115 API Response

# %%
#Create DF and append FIPS column with county code and 06 (state code) to create FIPS code
data_2013 = pd.DataFrame(list_2013, columns = header)
data_2013["FIPS"] = "06" + data_2013["County Code"]
data_2013
# Out:
#            Latitude    Longitude  Datum Horizontal Accuracy State Code  \
# 0         37.814781  -122.282347  WGS84                   6         06
# 1         37.687526  -121.784217  WGS84           109305.56         06
# 2         37.743065  -122.169935  WGS84                   6         06
# 3         37.814781  -122.282347  WGS84                   6         06
# 4         37.687526  -121.784217  WGS84           109305.56         06
# 5         37.743065  -122.169935  WGS84                   6         06
# 6         37.814781  -122.282347  WGS84                   6         06
# 7         37.687526  -121.784217  WGS84           109305.56         06
# 8         37.743065  -122.169935  WGS84                   6         06
# 9         37.814781  -122.282347  WGS84                   6         06
# 10        37.687526  -121.784217  WGS84           109305.56         06
# 11        37.743065  -122.169935  WGS84                   6         06
# 12        37.814781  -122.282347  WGS84                   6         06
# 13        37.687526  -121.784217  WGS84           109305.56         06
# 14        37.743065  -122.169935  WGS84                   6         06
# 15        37.814781  -122.282347  WGS84                   6         06
# 16        37.687526  -121.784217  WGS84           109305.56         06
# 17        37.743065  -122.169935  WGS84                   6         06
# 18        37.814781  -122.282347  WGS84                   6         06
# 19        37.687526  -121.784217  WGS84           109305.56         06
# 20        37.743065  -122.169935  WGS84                   6         06
# 21        37.814781  -122.282347  WGS84                   6         06
# 22        37.687526  -121.784217  WGS84           109305.56         06
# 23        37.743065  -122.169935  WGS84                   6         06
# 24        37.814781  -122.282347  WGS84                   6         06
# 25        37.687526  -121.784217  WGS84           109305.56         06
# 26        37.743065  -122.169935  WGS84                   6         06
# 27        37.814781  -122.282347  WGS84                   6         06
# 28        37.687526  -121.784217  WGS84           109305.56         06
# 29        37.743065  -122.169935  WGS84                   6         06
# ...             ...          ...    ...                 ...        ...
# 473731     38.66121   -121.73269  WGS84              151.82         06
# 473732     38.66121   -121.73269  WGS84              151.82         06
# 473733     38.66121   -121.73269  WGS84              151.82         06
# 473734     38.66121   -121.73269  WGS84              151.82         06
# 473735     38.66121   -121.73269  WGS84              151.82         06
# 473736     38.66121   -121.73269  WGS84              151.82         06
# 473737     38.66121   -121.73269  WGS84              151.82         06
# 473738     38.66121   -121.73269  WGS84              151.82         06
# 473739     38.66121   -121.73269  WGS84              151.82         06
# 473740     38.66121   -121.73269  WGS84              151.82         06
# 473741     38.66121   -121.73269  WGS84              151.82         06
# 473742     38.66121   -121.73269  WGS84              151.82         06
# 473743     38.66121   -121.73269  WGS84              151.82         06
# 473744     38.66121   -121.73269  WGS84              151.82         06
# 473745     38.66121   -121.73269  WGS84              151.82         06
# 473746     38.66121   -121.73269  WGS84              151.82         06
# 473747     38.66121   -121.73269  WGS84              151.82         06
# 473748     38.66121   -121.73269  WGS84              151.82         06
# 473749     38.66121   -121.73269  WGS84              151.82         06
# 473750     38.66121   -121.73269  WGS84              151.82         06
# 473751     38.66121   -121.73269  WGS84              151.82         06
# 473752     38.66121   -121.73269  WGS84              151.82         06
# 473753     38.66121   -121.73269  WGS84              151.82         06
# 473754     38.66121   -121.73269  WGS84              151.82         06
# 473755     38.66121   -121.73269  WGS84              151.82         06
# 473756     38.66121   -121.73269  WGS84              151.82         06
# 473757     38.66121   -121.73269  WGS84              151.82         06
# 473758     38.66121   -121.73269  WGS84              151.82         06
# 473759  END OF FILE         None   None                None       None
# 473760  END OF FILE         None   None                None       None
#
#        County Code Site Num Parameter Code   POC        AQS Parameter Desc  \
# 0              001     0011          88101     3  PM2.5 - Local Conditions
# 1              001     0007          88101     3  PM2.5 - Local Conditions
# 2              001     0009          88101     3  PM2.5 - Local Conditions
# 3              001     0011          88101     3  PM2.5 - Local Conditions
# 4              001     0007          88101     3  PM2.5 - Local Conditions
# 5              001     0009          88101     3  PM2.5 - Local Conditions
# 6              001     0011          88101     3  PM2.5 - Local Conditions
# 7              001     0007          88101     3  PM2.5 - Local Conditions
# 8              001     0009          88101     3  PM2.5 - Local Conditions
# 9              001     0011          88101     3  PM2.5 - Local Conditions
# 10             001     0007          88101     3  PM2.5 - Local Conditions
# 11             001     0009          88101     3  PM2.5 - Local Conditions
# 12             001     0011          88101     3  PM2.5 - Local Conditions
# 13             001     0007          88101     3  PM2.5 - Local Conditions
# 14             001     0009          88101     3  PM2.5 - Local Conditions
# 15             001     0011          88101     3  PM2.5 - Local Conditions
# 16             001     0007          88101     3  PM2.5 - Local Conditions
# 17             001     0009          88101     3  PM2.5 - Local Conditions
# 18             001     0011          88101     3  PM2.5 - Local Conditions
# 19             001     0007          88101     3  PM2.5 - Local Conditions
# 20             001     0009          88101     3  PM2.5 - Local Conditions
# 21             001     0011          88101     3  PM2.5 - Local Conditions
# 22             001     0007          88101     3  PM2.5 - Local Conditions
# 23             001     0009          88101     3  PM2.5 - Local Conditions
# 24             001     0011          88101     3  PM2.5 - Local Conditions
# 25             001     0007          88101     3  PM2.5 - Local Conditions
# 26             001     0009          88101     3  PM2.5 - Local Conditions
# 27             001     0011          88101     3  PM2.5 - Local Conditions
# 28             001     0007          88101     3  PM2.5 - Local Conditions
# 29             001     0009          88101     3  PM2.5 - Local Conditions
# ...            ...      ...            ...   ...                       ...
# 473731         113     1003          88101     1  PM2.5 - Local Conditions
# 473732         113     1003          88101     1  PM2.5 - Local Conditions
# 473733         113     1003          88101     1  PM2.5 - Local Conditions
# 473734         113     1003          88101     1  PM2.5 - Local Conditions
# 473735         113     1003          88101     1  PM2.5 - Local Conditions
# 473736         113     1003          88101     1  PM2.5 - Local Conditions
# 473737         113     1003          88101     1  PM2.5 - Local Conditions
# 473738         113     1003          88101     1  PM2.5 - Local Conditions
# 473739         113     1003          88101     1  PM2.5 - Local Conditions
# 473740         113     1003          88101     1  PM2.5 - Local Conditions
# 473741         113     1003          88101     1  PM2.5 - Local Conditions
# 473742         113     1003          88101     1  PM2.5 - Local Conditions
# 473743         113     1003          88101     1  PM2.5 - Local Conditions
# 473744         113     1003          88101     1  PM2.5 - Local Conditions
# 473745         113     1003          88101     1  PM2.5 - Local Conditions
# 473746         113     1003          88101     1  PM2.5 - Local Conditions
# 473747         113     1003          88101     1  PM2.5 - Local Conditions
# 473748         113     1003          88101     1  PM2.5 - Local Conditions
# 473749         113     1003          88101     1  PM2.5 - Local Conditions
# 473750         113     1003          88101     1  PM2.5 - Local Conditions
# 473751         113     1003          88101     1  PM2.5 - Local Conditions
# 473752         113     1003          88101     1  PM2.5 - Local Conditions
# 473753         113     1003          88101     1  PM2.5 - Local Conditions
# 473754         113     1003          88101     1  PM2.5 - Local Conditions
# 473755         113     1003          88101     1  PM2.5 - Local Conditions
# 473756         113     1003          88101     1  PM2.5 - Local Conditions
# 473757         113     1003          88101     1  PM2.5 - Local Conditions
# 473758         113     1003          88101     1  PM2.5 - Local Conditions
# 473759        None     None           None  None                      None
# 473760        None     None           None  None                      None
#
#         ...   Sample Measurement             Units of Measure Sample Duration  \
# 0       ...                    6  Micrograms/cubic meter (LC)          1 HOUR
# 1       ...                    4  Micrograms/cubic meter (LC)          1 HOUR
# 2       ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 3       ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 4       ...                    4  Micrograms/cubic meter (LC)          1 HOUR
# 5       ...                    4  Micrograms/cubic meter (LC)          1 HOUR
# 6       ...                    9  Micrograms/cubic meter (LC)          1 HOUR
# 7       ...                   13  Micrograms/cubic meter (LC)          1 HOUR
# 8       ...                    9  Micrograms/cubic meter (LC)          1 HOUR
# 9       ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 10      ...                    3  Micrograms/cubic meter (LC)          1 HOUR
# 11      ...                    4  Micrograms/cubic meter (LC)          1 HOUR
# 12      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 13      ...                    2  Micrograms/cubic meter (LC)          1 HOUR
# 14      ...                    3  Micrograms/cubic meter (LC)          1 HOUR
# 15      ...                    8  Micrograms/cubic meter (LC)          1 HOUR
# 16      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 17      ...                    1  Micrograms/cubic meter (LC)          1 HOUR
# 18      ...                    6  Micrograms/cubic meter (LC)          1 HOUR
# 19      ...                    2  Micrograms/cubic meter (LC)          1 HOUR
# 20      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 21      ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 22      ...                    0  Micrograms/cubic meter (LC)          1 HOUR
# 23      ...                    9  Micrograms/cubic meter (LC)          1 HOUR
# 24      ...                    8  Micrograms/cubic meter (LC)          1 HOUR
# 25      ...                    5  Micrograms/cubic meter (LC)          1 HOUR
# 26      ...                    6  Micrograms/cubic meter (LC)          1 HOUR
# 27      ...                    7  Micrograms/cubic meter (LC)          1 HOUR
# 28      ...                    6  Micrograms/cubic meter (LC)          1 HOUR
# 29      ...                    6  Micrograms/cubic meter (LC)          1 HOUR
# ...     ...                  ...                          ...             ...
# 473731  ...                  2.5  Micrograms/cubic meter (LC)         24 HOUR
# 473732  ...                  5.9  Micrograms/cubic meter (LC)         24 HOUR
# 473733  ...                  9.2  Micrograms/cubic meter (LC)         24 HOUR
# 473734  ...                 14.5  Micrograms/cubic meter (LC)         24 HOUR
# 473735  ...                    3  Micrograms/cubic meter (LC)         24 HOUR
# 473736  ...                  7.9  Micrograms/cubic meter (LC)         24 HOUR
# 473737  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 473738  ...                  2.5  Micrograms/cubic meter (LC)         24 HOUR
# 473739  ...                  2.7  Micrograms/cubic meter (LC)         24 HOUR
# 473740  ...                  7.3  Micrograms/cubic meter (LC)         24 HOUR
# 473741  ...                  3.4  Micrograms/cubic meter (LC)         24 HOUR
# 473742  ...                  6.9  Micrograms/cubic meter (LC)         24 HOUR
# 473743  ...                  3.5  Micrograms/cubic meter (LC)         24 HOUR
# 473744  ...                  2.8  Micrograms/cubic meter (LC)         24 HOUR
# 473745  ...                  2.8  Micrograms/cubic meter (LC)         24 HOUR
# 473746  ...                  5.2  Micrograms/cubic meter (LC)         24 HOUR
# 473747  ...                  4.3  Micrograms/cubic meter (LC)         24 HOUR
# 473748  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 473749  ...                  4.7  Micrograms/cubic meter (LC)         24 HOUR
# 473750  ...                    4  Micrograms/cubic meter (LC)         24 HOUR
# 473751  ...                  6.2  Micrograms/cubic meter (LC)         24 HOUR
# 473752  ...                  3.5  Micrograms/cubic meter (LC)         24 HOUR
# 473753  ...                  3.3  Micrograms/cubic meter (LC)         24 HOUR
# 473754  ...                 10.7  Micrograms/cubic meter (LC)         24 HOUR
# 473755  ...                  9.1  Micrograms/cubic meter (LC)         24 HOUR
# 473756  ...                  3.2  Micrograms/cubic meter (LC)         24 HOUR
# 473757  ...                   22  Micrograms/cubic meter (LC)         24 HOUR
# 473758  ...                 10.5  Micrograms/cubic meter (LC)         24 HOUR
# 473759  ...                 None                         None            None
# 473760  ...                 None                         None            None
#
#        Sample Frequency Detection Limit Measurement Uncertainty  \
# 0                                     5
# 1                                     5
# 2                                     5
# 3                                     5
# 4                                     5
# 5                                     5
# 6                                     5
# 7                                     5
# 8                                     5
# 9                                     5
# 10                                    5
# 11                                    5
# 12                                    5
# 13                                    5
# 14                                    5
# 15                                    5
# 16                                    5
# 17                                    5
# 18                                    5
# 19                                    5
# 20                                    5
# 21                                    5
# 22                                    5
# 23                                    5
# 24                                    5
# 25                                    5
# 26                                    5
# 27                                    5
# 28                                    5
# 29                                    5
# ...                 ...             ...                     ...
# 473731                                2
# 473732                                2
# 473733                                2
# 473734    EVERY 6TH DAY               2
# 473735    EVERY 6TH DAY               2
# 473736    EVERY 6TH DAY               2
# 473737    EVERY 6TH DAY               2
# 473738    EVERY 6TH DAY               2
# 473739    EVERY 6TH DAY               2
# 473740    EVERY 6TH DAY               2
# 473741    EVERY 6TH DAY               2
# 473742    EVERY 6TH DAY               2
# 473743    EVERY 6TH DAY               2
# 473744    EVERY 6TH DAY               2
# 473745    EVERY 6TH DAY               2
# 473746    EVERY 6TH DAY               2
# 473747    EVERY 6TH DAY               2
# 473748    EVERY 6TH DAY               2
# 473749    EVERY 6TH DAY               2
# 473750    EVERY 6TH DAY               2
# 473751    EVERY 6TH DAY               2
# 473752    EVERY 6TH DAY               2
# 473753    EVERY 6TH DAY               2
# 473754    EVERY 6TH DAY               2
# 473755    EVERY 6TH DAY               2
# 473756    EVERY 6TH DAY               2
# 473757    EVERY 6TH DAY               2
# 473758    EVERY 6TH DAY               2
# 473759             None            None                    None
# 473760             None            None                    None
#
#        Qualifier Description Method Type  \
# 0                             Equivalent
# 1                             Equivalent
# 2                             Equivalent
# 3                             Equivalent
# 4                             Equivalent
# 5                             Equivalent
# 6                             Equivalent
# 7                             Equivalent
# 8                             Equivalent
# 9                             Equivalent
# 10                            Equivalent
# 11                            Equivalent
# 12                            Equivalent
# 13                            Equivalent
# 14                            Equivalent
# 15                            Equivalent
# 16                            Equivalent
# 17                            Equivalent
# 18                            Equivalent
# 19                            Equivalent
# 20                            Equivalent
# 21                            Equivalent
# 22                            Equivalent
# 23                            Equivalent
# 24                            Equivalent
# 25                            Equivalent
# 26                            Equivalent
# 27                            Equivalent
# 28                            Equivalent
# 29                            Equivalent
# ...                      ...         ...
# 473731                         Reference
# 473732                         Reference
# 473733        Wildfire-U. S.   Reference
# 473734                         Reference
# 473735                         Reference
# 473736                         Reference
# 473737            High Winds   Reference
# 473738                         Reference
# 473739                         Reference
# 473740                         Reference
# 473741                         Reference
# 473742                         Reference
# 473743            High Winds   Reference
# 473744            High Winds   Reference
# 473745                         Reference
# 473746                         Reference
# 473747                         Reference
# 473748            High Winds   Reference
# 473749                         Reference
# 473750                         Reference
# 473751                         Reference
# 473752            High Winds   Reference
# 473753                         Reference
# 473754                         Reference
# 473755            High Winds   Reference
# 473756            High Winds   Reference
# 473757                         Reference
# 473758                         Reference
# 473759                  None        None
# 473760                  None        None
#
#                                        Method Description   FIPS
# 0       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 1       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 2       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 3       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 4       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 5       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 6       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 7       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 8       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 9       Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 10      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 11      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 12      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 13      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 14      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 15      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 16      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 17      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 18      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 19      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 20      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 21      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 22      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 23      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 24      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 25      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 26      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 27      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 28      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# 29      Met One BAM-1020 Mass Monitor w/VSCC-Beta Atte...  06001
# ...                                                   ...    ...
# 473731  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473732  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473733  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473734  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473735  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473736  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473737  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473738  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473739  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473740  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473741  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473742  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473743  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473744  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473745  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473746  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473747  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473748  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473749  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473750  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473751  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473752  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473753  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473754  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473755  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473756  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473757  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473758  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 473759                                               None    NaN
# 473760                                               None    NaN
#
# [473761 rows x 26 columns]

# %%
countyname = { "001": "Alameda", "003": "Apline", "005": "Amador", "007":"Butte", "009":"Calaveras", "011": "Colusa", "013":"Contra Costa", "015":"Del Norte", "017":"El Dorado", "019": "Fresno", "021": "Glenn", "023": "Humboldt", "025": "Imperial", "027": "Inyo", "029": "Kern", "031": "Kings", "033":"Lake", "035": "Lassen", "037": "Los Angeles", "039": "Madera", "041": "Marin", "043": "Mariposa", "045": "Mendicino", "047": "Merced", "049": "Modoc", "051": "Mono", "053": "Monterey", "055": "Napa", "057": "Nevada", "059": "Orange", "061": "Placer", "063": "Plumas", "065": "Riverside", "067": "Sacramento", "069": "San Benito", "071": "San Bernardino", "073": "San Diego", "075": "San Francisco", "077": "San Joaquin", "079": "San Luis Obispo", "081": "San Mateo", "083": "Santa Barbara", "085": "Santa Clara", "087": "Santa Cruz", "089": "Shasta", "091": "Sierra", "093": "Siskiyou", "095": "Solano", "097": "Sonoma", "099": "Stanislaus", "101": "Sutter", "103": "Tehama", "105": "Trinity", "107": "Tulare", "109": "Tuolumne", "111": "Ventura", "113": "Yolo", "115": "Yuba"}

df_trim = data_2013[['County Code','Date Local','24 Hour Local','Date GMT','Sample Measurement', "Sample Frequency",'Units of Measure','Sample Duration', "Latitude", "Longitude", "FIPS"]]
df_trim["County Names"] = df_trim["County Code"].map(countyname)
df_trim
# Out:
#        County Code  Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 0              001  2013-02-18         23:00  2013-02-19                  6
# 1              001  2013-02-18         23:00  2013-02-19                  4
# 2              001  2013-02-18         23:00  2013-02-19                  5
# 3              001  2013-02-18         22:00  2013-02-19                  7
# 4              001  2013-02-18         22:00  2013-02-19                  4
# 5              001  2013-02-18         22:00  2013-02-19                  4
# 6              001  2013-02-18         00:00  2013-02-18                  9
# 7              001  2013-02-18         00:00  2013-02-18                 13
# 8              001  2013-02-18         00:00  2013-02-18                  9
# 9              001  2013-02-18         20:00  2013-02-19                  7
# 10             001  2013-02-18         20:00  2013-02-19                  3
# 11             001  2013-02-18         20:00  2013-02-19                  4
# 12             001  2013-02-18         19:00  2013-02-19                  5
# 13             001  2013-02-18         19:00  2013-02-19                  2
# 14             001  2013-02-18         19:00  2013-02-19                  3
# 15             001  2013-02-18         21:00  2013-02-19                  8
# 16             001  2013-02-18         21:00  2013-02-19                  5
# 17             001  2013-02-18         21:00  2013-02-19                  1
# 18             001  2013-02-18         18:00  2013-02-19                  6
# 19             001  2013-02-18         18:00  2013-02-19                  2
# 20             001  2013-02-18         18:00  2013-02-19                  5
# 21             001  2013-02-18         17:00  2013-02-19                  7
# 22             001  2013-02-18         17:00  2013-02-19                  0
# 23             001  2013-02-18         17:00  2013-02-19                  9
# 24             001  2013-02-18         15:00  2013-02-18                  8
# 25             001  2013-02-18         15:00  2013-02-18                  5
# 26             001  2013-02-18         15:00  2013-02-18                  6
# 27             001  2013-02-18         14:00  2013-02-18                  7
# 28             001  2013-02-18         14:00  2013-02-18                  6
# 29             001  2013-02-18         14:00  2013-02-18                  6
# ...            ...         ...           ...         ...                ...
# 473731         113  2013-08-28         00:00  2013-08-28                2.5
# 473732         113  2013-07-09         00:00  2013-07-09                5.9
# 473733         113  2013-08-20         00:00  2013-08-20                9.2
# 473734         113  2013-01-04         00:00  2013-01-04               14.5
# 473735         113  2013-05-16         00:00  2013-05-16                  3
# 473736         113  2013-05-04         00:00  2013-05-04                7.9
# 473737         113  2013-04-16         00:00  2013-04-16                  1
# 473738         113  2013-03-17         00:00  2013-03-17                2.5
# 473739         113  2013-01-28         00:00  2013-01-28                2.7
# 473740         113  2013-04-28         00:00  2013-04-28                7.3
# 473741         113  2013-04-10         00:00  2013-04-10                3.4
# 473742         113  2013-03-11         00:00  2013-03-11                6.9
# 473743         113  2013-03-05         00:00  2013-03-05                3.5
# 473744         113  2013-02-09         00:00  2013-02-09                2.8
# 473745         113  2013-05-28         00:00  2013-05-28                2.8
# 473746         113  2013-05-10         00:00  2013-05-10                5.2
# 473747         113  2013-02-21         00:00  2013-02-21                4.3
# 473748         113  2013-04-04         00:00  2013-04-04                  1
# 473749         113  2013-01-10         00:00  2013-01-10                4.7
# 473750         113  2013-02-27         00:00  2013-02-27                  4
# 473751         113  2013-04-22         00:00  2013-04-22                6.2
# 473752         113  2013-03-23         00:00  2013-03-23                3.5
# 473753         113  2013-03-29         00:00  2013-03-29                3.3
# 473754         113  2013-02-03         00:00  2013-02-03               10.7
# 473755         113  2013-02-15         00:00  2013-02-15                9.1
# 473756         113  2013-05-22         00:00  2013-05-22                3.2
# 473757         113  2013-01-16         00:00  2013-01-16                 22
# 473758         113  2013-01-22         00:00  2013-01-22               10.5
# 473759        None        None          None        None               None
# 473760        None        None          None        None               None
#
#        Sample Frequency             Units of Measure Sample Duration  \
# 0                        Micrograms/cubic meter (LC)          1 HOUR
# 1                        Micrograms/cubic meter (LC)          1 HOUR
# 2                        Micrograms/cubic meter (LC)          1 HOUR
# 3                        Micrograms/cubic meter (LC)          1 HOUR
# 4                        Micrograms/cubic meter (LC)          1 HOUR
# 5                        Micrograms/cubic meter (LC)          1 HOUR
# 6                        Micrograms/cubic meter (LC)          1 HOUR
# 7                        Micrograms/cubic meter (LC)          1 HOUR
# 8                        Micrograms/cubic meter (LC)          1 HOUR
# 9                        Micrograms/cubic meter (LC)          1 HOUR
# 10                       Micrograms/cubic meter (LC)          1 HOUR
# 11                       Micrograms/cubic meter (LC)          1 HOUR
# 12                       Micrograms/cubic meter (LC)          1 HOUR
# 13                       Micrograms/cubic meter (LC)          1 HOUR
# 14                       Micrograms/cubic meter (LC)          1 HOUR
# 15                       Micrograms/cubic meter (LC)          1 HOUR
# 16                       Micrograms/cubic meter (LC)          1 HOUR
# 17                       Micrograms/cubic meter (LC)          1 HOUR
# 18                       Micrograms/cubic meter (LC)          1 HOUR
# 19                       Micrograms/cubic meter (LC)          1 HOUR
# 20                       Micrograms/cubic meter (LC)          1 HOUR
# 21                       Micrograms/cubic meter (LC)          1 HOUR
# 22                       Micrograms/cubic meter (LC)          1 HOUR
# 23                       Micrograms/cubic meter (LC)          1 HOUR
# 24                       Micrograms/cubic meter (LC)          1 HOUR
# 25                       Micrograms/cubic meter (LC)          1 HOUR
# 26                       Micrograms/cubic meter (LC)          1 HOUR
# 27                       Micrograms/cubic meter (LC)          1 HOUR
# 28                       Micrograms/cubic meter (LC)          1 HOUR
# 29                       Micrograms/cubic meter (LC)          1 HOUR
# ...                 ...                          ...             ...
# 473731                   Micrograms/cubic meter (LC)         24 HOUR
# 473732                   Micrograms/cubic meter (LC)         24 HOUR
# 473733                   Micrograms/cubic meter (LC)         24 HOUR
# 473734    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473735    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473736    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473737    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473738    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473739    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473740    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473741    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473742    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473743    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473744    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473745    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473746    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473747    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473748    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473749    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473750    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473751    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473752    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473753    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473754    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473755    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473756    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473757    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473758    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 473759             None                         None            None
# 473760             None                         None            None
#
#            Latitude    Longitude   FIPS County Names
# 0         37.814781  -122.282347  06001      Alameda
# 1         37.687526  -121.784217  06001      Alameda
# 2         37.743065  -122.169935  06001      Alameda
# 3         37.814781  -122.282347  06001      Alameda
# 4         37.687526  -121.784217  06001      Alameda
# 5         37.743065  -122.169935  06001      Alameda
# 6         37.814781  -122.282347  06001      Alameda
# 7         37.687526  -121.784217  06001      Alameda
# 8         37.743065  -122.169935  06001      Alameda
# 9         37.814781  -122.282347  06001      Alameda
# 10        37.687526  -121.784217  06001      Alameda
# 11        37.743065  -122.169935  06001      Alameda
# 12        37.814781  -122.282347  06001      Alameda
# 13        37.687526  -121.784217  06001      Alameda
# 14        37.743065  -122.169935  06001      Alameda
# 15        37.814781  -122.282347  06001      Alameda
# 16        37.687526  -121.784217  06001      Alameda
# 17        37.743065  -122.169935  06001      Alameda
# 18        37.814781  -122.282347  06001      Alameda
# 19        37.687526  -121.784217  06001      Alameda
# 20        37.743065  -122.169935  06001      Alameda
# 21        37.814781  -122.282347  06001      Alameda
# 22        37.687526  -121.784217  06001      Alameda
# 23        37.743065  -122.169935  06001      Alameda
# 24        37.814781  -122.282347  06001      Alameda
# 25        37.687526  -121.784217  06001      Alameda
# 26        37.743065  -122.169935  06001      Alameda
# 27        37.814781  -122.282347  06001      Alameda
# 28        37.687526  -121.784217  06001      Alameda
# 29        37.743065  -122.169935  06001      Alameda
# ...             ...          ...    ...          ...
# 473731     38.66121   -121.73269  06113         Yolo
# 473732     38.66121   -121.73269  06113         Yolo
# 473733     38.66121   -121.73269  06113         Yolo
# 473734     38.66121   -121.73269  06113         Yolo
# 473735     38.66121   -121.73269  06113         Yolo
# 473736     38.66121   -121.73269  06113         Yolo
# 473737     38.66121   -121.73269  06113         Yolo
# 473738     38.66121   -121.73269  06113         Yolo
# 473739     38.66121   -121.73269  06113         Yolo
# 473740     38.66121   -121.73269  06113         Yolo
# 473741     38.66121   -121.73269  06113         Yolo
# 473742     38.66121   -121.73269  06113         Yolo
# 473743     38.66121   -121.73269  06113         Yolo
# 473744     38.66121   -121.73269  06113         Yolo
# 473745     38.66121   -121.73269  06113         Yolo
# 473746     38.66121   -121.73269  06113         Yolo
# 473747     38.66121   -121.73269  06113         Yolo
# 473748     38.66121   -121.73269  06113         Yolo
# 473749     38.66121   -121.73269  06113         Yolo
# 473750     38.66121   -121.73269  06113         Yolo
# 473751     38.66121   -121.73269  06113         Yolo
# 473752     38.66121   -121.73269  06113         Yolo
# 473753     38.66121   -121.73269  06113         Yolo
# 473754     38.66121   -121.73269  06113         Yolo
# 473755     38.66121   -121.73269  06113         Yolo
# 473756     38.66121   -121.73269  06113         Yolo
# 473757     38.66121   -121.73269  06113         Yolo
# 473758     38.66121   -121.73269  06113         Yolo
# 473759  END OF FILE         None    NaN          NaN
# 473760  END OF FILE         None    NaN          NaN
#
# [473761 rows x 12 columns]

# %%
#Create 2 dataframes to hold records for sampling done by 24 hour duration and 1 hour duration
hour1_df = df_trim.loc[(df_trim["Sample Duration"]== "1 HOUR")]
hour24_df = df_trim.loc[(df_trim["Sample Duration"]== "24 HOUR")]

#See which sampling duration has more unique counties
hour1_df["County Names"].nunique()
hour24_df["County Names"].nunique()
# Out:
# 28

# %%
#Convert 'Date Local' column to datetime to extract month #
hour1_df['Date Local'] = pd.to_datetime(hour1_df['Date Local'])

#Creating column for Month # for 1hour sample duration df
hour1_df['Month'] = pd.DatetimeIndex(hour1_df['Date Local']).month
hour1_df["Month"].fillna(0)
hour1_df["Month"].astype(float)
hour1_df.fillna(0)
hour1_df["County Names"].dtype

#Convert 'Date Local' column to datetime to extract month #
hour24_df['Date Local'] = pd.to_datetime(hour24_df['Date Local'])

#Creating column for Month # for 24 hour sample duration df
hour24_df['Month'] = pd.DatetimeIndex(hour24_df['Date Local']).month
hour24_df["Month"].fillna(0)
hour24_df["Month"].astype(float)
hour24_df.fillna(0)
hour24_df.head()
# Out:
#       County Code Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 25079         007 2013-02-18         00:00  2013-02-18               12.1
# 25080         007 2013-01-21         00:00  2013-01-21               21.8
# 25081         007 2013-05-27         00:00  2013-05-27                2.7
# 25082         007 2013-04-20         00:00  2013-04-20                5.5
# 25083         007 2013-04-06         00:00  2013-04-06                3.7
#
#       Sample Frequency             Units of Measure Sample Duration  Latitude  \
# 25079        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 25080        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 25081        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 25082        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  39.76168
# 25083        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  39.76168
#
#         Longitude   FIPS County Names  Month
# 25079  -121.84047  06007        Butte      2
# 25080  -121.84047  06007        Butte      1
# 25081  -121.84047  06007        Butte      5
# 25082  -121.84047  06007        Butte      4
# 25083  -121.84047  06007        Butte      4

# %%
#extract only relevant columns and create a groupby df (for 24 hour sample duration)
mday_df = hour24_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mday_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuff24 = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuff24
mday_df["PM2.5 Values 2013"] = tuff24
finalday = mday_df
finalday.drop(columns="Sample Measurement")
#finalday
finalday.to_csv("2013CA24hrPM2.5.csv")
finalday.head()
# Out:
#       County Names  Month Sample Measurement  Latitude   Longitude   FIPS  \
# 25079        Butte      2               12.1  39.76168  -121.84047  06007
# 25080        Butte      1               21.8  39.76168  -121.84047  06007
# 25081        Butte      5                2.7  39.76168  -121.84047  06007
# 25082        Butte      4                5.5  39.76168  -121.84047  06007
# 25083        Butte      4                3.7  39.76168  -121.84047  06007
#
#        PM2.5 Values 2013
# 25079               12.1
# 25080               21.8
# 25081                2.7
# 25082                5.5
# 25083                3.7

# %%
#groupby to graph results
county_date24hr = pd.DataFrame(finalday.groupby(['County Names', 'Month']).mean())
county_date24hr.head()
# Out:
#                     PM2.5 Values 2013
# County Names Month
# Butte        1              19.300000
#              2              10.025926
#              3               5.257143
#              4               3.490909
#              5               8.220690

# %%
county_date24hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2013 (24hr Sampling Duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2013 PM2.5 AVG (24hr Sampling).png", bbox_inches='tight')
plt.figure()

# %%
# extract only relevant columns and create a groupby df
mhour_df = hour1_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mhour_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mhour_df["Sample Measurement"], errors='coerce')
tuffhour_df
mhour_df["PM2.5 Values 2013"] = tuffhour_df
finalhour = mhour_df
finalhour.drop(columns="Sample Measurement")

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuffhour_df
mday_df["PM2.5 Values 2013"] = tuffhour_df
finalhour = mday_df
finalhour.drop(columns="Sample Measurement")

finalday.to_csv("2013CA1hrPM2.5.csv")

# %%
#groupby to graph results
county_1hr = pd.DataFrame(finalhour.groupby(['County Names', 'Month']).mean())
county_1hr.head()
# Out:
#                     PM2.5 Values 2013
# County Names Month
# Butte        1              19.300000
#              2              10.025926
#              3               5.257143
#              4               3.490909
#              5               8.220690

# %%
county_1hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2013 (1Hr Sampling duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2013 PM2.5 AVG (1hrSampling).png", bbox_inches='tight')
plt.figure()

# %%
#Find Max for 24hr sampling group
max_pm25 = county_date24hr['PM2.5 Values 2013'].max()
max_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2013'] == max_pm25,:]
max_county24hr

#Find Max for 1hr sampling group
max_pm25 = county_1hr['PM2.5 Values 2013'].max()
max_1hr = county_1hr.loc[county_1hr['PM2.5 Values 2013'] == max_pm25,:]
max_1hr
# Out:
#                     PM2.5 Values 2013
# County Names Month
# Tulare       12                 55.43

# %%
#Find Min
min_pm25 = county_date24hr['PM2.5 Values 2013'].min()
min_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2013'] == min_pm25,:]
min_county24hr

min_pm25 = county_1hr['PM2.5 Values 2013'].min()
min_county1hr = county_1hr.loc[county_1hr['PM2.5 Values 2013'] == min_pm25,:]
min_county1hr
# Out:
#                     PM2.5 Values 2013
# County Names Month
# Siskiyou     4                  1.425

# %%
# create a df with only the Max & Min, and SD/LA for ref counties
minmax_df = finalday.loc[(finalday['County Names']=='Tulare') | (finalday['County Names']=='Siskiyou') | (finalday['County Names']=='San Diego') | (finalday['County Names']=='Los Angeles'),:]
minmax_df.head()
# Out:
#        County Names  Month Sample Measurement   Latitude    Longitude   FIPS  \
# 117382  Los Angeles     10                5.4  34.671394  -118.131456  06037
# 117383  Los Angeles     10                5.9  34.671394  -118.131456  06037
# 117384  Los Angeles      1                7.1  34.671394  -118.131456  06037
# 117385  Los Angeles      3                9.8  34.671394  -118.131456  06037
# 117386  Los Angeles     10                4.3  34.671394  -118.131456  06037
#
#         PM2.5 Values 2013
# 117382                5.4
# 117383                5.9
# 117384                7.1
# 117385                9.8
# 117386                4.3

# %%
mm_mean_df = minmax_df.loc[:, ['County Names', 'Month', 'PM2.5 Values 2013']]
mm_df = pd.DataFrame(mm_mean_df.groupby(['County Names', 'Month']).mean())
mm_df.head()
# Out:
#                     PM2.5 Values 2013
# County Names Month
# Los Angeles  1              11.736364
#              2              11.299315
#              3              13.046341
#              4              10.129341
#              5              11.121557

# %%
mm_df.unstack(0).plot(figsize = (10,10))
plt.title("Graph of PM2.5 Max & Min in CA + San Diego & Los Angeles 2013")
plt.xlabel('Month')
plt.ylabel('PM2.5 Mean/Month')
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("2013_CA_MaxMin_SDLA.png", bbox_inches='tight') 
plt.figure()

# %%
county_final = pd.DataFrame(finalday.groupby(['FIPS']).mean())
county_sum = county_final.drop(columns=["Month"], )
#county_sum.to_csv('2013_CA_PM25_Mean.csv')
county_sum
county_sum.sort_values(by=["PM2.5 Values 2013"], ascending=False)
#county_sum.to_csv('2013_CA_PM25_Sum.csv')
# Out:
#        PM2.5 Values 2013
# FIPS
# 06029          19.040706
# 06107          18.398291
# 06031          17.782143
# 06019          17.051573
# 06047          16.198795
# 06099          13.490000
# 06065          11.665862
# 06037          11.313958
# 06063          10.926961
# 06067          10.800654
# 06085          10.600000
# 06071          10.594455
# 06007          10.166667
# 06025           9.962980
# 06059           9.577902
# 06073           9.389766
# 06111           8.898701
# 06027           8.307692
# 06101           8.200952
# 06093           7.931579
# 06061           7.431034
# 06113           7.191228
# 06011           7.048148
# 06057           6.892632
# 06023           6.842857
# 06089           5.541772
# 06053           5.451724
# 06033           3.868852

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
plotly.tools.set_credentials_file(username=Plotuser, api_key=Plotkey)

# %%
#create lists of values to graph in plotly
values = county_sum["PM2.5 Values 2013"].tolist()
fips = county_sum.index.values
print(values)
# Out:
# [10.166666666666671, 7.048148148148148, 17.051573426573423, 6.842857142857141, 9.962979683972913, 8.307692307692308, 19.040706319702593, 17.78214285714285, 3.8688524590163933, 11.313958125623124, 16.19879518072289, 5.451724137931035, 6.892631578947368, 9.577901785714287, 7.431034482758622, 10.926960784313724, 11.665861513687613, 10.800653594771235, 10.59445544554455, 9.389766081871333, 10.599999999999996, 5.541772151898734, 7.931578947368425, 13.49, 8.20095238095238, 18.398290598290593, 8.898701298701305, 7.1912280701754385]

# %%
#send FIPS codes and corresponding PM2.5 values to plotly to graph
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['CA'],
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='PM2.5 by County', title='California PM2.5 2013 By County'
)
py.iplot(fig, filename='CA_PM2.5 2013')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tonyphelps/4.embed" height="450px" width="900px"></iframe>
