# %%
#import dependencies

import plotly.plotly as py
import plotly.figure_factory as ff

import pandas as pd
import requests as req
#create separate file with individual log in credentials to be imported
from config import (user_id_aqs, password_aqs, Plotkey, Plotuser)
import csv
import matplotlib.pyplot as plt

# %%
codes = []
countycodes = ["{0:03}".format(i) for i in range(117) if i%2 > 0]

for countycode in countycodes:
    codes.append(countycode)
#listyy

# %%
#API REQUEST
URL_new = f"https://aqs.epa.gov/api/rawData?user={user_id_aqs}&pw={password_aqs}&format=DMCSV&param=88101&bdate=20110101&edate=20111231&state=06&county="
list_2011 = []

for x in codes:
    url_loop = URL_new + x
    print(f"fetching county code {x}")
    response1 = req.get(url_loop)
    print(f"Got API Response for {x}")
    wrapper = csv.reader(response1.text.strip().split('\n'))
    header = next(wrapper)
    for record in wrapper:
        list_2011.append(record)
    print(f"Appended List with {x} API Response")
# Out:
# fetching county code 001
# Got API Response for 001
# Appended List with 001 API Response
# fetching county code 003
# Got API Response for 003
# Appended List with 003 API Response
# fetching county code 005
# Got API Response for 005
# Appended List with 005 API Response
# fetching county code 007
# Got API Response for 007
# Appended List with 007 API Response
# fetching county code 009
# Got API Response for 009
# Appended List with 009 API Response
# fetching county code 011
# Got API Response for 011
# Appended List with 011 API Response
# fetching county code 013
# Got API Response for 013
# Appended List with 013 API Response
# fetching county code 015
# Got API Response for 015
# Appended List with 015 API Response
# fetching county code 017
# Got API Response for 017
# Appended List with 017 API Response
# fetching county code 019
# Got API Response for 019
# Appended List with 019 API Response
# fetching county code 021
# Got API Response for 021
# Appended List with 021 API Response
# fetching county code 023
# Got API Response for 023
# Appended List with 023 API Response
# fetching county code 025
# Got API Response for 025
# Appended List with 025 API Response
# fetching county code 027
# Got API Response for 027
# Appended List with 027 API Response
# fetching county code 029
# Got API Response for 029
# Appended List with 029 API Response
# fetching county code 031
# Got API Response for 031
# Appended List with 031 API Response
# fetching county code 033
# Got API Response for 033
# Appended List with 033 API Response
# fetching county code 035
# Got API Response for 035
# Appended List with 035 API Response
# fetching county code 037
# Got API Response for 037
# Appended List with 037 API Response
# fetching county code 039
# Got API Response for 039
# Appended List with 039 API Response
# fetching county code 041
# Got API Response for 041
# Appended List with 041 API Response
# fetching county code 043
# Got API Response for 043
# Appended List with 043 API Response
# fetching county code 045
# Got API Response for 045
# Appended List with 045 API Response
# fetching county code 047
# Got API Response for 047
# Appended List with 047 API Response
# fetching county code 049
# Got API Response for 049
# Appended List with 049 API Response
# fetching county code 051
# Got API Response for 051
# Appended List with 051 API Response
# fetching county code 053
# Got API Response for 053
# Appended List with 053 API Response
# fetching county code 055
# Got API Response for 055
# Appended List with 055 API Response
# fetching county code 057
# Got API Response for 057
# Appended List with 057 API Response
# fetching county code 059
# Got API Response for 059
# Appended List with 059 API Response
# fetching county code 061
# Got API Response for 061
# Appended List with 061 API Response
# fetching county code 063
# Got API Response for 063
# Appended List with 063 API Response
# fetching county code 065
# Got API Response for 065
# Appended List with 065 API Response
# fetching county code 067
# Got API Response for 067
# Appended List with 067 API Response
# fetching county code 069
# Got API Response for 069
# Appended List with 069 API Response
# fetching county code 071
# Got API Response for 071
# Appended List with 071 API Response
# fetching county code 073
# Got API Response for 073
# Appended List with 073 API Response
# fetching county code 075
# Got API Response for 075
# Appended List with 075 API Response
# fetching county code 077
# Got API Response for 077
# Appended List with 077 API Response
# fetching county code 079
# Got API Response for 079
# Appended List with 079 API Response
# fetching county code 081
# Got API Response for 081
# Appended List with 081 API Response
# fetching county code 083
# Got API Response for 083
# Appended List with 083 API Response
# fetching county code 085
# Got API Response for 085
# Appended List with 085 API Response
# fetching county code 087
# Got API Response for 087
# Appended List with 087 API Response
# fetching county code 089
# Got API Response for 089
# Appended List with 089 API Response
# fetching county code 091
# Got API Response for 091
# Appended List with 091 API Response
# fetching county code 093
# Got API Response for 093
# Appended List with 093 API Response
# fetching county code 095
# Got API Response for 095
# Appended List with 095 API Response
# fetching county code 097
# Got API Response for 097
# Appended List with 097 API Response
# fetching county code 099
# Got API Response for 099
# Appended List with 099 API Response
# fetching county code 101
# Got API Response for 101
# Appended List with 101 API Response
# fetching county code 103
# Got API Response for 103
# Appended List with 103 API Response
# fetching county code 105
# Got API Response for 105
# Appended List with 105 API Response
# fetching county code 107
# Got API Response for 107
# Appended List with 107 API Response
# fetching county code 109
# Got API Response for 109
# Appended List with 109 API Response
# fetching county code 111
# Got API Response for 111
# Appended List with 111 API Response
# fetching county code 113
# Got API Response for 113
# Appended List with 113 API Response
# fetching county code 115
# Got API Response for 115
# Appended List with 115 API Response

# %%
#Create DF and append FIPS column with county code and 06 (state code) to create FIPS code
data_2011 = pd.DataFrame(list_2011, columns = header)
data_2011["FIPS"] = "06" + data_2011["County Code"]
data_2011
# Out:
#            Latitude    Longitude  Datum Horizontal Accuracy State Code  \
# 0         37.687526  -121.784217  WGS84           109305.56         06
# 1         37.687526  -121.784217  WGS84           109305.56         06
# 2         37.687526  -121.784217  WGS84           109305.56         06
# 3         37.687526  -121.784217  WGS84           109305.56         06
# 4         37.687526  -121.784217  WGS84           109305.56         06
# 5         37.687526  -121.784217  WGS84           109305.56         06
# 6         37.687526  -121.784217  WGS84           109305.56         06
# 7         37.687526  -121.784217  WGS84           109305.56         06
# 8         37.687526  -121.784217  WGS84           109305.56         06
# 9         37.687526  -121.784217  WGS84           109305.56         06
# 10        37.687526  -121.784217  WGS84           109305.56         06
# 11        37.687526  -121.784217  WGS84           109305.56         06
# 12        37.687526  -121.784217  WGS84           109305.56         06
# 13        37.687526  -121.784217  WGS84           109305.56         06
# 14        37.687526  -121.784217  WGS84           109305.56         06
# 15        37.687526  -121.784217  WGS84           109305.56         06
# 16        37.687526  -121.784217  WGS84           109305.56         06
# 17        37.687526  -121.784217  WGS84           109305.56         06
# 18        37.687526  -121.784217  WGS84           109305.56         06
# 19        37.687526  -121.784217  WGS84           109305.56         06
# 20        37.687526  -121.784217  WGS84           109305.56         06
# 21        37.687526  -121.784217  WGS84           109305.56         06
# 22        37.687526  -121.784217  WGS84           109305.56         06
# 23        37.687526  -121.784217  WGS84           109305.56         06
# 24        37.687526  -121.784217  WGS84           109305.56         06
# 25        37.687526  -121.784217  WGS84           109305.56         06
# 26        37.687526  -121.784217  WGS84           109305.56         06
# 27        37.687526  -121.784217  WGS84           109305.56         06
# 28        37.687526  -121.784217  WGS84           109305.56         06
# 29        37.687526  -121.784217  WGS84           109305.56         06
# ...             ...          ...    ...                 ...        ...
# 318368     38.66121   -121.73269  WGS84              151.82         06
# 318369     38.66121   -121.73269  WGS84              151.82         06
# 318370     38.66121   -121.73269  WGS84              151.82         06
# 318371     38.66121   -121.73269  WGS84              151.82         06
# 318372     38.66121   -121.73269  WGS84              151.82         06
# 318373     38.66121   -121.73269  WGS84              151.82         06
# 318374     38.66121   -121.73269  WGS84              151.82         06
# 318375     38.66121   -121.73269  WGS84              151.82         06
# 318376     38.66121   -121.73269  WGS84              151.82         06
# 318377     38.66121   -121.73269  WGS84              151.82         06
# 318378     38.66121   -121.73269  WGS84              151.82         06
# 318379     38.66121   -121.73269  WGS84              151.82         06
# 318380     38.66121   -121.73269  WGS84              151.82         06
# 318381     38.66121   -121.73269  WGS84              151.82         06
# 318382     38.66121   -121.73269  WGS84              151.82         06
# 318383     38.66121   -121.73269  WGS84              151.82         06
# 318384     38.66121   -121.73269  WGS84              151.82         06
# 318385     38.66121   -121.73269  WGS84              151.82         06
# 318386     38.66121   -121.73269  WGS84              151.82         06
# 318387     38.66121   -121.73269  WGS84              151.82         06
# 318388     38.66121   -121.73269  WGS84              151.82         06
# 318389     38.66121   -121.73269  WGS84              151.82         06
# 318390     38.66121   -121.73269  WGS84              151.82         06
# 318391     38.66121   -121.73269  WGS84              151.82         06
# 318392     38.66121   -121.73269  WGS84              151.82         06
# 318393     38.66121   -121.73269  WGS84              151.82         06
# 318394     38.66121   -121.73269  WGS84              151.82         06
# 318395     38.66121   -121.73269  WGS84              151.82         06
# 318396  END OF FILE         None   None                None       None
# 318397  END OF FILE         None   None                None       None
#
#        County Code Site Num Parameter Code   POC        AQS Parameter Desc  \
# 0              001     0007          88101     1  PM2.5 - Local Conditions
# 1              001     0007          88101     1  PM2.5 - Local Conditions
# 2              001     0007          88101     1  PM2.5 - Local Conditions
# 3              001     0007          88101     1  PM2.5 - Local Conditions
# 4              001     0007          88101     1  PM2.5 - Local Conditions
# 5              001     0007          88101     1  PM2.5 - Local Conditions
# 6              001     0007          88101     1  PM2.5 - Local Conditions
# 7              001     0007          88101     1  PM2.5 - Local Conditions
# 8              001     0007          88101     1  PM2.5 - Local Conditions
# 9              001     0007          88101     1  PM2.5 - Local Conditions
# 10             001     0007          88101     1  PM2.5 - Local Conditions
# 11             001     0007          88101     1  PM2.5 - Local Conditions
# 12             001     0007          88101     1  PM2.5 - Local Conditions
# 13             001     0007          88101     1  PM2.5 - Local Conditions
# 14             001     0007          88101     1  PM2.5 - Local Conditions
# 15             001     0007          88101     1  PM2.5 - Local Conditions
# 16             001     0007          88101     1  PM2.5 - Local Conditions
# 17             001     0007          88101     1  PM2.5 - Local Conditions
# 18             001     0007          88101     1  PM2.5 - Local Conditions
# 19             001     0007          88101     1  PM2.5 - Local Conditions
# 20             001     0007          88101     1  PM2.5 - Local Conditions
# 21             001     0007          88101     1  PM2.5 - Local Conditions
# 22             001     0007          88101     1  PM2.5 - Local Conditions
# 23             001     0007          88101     1  PM2.5 - Local Conditions
# 24             001     0007          88101     1  PM2.5 - Local Conditions
# 25             001     0007          88101     1  PM2.5 - Local Conditions
# 26             001     0007          88101     1  PM2.5 - Local Conditions
# 27             001     0007          88101     1  PM2.5 - Local Conditions
# 28             001     0007          88101     1  PM2.5 - Local Conditions
# 29             001     0007          88101     1  PM2.5 - Local Conditions
# ...            ...      ...            ...   ...                       ...
# 318368         113     1003          88101     1  PM2.5 - Local Conditions
# 318369         113     1003          88101     1  PM2.5 - Local Conditions
# 318370         113     1003          88101     1  PM2.5 - Local Conditions
# 318371         113     1003          88101     1  PM2.5 - Local Conditions
# 318372         113     1003          88101     1  PM2.5 - Local Conditions
# 318373         113     1003          88101     1  PM2.5 - Local Conditions
# 318374         113     1003          88101     1  PM2.5 - Local Conditions
# 318375         113     1003          88101     1  PM2.5 - Local Conditions
# 318376         113     1003          88101     1  PM2.5 - Local Conditions
# 318377         113     1003          88101     1  PM2.5 - Local Conditions
# 318378         113     1003          88101     1  PM2.5 - Local Conditions
# 318379         113     1003          88101     1  PM2.5 - Local Conditions
# 318380         113     1003          88101     1  PM2.5 - Local Conditions
# 318381         113     1003          88101     1  PM2.5 - Local Conditions
# 318382         113     1003          88101     1  PM2.5 - Local Conditions
# 318383         113     1003          88101     1  PM2.5 - Local Conditions
# 318384         113     1003          88101     1  PM2.5 - Local Conditions
# 318385         113     1003          88101     1  PM2.5 - Local Conditions
# 318386         113     1003          88101     1  PM2.5 - Local Conditions
# 318387         113     1003          88101     1  PM2.5 - Local Conditions
# 318388         113     1003          88101     1  PM2.5 - Local Conditions
# 318389         113     1003          88101     1  PM2.5 - Local Conditions
# 318390         113     1003          88101     1  PM2.5 - Local Conditions
# 318391         113     1003          88101     1  PM2.5 - Local Conditions
# 318392         113     1003          88101     1  PM2.5 - Local Conditions
# 318393         113     1003          88101     1  PM2.5 - Local Conditions
# 318394         113     1003          88101     1  PM2.5 - Local Conditions
# 318395         113     1003          88101     1  PM2.5 - Local Conditions
# 318396        None     None           None  None                      None
# 318397        None     None           None  None                      None
#
#         ...   Sample Measurement             Units of Measure Sample Duration  \
# 0       ...                  6.6  Micrograms/cubic meter (LC)         24 HOUR
# 1       ...                 23.6  Micrograms/cubic meter (LC)         24 HOUR
# 2       ...                 10.5  Micrograms/cubic meter (LC)         24 HOUR
# 3       ...                  8.5  Micrograms/cubic meter (LC)         24 HOUR
# 4       ...                    3  Micrograms/cubic meter (LC)         24 HOUR
# 5       ...                  4.7  Micrograms/cubic meter (LC)         24 HOUR
# 6       ...                  2.6  Micrograms/cubic meter (LC)         24 HOUR
# 7       ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 8       ...                  2.5  Micrograms/cubic meter (LC)         24 HOUR
# 9       ...                  9.4  Micrograms/cubic meter (LC)         24 HOUR
# 10      ...                 16.8  Micrograms/cubic meter (LC)         24 HOUR
# 11      ...                  4.8  Micrograms/cubic meter (LC)         24 HOUR
# 12      ...                 13.7  Micrograms/cubic meter (LC)         24 HOUR
# 13      ...                 16.2  Micrograms/cubic meter (LC)         24 HOUR
# 14      ...                  7.1  Micrograms/cubic meter (LC)         24 HOUR
# 15      ...                 15.9  Micrograms/cubic meter (LC)         24 HOUR
# 16      ...                  7.3  Micrograms/cubic meter (LC)         24 HOUR
# 17      ...                    6  Micrograms/cubic meter (LC)         24 HOUR
# 18      ...                  6.2  Micrograms/cubic meter (LC)         24 HOUR
# 19      ...                  4.6  Micrograms/cubic meter (LC)         24 HOUR
# 20      ...                 18.7  Micrograms/cubic meter (LC)         24 HOUR
# 21      ...                  3.8  Micrograms/cubic meter (LC)         24 HOUR
# 22      ...                  9.2  Micrograms/cubic meter (LC)         24 HOUR
# 23      ...                 16.8  Micrograms/cubic meter (LC)         24 HOUR
# 24      ...                  5.2  Micrograms/cubic meter (LC)         24 HOUR
# 25      ...                 13.8  Micrograms/cubic meter (LC)         24 HOUR
# 26      ...                  1.5  Micrograms/cubic meter (LC)         24 HOUR
# 27      ...                  4.4  Micrograms/cubic meter (LC)         24 HOUR
# 28      ...                  5.8  Micrograms/cubic meter (LC)         24 HOUR
# 29      ...                 15.5  Micrograms/cubic meter (LC)         24 HOUR
# ...     ...                  ...                          ...             ...
# 318368  ...                  6.3  Micrograms/cubic meter (LC)         24 HOUR
# 318369  ...                  7.5  Micrograms/cubic meter (LC)         24 HOUR
# 318370  ...                  8.3  Micrograms/cubic meter (LC)         24 HOUR
# 318371  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 318372  ...                    2  Micrograms/cubic meter (LC)         24 HOUR
# 318373  ...                 14.9  Micrograms/cubic meter (LC)         24 HOUR
# 318374  ...                 39.4  Micrograms/cubic meter (LC)         24 HOUR
# 318375  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 318376  ...                  2.6  Micrograms/cubic meter (LC)         24 HOUR
# 318377  ...                  7.9  Micrograms/cubic meter (LC)         24 HOUR
# 318378  ...                  2.9  Micrograms/cubic meter (LC)         24 HOUR
# 318379  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 318380  ...                  3.1  Micrograms/cubic meter (LC)         24 HOUR
# 318381  ...                  7.1  Micrograms/cubic meter (LC)         24 HOUR
# 318382  ...                  2.7  Micrograms/cubic meter (LC)         24 HOUR
# 318383  ...                    4  Micrograms/cubic meter (LC)         24 HOUR
# 318384  ...                  3.7  Micrograms/cubic meter (LC)         24 HOUR
# 318385  ...                  5.1  Micrograms/cubic meter (LC)         24 HOUR
# 318386  ...                  3.8  Micrograms/cubic meter (LC)         24 HOUR
# 318387  ...                  5.8  Micrograms/cubic meter (LC)         24 HOUR
# 318388  ...                 10.7  Micrograms/cubic meter (LC)         24 HOUR
# 318389  ...                  6.6  Micrograms/cubic meter (LC)         24 HOUR
# 318390  ...                  6.8  Micrograms/cubic meter (LC)         24 HOUR
# 318391  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 318392  ...                  4.8  Micrograms/cubic meter (LC)         24 HOUR
# 318393  ...                    1  Micrograms/cubic meter (LC)         24 HOUR
# 318394  ...                 16.2  Micrograms/cubic meter (LC)         24 HOUR
# 318395  ...                 10.2  Micrograms/cubic meter (LC)         24 HOUR
# 318396  ...                 None                         None            None
# 318397  ...                 None                         None            None
#
#        Sample Frequency Detection Limit Measurement Uncertainty  \
# 0             EVERY DAY               2
# 1             EVERY DAY               2
# 2             EVERY DAY               2
# 3             EVERY DAY               2
# 4             EVERY DAY               2
# 5             EVERY DAY               2
# 6             EVERY DAY               2
# 7             EVERY DAY               2
# 8             EVERY DAY               2
# 9             EVERY DAY               2
# 10            EVERY DAY               2
# 11            EVERY DAY               2
# 12            EVERY DAY               2
# 13            EVERY DAY               2
# 14            EVERY DAY               2
# 15            EVERY DAY               2
# 16            EVERY DAY               2
# 17            EVERY DAY               2
# 18            EVERY DAY               2
# 19            EVERY DAY               2
# 20            EVERY DAY               2
# 21            EVERY DAY               2
# 22            EVERY DAY               2
# 23            EVERY DAY               2
# 24            EVERY DAY               2
# 25            EVERY DAY               2
# 26            EVERY DAY               2
# 27            EVERY DAY               2
# 28            EVERY DAY               2
# 29            EVERY DAY               2
# ...                 ...             ...                     ...
# 318368    EVERY 6TH DAY               2
# 318369    EVERY 6TH DAY               2
# 318370    EVERY 6TH DAY               2
# 318371    EVERY 6TH DAY               2
# 318372    EVERY 6TH DAY               2
# 318373    EVERY 6TH DAY               2
# 318374    EVERY 6TH DAY               2
# 318375    EVERY 6TH DAY               2
# 318376    EVERY 6TH DAY               2
# 318377    EVERY 6TH DAY               2
# 318378    EVERY 6TH DAY               2
# 318379    EVERY 6TH DAY               2
# 318380    EVERY 6TH DAY               2
# 318381    EVERY 6TH DAY               2
# 318382    EVERY 6TH DAY               2
# 318383    EVERY 6TH DAY               2
# 318384    EVERY 6TH DAY               2
# 318385    EVERY 6TH DAY               2
# 318386    EVERY 6TH DAY               2
# 318387    EVERY 6TH DAY               2
# 318388    EVERY 6TH DAY               2
# 318389    EVERY 6TH DAY               2
# 318390    EVERY 6TH DAY               2
# 318391    EVERY 6TH DAY               2
# 318392    EVERY 6TH DAY               2
# 318393    EVERY 6TH DAY               2
# 318394    EVERY 6TH DAY               2
# 318395    EVERY 6TH DAY               2
# 318396             None            None                    None
# 318397             None            None                    None
#
#        Qualifier Description Method Type  \
# 0                              Reference
# 1                              Reference
# 2                              Reference
# 3                              Reference
# 4                              Reference
# 5                              Reference
# 6                              Reference
# 7                              Reference
# 8                              Reference
# 9                              Reference
# 10                             Reference
# 11                             Reference
# 12                             Reference
# 13                             Reference
# 14                             Reference
# 15                             Reference
# 16                             Reference
# 17                             Reference
# 18                             Reference
# 19                             Reference
# 20                             Reference
# 21                             Reference
# 22                             Reference
# 23                             Reference
# 24                             Reference
# 25                             Reference
# 26                             Reference
# 27                             Reference
# 28                             Reference
# 29                             Reference
# ...                      ...         ...
# 318368                         Reference
# 318369                         Reference
# 318370                         Reference
# 318371                         Reference
# 318372                         Reference
# 318373                         Reference
# 318374                         Reference
# 318375                         Reference
# 318376                         Reference
# 318377                         Reference
# 318378                         Reference
# 318379            High Winds   Reference
# 318380                         Reference
# 318381                         Reference
# 318382                         Reference
# 318383                         Reference
# 318384                         Reference
# 318385                         Reference
# 318386            High Winds   Reference
# 318387                         Reference
# 318388                         Reference
# 318389                         Reference
# 318390                         Reference
# 318391                         Reference
# 318392                         Reference
# 318393                         Reference
# 318394                         Reference
# 318395                         Reference
# 318396                  None        None
# 318397                  None        None
#
#                                        Method Description   FIPS
# 0       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 1       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 2       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 3       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 4       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 5       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 6       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 7       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 8       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 9       R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 10      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 11      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 12      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 13      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 14      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 15      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 16      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 17      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 18      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 19      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 20      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 21      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 22      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 23      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 24      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 25      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 26      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 27      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 28      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# 29      R & P Model 2025 PM-2.5 Sequential Air Sampler...  06001
# ...                                                   ...    ...
# 318368  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318369  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318370  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318371  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318372  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318373  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318374  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318375  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318376  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318377  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318378  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318379  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318380  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318381  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318382  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318383  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318384  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318385  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318386  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318387  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318388  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318389  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318390  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318391  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318392  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318393  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318394  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318395  R & P Model 2025 PM2.5 Sequential w/WINS-GRAVI...  06113
# 318396                                               None    NaN
# 318397                                               None    NaN
#
# [318398 rows x 26 columns]

# %%
countyname = { "001": "Alameda", "003": "Apline", "005": "Amador", "007":"Butte", "009":"Calaveras", "011": "Colusa", "013":"Contra Costa", "015":"Del Norte", "017":"El Dorado", "019": "Fresno", "021": "Glenn", "023": "Humboldt", "025": "Imperial", "027": "Inyo", "029": "Kern", "031": "Kings", "033":"Lake", "035": "Lassen", "037": "Los Angeles", "039": "Madera", "041": "Marin", "043": "Mariposa", "045": "Mendicino", "047": "Merced", "049": "Modoc", "051": "Mono", "053": "Monterey", "055": "Napa", "057": "Nevada", "059": "Orange", "061": "Placer", "063": "Plumas", "065": "Riverside", "067": "Sacramento", "069": "San Benito", "071": "San Bernardino", "073": "San Diego", "075": "San Francisco", "077": "San Joaquin", "079": "San Luis Obispo", "081": "San Mateo", "083": "Santa Barbara", "085": "Santa Clara", "087": "Santa Cruz", "089": "Shasta", "091": "Sierra", "093": "Siskiyou", "095": "Solano", "097": "Sonoma", "099": "Stanislaus", "101": "Sutter", "103": "Tehama", "105": "Trinity", "107": "Tulare", "109": "Tuolumne", "111": "Ventura", "113": "Yolo", "115": "Yuba"}

df_trim = data_2011[['County Code','Date Local','24 Hour Local','Date GMT','Sample Measurement', "Sample Frequency",'Units of Measure','Sample Duration', "Latitude", "Longitude", "FIPS"]]
df_trim["County Names"] = df_trim["County Code"].map(countyname)
df_trim
# Out:
#        County Code  Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 0              001  2011-01-18         00:00  2011-01-18                6.6
# 1              001  2011-01-21         00:00  2011-01-21               23.6
# 2              001  2011-01-01         00:00  2011-01-01               10.5
# 3              001  2011-01-31         00:00  2011-01-31                8.5
# 4              001  2011-02-14         00:00  2011-02-14                  3
# 5              001  2011-02-23         00:00  2011-02-23                4.7
# 6              001  2011-02-01         00:00  2011-02-01                2.6
# 7              001  2011-02-08         00:00  2011-02-08                  1
# 8              001  2011-02-18         00:00  2011-02-18                2.5
# 9              001  2011-01-23         00:00  2011-01-23                9.4
# 10             001  2011-02-13         00:00  2011-02-13               16.8
# 11             001  2011-01-29         00:00  2011-01-29                4.8
# 12             001  2011-02-04         00:00  2011-02-04               13.7
# 13             001  2011-01-07         00:00  2011-01-07               16.2
# 14             001  2011-02-20         00:00  2011-02-20                7.1
# 15             001  2011-02-12         00:00  2011-02-12               15.9
# 16             001  2011-02-10         00:00  2011-02-10                7.3
# 17             001  2011-02-28         00:00  2011-02-28                  6
# 18             001  2011-01-19         00:00  2011-01-19                6.2
# 19             001  2011-01-02         00:00  2011-01-02                4.6
# 20             001  2011-01-05         00:00  2011-01-05               18.7
# 21             001  2011-02-19         00:00  2011-02-19                3.8
# 22             001  2011-02-26         00:00  2011-02-26                9.2
# 23             001  2011-01-13         00:00  2011-01-13               16.8
# 24             001  2011-02-22         00:00  2011-02-22                5.2
# 25             001  2011-01-06         00:00  2011-01-06               13.8
# 26             001  2011-02-17         00:00  2011-02-17                1.5
# 27             001  2011-02-05         00:00  2011-02-05                4.4
# 28             001  2011-02-07         00:00  2011-02-07                5.8
# 29             001  2011-01-20         00:00  2011-01-20               15.5
# ...            ...         ...           ...         ...                ...
# 318368         113  2011-04-15         00:00  2011-04-15                6.3
# 318369         113  2011-08-13         00:00  2011-08-13                7.5
# 318370         113  2011-11-29         00:00  2011-11-29                8.3
# 318371         113  2011-03-28         00:00  2011-03-28                  1
# 318372         113  2011-06-02         00:00  2011-06-02                  2
# 318373         113  2011-01-21         00:00  2011-01-21               14.9
# 318374         113  2011-12-29         00:00  2011-12-29               39.4
# 318375         113  2011-02-08         00:00  2011-02-08                  1
# 318376         113  2011-02-26         00:00  2011-02-26                2.6
# 318377         113  2011-10-18         00:00  2011-10-18                7.9
# 318378         113  2011-03-10         00:00  2011-03-10                2.9
# 318379         113  2011-03-22         00:00  2011-03-22                  1
# 318380         113  2011-02-02         00:00  2011-02-02                3.1
# 318381         113  2011-07-26         00:00  2011-07-26                7.1
# 318382         113  2011-03-04         00:00  2011-03-04                2.7
# 318383         113  2011-09-24         00:00  2011-09-24                  4
# 318384         113  2011-06-20         00:00  2011-06-20                3.7
# 318385         113  2011-08-07         00:00  2011-08-07                5.1
# 318386         113  2011-02-14         00:00  2011-02-14                3.8
# 318387         113  2011-11-05         00:00  2011-11-05                5.8
# 318388         113  2011-10-13         00:00  2011-10-13               10.7
# 318389         113  2011-12-05         00:00  2011-12-05                6.6
# 318390         113  2011-06-08         00:00  2011-06-08                6.8
# 318391         113  2011-05-15         00:00  2011-05-15                  1
# 318392         113  2011-07-14         00:00  2011-07-14                4.8
# 318393         113  2011-12-01         00:00  2011-12-01                  1
# 318394         113  2011-10-30         00:00  2011-10-30               16.2
# 318395         113  2011-10-24         00:00  2011-10-24               10.2
# 318396        None        None          None        None               None
# 318397        None        None          None        None               None
#
#        Sample Frequency             Units of Measure Sample Duration  \
# 0             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 1             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 2             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 3             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 4             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 5             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 6             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 7             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 8             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 9             EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 10            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 11            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 12            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 13            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 14            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 15            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 16            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 17            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 18            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 19            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 20            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 21            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 22            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 23            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 24            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 25            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 26            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 27            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 28            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# 29            EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR
# ...                 ...                          ...             ...
# 318368    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318369    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318370    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318371    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318372    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318373    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318374    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318375    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318376    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318377    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318378    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318379    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318380    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318381    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318382    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318383    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318384    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318385    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318386    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318387    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318388    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318389    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318390    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318391    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318392    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318393    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318394    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318395    EVERY 6TH DAY  Micrograms/cubic meter (LC)         24 HOUR
# 318396             None                         None            None
# 318397             None                         None            None
#
#            Latitude    Longitude   FIPS County Names
# 0         37.687526  -121.784217  06001      Alameda
# 1         37.687526  -121.784217  06001      Alameda
# 2         37.687526  -121.784217  06001      Alameda
# 3         37.687526  -121.784217  06001      Alameda
# 4         37.687526  -121.784217  06001      Alameda
# 5         37.687526  -121.784217  06001      Alameda
# 6         37.687526  -121.784217  06001      Alameda
# 7         37.687526  -121.784217  06001      Alameda
# 8         37.687526  -121.784217  06001      Alameda
# 9         37.687526  -121.784217  06001      Alameda
# 10        37.687526  -121.784217  06001      Alameda
# 11        37.687526  -121.784217  06001      Alameda
# 12        37.687526  -121.784217  06001      Alameda
# 13        37.687526  -121.784217  06001      Alameda
# 14        37.687526  -121.784217  06001      Alameda
# 15        37.687526  -121.784217  06001      Alameda
# 16        37.687526  -121.784217  06001      Alameda
# 17        37.687526  -121.784217  06001      Alameda
# 18        37.687526  -121.784217  06001      Alameda
# 19        37.687526  -121.784217  06001      Alameda
# 20        37.687526  -121.784217  06001      Alameda
# 21        37.687526  -121.784217  06001      Alameda
# 22        37.687526  -121.784217  06001      Alameda
# 23        37.687526  -121.784217  06001      Alameda
# 24        37.687526  -121.784217  06001      Alameda
# 25        37.687526  -121.784217  06001      Alameda
# 26        37.687526  -121.784217  06001      Alameda
# 27        37.687526  -121.784217  06001      Alameda
# 28        37.687526  -121.784217  06001      Alameda
# 29        37.687526  -121.784217  06001      Alameda
# ...             ...          ...    ...          ...
# 318368     38.66121   -121.73269  06113         Yolo
# 318369     38.66121   -121.73269  06113         Yolo
# 318370     38.66121   -121.73269  06113         Yolo
# 318371     38.66121   -121.73269  06113         Yolo
# 318372     38.66121   -121.73269  06113         Yolo
# 318373     38.66121   -121.73269  06113         Yolo
# 318374     38.66121   -121.73269  06113         Yolo
# 318375     38.66121   -121.73269  06113         Yolo
# 318376     38.66121   -121.73269  06113         Yolo
# 318377     38.66121   -121.73269  06113         Yolo
# 318378     38.66121   -121.73269  06113         Yolo
# 318379     38.66121   -121.73269  06113         Yolo
# 318380     38.66121   -121.73269  06113         Yolo
# 318381     38.66121   -121.73269  06113         Yolo
# 318382     38.66121   -121.73269  06113         Yolo
# 318383     38.66121   -121.73269  06113         Yolo
# 318384     38.66121   -121.73269  06113         Yolo
# 318385     38.66121   -121.73269  06113         Yolo
# 318386     38.66121   -121.73269  06113         Yolo
# 318387     38.66121   -121.73269  06113         Yolo
# 318388     38.66121   -121.73269  06113         Yolo
# 318389     38.66121   -121.73269  06113         Yolo
# 318390     38.66121   -121.73269  06113         Yolo
# 318391     38.66121   -121.73269  06113         Yolo
# 318392     38.66121   -121.73269  06113         Yolo
# 318393     38.66121   -121.73269  06113         Yolo
# 318394     38.66121   -121.73269  06113         Yolo
# 318395     38.66121   -121.73269  06113         Yolo
# 318396  END OF FILE         None    NaN          NaN
# 318397  END OF FILE         None    NaN          NaN
#
# [318398 rows x 12 columns]

# %%
#Create 2 dataframes to hold records for sampling done by 24 hour duration and 1 hour duration
hour1_df = df_trim.loc[(df_trim["Sample Duration"]== "1 HOUR")]
hour24_df = df_trim.loc[(df_trim["Sample Duration"]== "24 HOUR")]

#See which sampling duration has more unique counties
hour1_df["County Names"].nunique()
hour24_df["County Names"].nunique()
# Out:
# 32

# %%
#Convert 'Date Local' column to datetime to extract month #
hour1_df['Date Local'] = pd.to_datetime(hour1_df['Date Local'])

#Creating column for Month # for 1hour sample duration df
hour1_df['Month'] = pd.DatetimeIndex(hour1_df['Date Local']).month
hour1_df["Month"].fillna(0)
hour1_df["Month"].astype(float)
hour1_df.fillna(0)
hour1_df["County Names"].dtype

#Convert 'Date Local' column to datetime to extract month #
hour24_df['Date Local'] = pd.to_datetime(hour24_df['Date Local'])

#Creating column for Month # for 24 hour sample duration df
hour24_df['Month'] = pd.DatetimeIndex(hour24_df['Date Local']).month
hour24_df["Month"].fillna(0)
hour24_df["Month"].astype(float)
hour24_df.fillna(0)
hour24_df.head()
# Out:
#   County Code Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 0         001 2011-01-18         00:00  2011-01-18                6.6
# 1         001 2011-01-21         00:00  2011-01-21               23.6
# 2         001 2011-01-01         00:00  2011-01-01               10.5
# 3         001 2011-01-31         00:00  2011-01-31                8.5
# 4         001 2011-02-14         00:00  2011-02-14                  3
#
#   Sample Frequency             Units of Measure Sample Duration   Latitude  \
# 0        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  37.687526
# 1        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  37.687526
# 2        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  37.687526
# 3        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  37.687526
# 4        EVERY DAY  Micrograms/cubic meter (LC)         24 HOUR  37.687526
#
#      Longitude   FIPS County Names  Month
# 0  -121.784217  06001      Alameda      1
# 1  -121.784217  06001      Alameda      1
# 2  -121.784217  06001      Alameda      1
# 3  -121.784217  06001      Alameda      1
# 4  -121.784217  06001      Alameda      2

# %%
#extract only relevant columns and create a groupby df (for 24 hour sample duration)
mday_df = hour24_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mday_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuff24 = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuff24
mday_df["PM2.5 Values 2011"] = tuff24
finalday = mday_df
finalday.drop(columns="Sample Measurement")
#finalday
finalday.to_csv("2011CA24hrPM2.5.csv")

# %%
#groupby to graph results
county_date24hr = pd.DataFrame(finalday.groupby(['County Names', 'Month']).mean())
county_date24hr.head()
# Out:
#                     PM2.5 Values 2011
# County Names Month
# Alameda      1              13.246667
#              2               6.171429
# Butte        1              29.920000
#              2              11.560000
#              3               4.460000

# %%
county_date24hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2011 (24hr Sampling Duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2011 PM2.5 AVG (24hr Sampling).png", bbox_inches='tight')
plt.figure()

# %%
# extract only relevant columns and create a groupby df
mhour_df = hour1_df.loc[:, ['County Names', 'Month', "Sample Measurement", "Latitude", "Longitude", "FIPS"]]
mhour_df["Sample Measurement"].astype(float)

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mhour_df["Sample Measurement"], errors='coerce')
tuffhour_df
mhour_df["PM2.5 Values 2011"] = tuffhour_df
finalhour = mhour_df
finalhour.drop(columns="Sample Measurement")

#Convert column dtype: "O" to numeric for groupby functionality 
tuffhour_df = pd.to_numeric(mday_df["Sample Measurement"], errors='coerce')
tuffhour_df
mday_df["PM2.5 Values 2011"] = tuffhour_df
finalhour = mday_df
finalhour.drop(columns="Sample Measurement")

finalday.to_csv("2011CA1hrPM2.5.csv")

# %%
#groupby to graph results
county_1hr = pd.DataFrame(finalhour.groupby(['County Names', 'Month']).mean())
county_1hr.head()
# Out:
#                     PM2.5 Values 2011
# County Names Month
# Alameda      1              13.246667
#              2               6.171429
# Butte        1              29.920000
#              2              11.560000
#              3               4.460000

# %%
county_1hr.unstack(0).plot(figsize = (10,10))
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.title("Graph of PM2.5 Monthly Averages in CA Counties 2011 (1Hr Sampling duration)")
plt.ylabel("PM2.5 Mean Per Month")
plt.xlabel("Month")
plt.savefig("2011 PM2.5 AVG (1hrSampling).png", bbox_inches='tight')
plt.figure()

# %%
#Find Max for 24hr sampling group
max_pm25 = county_date24hr['PM2.5 Values 2011'].max()
max_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2011'] == max_pm25,:]
max_county24hr

#Find Max for 1hr sampling group
max_pm25 = county_1hr['PM2.5 Values 2011'].max()
max_1hr = county_1hr.loc[county_1hr['PM2.5 Values 2011'] == max_pm25,:]
max_1hr
# Out:
#                     PM2.5 Values 2011
# County Names Month
# Fresno       12             50.695349

# %%
#Find Min
min_pm25 = county_date24hr['PM2.5 Values 2011'].min()
min_county24hr = county_date24hr.loc[county_date24hr['PM2.5 Values 2011'] == min_pm25,:]
min_county24hr

#min_pm25 = county_1hr['PM2.5 Values 2011'].min()
min_county1hr = county_1hr.loc[county_1hr['PM2.5 Values 2011'] == min_pm25,:]
min_county1hr
# Out:
#                     PM2.5 Values 2011
# County Names Month
# Lake         2                   1.86

# %%
# create a df with only the Max & Min, and SD/LA for ref counties
minmax_df = finalday.loc[(finalday['County Names']=='Lake') | (finalday['County Names']=='Fresno') | (finalday['County Names']=='San Diego') | (finalday['County Names']=='Los Angeles'),:]
minmax_df.head()
# Out:
#       County Names  Month Sample Measurement   Latitude   Longitude   FIPS  \
# 32216       Fresno      7                9.8  36.781333  -119.77319  06019
# 32217       Fresno     11               22.1  36.781333  -119.77319  06019
# 32218       Fresno      4                4.8  36.781333  -119.77319  06019
# 32219       Fresno     12               78.5  36.781333  -119.77319  06019
# 32220       Fresno     10                3.5  36.781333  -119.77319  06019
#
#        PM2.5 Values 2011
# 32216                9.8
# 32217               22.1
# 32218                4.8
# 32219               78.5
# 32220                3.5

# %%
mm_mean_df = minmax_df.loc[:, ['County Names', 'Month', 'PM2.5 Values 2011']]
mm_df = pd.DataFrame(mm_mean_df.groupby(['County Names', 'Month']).mean())
mm_df.head()
# Out:
#                     PM2.5 Values 2011
# County Names Month
# Fresno       1              26.130435
#              2              15.402564
#              3               7.228261
#              4               5.620588
#              5               6.266667

# %%
mm_df.unstack(0).plot(figsize = (10,10))
plt.title("Graph of PM2.5 Max & Min in CA + San Diego & Los Angeles 2011")
plt.xlabel('Month')
plt.ylabel('PM2.5 Mean/Month')
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 0.5))
plt.savefig("2011_CA_MaxMin_SDLA.png", bbox_inches='tight') 
plt.figure()

# %%
county_final = pd.DataFrame(finalday.groupby(['FIPS']).mean())
county_sum = county_final.drop(columns=["Month"], )
#county_sum.to_csv('2011_CA_PM25_Mean.csv')
county_sum
county_sum.sort_values(by=["PM2.5 Values 2011"], ascending=False)
#county_sum.to_csv('2011_CA_PM25_Sum.csv')
# Out:
#        PM2.5 Values 2011
# FIPS
# 06107          16.375893
# 06019          15.716427
# 06029          13.953143
# 06099          12.860000
# 06095          12.709615
# 06065          12.101868
# 06007          12.003279
# 06037          11.831937
# 06047          11.467059
# 06063          11.446320
# 06071          11.093348
# 06085          10.931356
# 06067          10.444872
# 06073          10.371515
# 06059          10.358658
# 06001           9.831034
# 06025           9.759794
# 06111           8.644310
# 06061           8.462295
# 06013           8.458423
# 06081           8.206667
# 06101           8.134277
# 06113           7.466102
# 06027           7.420290
# 06011           7.029630
# 06023           6.792208
# 06093           5.564516
# 06089           5.169643
# 06053           4.886441
# 06057           4.676471
# 06079           4.264286
# 06033           3.518033

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
plotly.tools.set_credentials_file(username="UserNameHere", api_key="YourAPIkeyHere")

# %%
values = county_sum["PM2.5 Values 2011"].tolist()
fips = county_sum.index.values
print(values)
# Out:
# [9.83103448275862, 12.003278688524587, 7.029629629629631, 8.458422939068095, 15.716427104722808, 6.79220779220779, 9.759793814432985, 7.420289855072464, 13.953142857142852, 3.518032786885246, 11.831937436932378, 11.467058823529415, 4.8864406779661005, 4.676470588235293, 10.358658008658, 8.462295081967214, 11.446320346320357, 12.101867572156207, 10.444871794871808, 11.09334763948498, 10.371515151515142, 4.264285714285714, 8.206666666666669, 10.931355932203388, 5.169642857142858, 5.564516129032262, 12.709615384615386, 12.859999999999998, 8.134276729559746, 16.37589285714285, 8.644309927360771, 7.466101694915255]

# %%
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['CA'],
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='PM2.5 by County', title='California PM2.5 2011 By County'
)
py.iplot(fig, filename='CA_PM2.5 2011')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~tonyphelps/0 or inside your plot.ly account where it is named 'CA_PM2.5 2011'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tonyphelps/0.embed" height="450px" width="900px"></iframe>
