# %%
#import dependencies

import plotly.plotly as py
import plotly.figure_factory as ff

import pandas as pd
import requests as req
#create separate file with individual log in credentials to be imported
from config import (user_id_aqs, password_aqs)
import csv
import matplotlib.pyplot as plt

# %%
asthmacsv = "ASTHMA20112016.csv"
asthma_df = pd.read_csv(asthmacsv)
asthma_df
# Out:
#        County Names        2011        2012        2013        2014  \
# 0           Alameda   70.917391   79.173913   81.721739  128.500000
# 1            Amador   78.483333   87.500000   84.684615   66.728571
# 2             Butte   72.733333   70.563158   70.825000   80.825000
# 3         Calaveras   66.508333   45.266667   60.884615   61.607143
# 4            Colusa   38.978571   39.085714   52.925000   46.178571
# 5      Contra Costa   93.234783   95.360870   85.095455   87.113043
# 6         Del Norte   83.337500   84.746667   63.771429   64.833333
# 7         El Dorado   38.443750   72.529412   39.562500   52.550000
# 8            Fresno   81.352174   92.133333   89.590476   83.345455
# 9             Glenn   48.685714   39.400000   44.442857   44.946667
# 10         Humboldt   83.214286   91.400000   97.145000   98.150000
# 11         Imperial   91.535294  125.038889  100.350000   95.056250
# 12             Inyo   64.407143   61.050000   62.866667   69.062500
# ...

# %%
asthma_2011 = asthma_df["2011"]
asthma_2012 = asthma_df["2012"]
asthma_2013 = asthma_df["2013"]
asthma_2014 = asthma_df["2014"]
asthma_2015 = asthma_df["2015"]
asthma_2016 = asthma_df["2016"]
abc = asthma_df.groupby("FIPS").mean()
abc
# Out:
#             2011        2012        2013        2014        2015        2016
# FIPS
# 6001   70.917391   79.173913   81.721739  128.500000  132.358333   79.700000
# 6005   78.483333   87.500000   84.684615   66.728571   63.033333   71.020000
# 6007   72.733333   70.563158   70.825000   80.825000   89.030000   68.961111
# 6009   66.508333   45.266667   60.884615   61.607143   48.040000   50.427273
# 6011   38.978571   39.085714   52.925000   46.178571   48.160000   32.015385
# 6013   93.234783   95.360870   85.095455   87.113043   84.140909   78.377273
# 6015   83.337500   84.746667   63.771429   64.833333   61.642857   85.978571
# 6017   38.443750   72.529412   39.562500   52.550000   43.105882   39.205882
# 6019   81.352174   92.133333   89.590476   83.345455   95.057143   88.590909
# 6021   48.685714   39.400000   44.442857   44.946667   43.760000   39.173333
# 6023   83.214286   91.400000   97.145000   98.150000   85.425000  116.457143
# ...

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
plotly.tools.set_credentials_file(username='yourAPIusername', api_key='yourAPIkey')

# %%
values = asthma_2012.tolist()
fips = abc.index.values
print(fips)
# Out:
# [6001 6005 6007 6009 6011 6013 6015 6017 6019 6021 6023 6025 6027 6029
#  6031 6033 6035 6037 6039 6041 6043 6045 6047 6049 6051 6053 6055 6057
#  6059 6061 6063 6065 6067 6069 6071 6073 6075 6077 6079 6081 6083 6085
#  6087 6089 6091 6093 6095 6097 6099 6101 6103 6105 6107 6109 6111 6113
#  6115]

# %%
fig = ff.create_choropleth(
    fips=fips, values=values, scope=['CA'],
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='Asthma Rates per 10,000 people', title='California Asthma Rates per County 2012'
)
py.iplot(fig, filename='California Asthma in Counties 2012')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tpmoney/46.embed" height="450px" width="900px"></iframe>

# %%
# Out:
# [0.3229925247166665, 0.2785836594911889, 0.32607563496515, 0.32381937792748544, 0.32591826604895696, 0.5922505712109728, 0.41444252278804533, 0.39216838570402457, 0.3889177693762108, 0.5015901698590736, 0.3051220295440037, 0.3132009454862082, 0.3775033678133182, 0.36421597369159747, 0.475121876827932, 0.2433849106393138, 0.2435787145139429, 0.49267188646932003, 0.18984820755734885, 0.3657989041441048, 0.4106940935883599, 0.4299124805179471, 0.30256315007429213]

# %%
#colorscale = [
#    'rgb(193, 193, 193)',
#    'rgb(239,239,239)',
#    'rgb(195, 196, 222)',
#    'rgb(144,148,194)',
#    'rgb(101,104,168)',
#    'rgb(65, 53, 132)'
#]

fig = ff.create_choropleth(
    fips=fips, values=values, scope=['CA'],
    county_outline={'color': 'rgb(255,255,255)', 'width': 0.5}, round_legend_values=True,
    legend_title='CO by County', title='California CO 2011 By County'
)
py.iplot(fig, filename='choropleth_california_CO 2011')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tpmoney/8.embed" height="450px" width="900px"></iframe>

# %%
fig = ff.create_choropleth(fips=fips, values=values)
py.iplot(fig, filename='CA PM2.5 2011')
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~tpmoney/2.embed" height="450px" width="900px"></iframe>
