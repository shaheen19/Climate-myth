# %%
# Dependencies
# %matplotlib inline
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import datetime
import numpy as np
from scipy.stats import linregress, stats
from textwrap import wrap

# %% [markdown]
# ## Ozone Data Collection/Clean-up

# %%
# Import excel sheets as data frames
xls = pd.ExcelFile('Resources/CA-daily_O3_ppb_2010-2016_Ruby.xlsx', )
ozone_2010 = pd.read_excel(xls, '2010', encoding='utf8')
ozone_2011 = pd.read_excel(xls, '2011', encoding='utf8')
ozone_2012 = pd.read_excel(xls, '2012', encoding='utf8')
ozone_2013 = pd.read_excel(xls, '2013', encoding='utf8')
ozone_2014 = pd.read_excel(xls, '2014', encoding='utf8')
ozone_2015 = pd.read_excel(xls, '2015', encoding='utf8')
ozone_2016 = pd.read_excel(xls, '2016', encoding='utf8')
ozone_2010.head(10)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           6            1         7           44201    1  37.687526
# 1           6            1         7           44201    1  37.687526
# 2           6            1         7           44201    1  37.687526
# 3           6            1         7           44201    1  37.687526
# 4           6            1         7           44201    1  37.687526
# 5           6            1         7           44201    1  37.687526
# 6           6            1         7           44201    1  37.687526
# 7           6            1         7           44201    1  37.687526
# 8           6            1         7           44201    1  37.687526
# 9           6            1         7           44201    1  37.687526
#
#     Longitude  Datum Parameter Name          Sample Duration  \
# 0 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 1 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 2 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 3 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 4 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 5 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 6 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 7 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 8 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 9 -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
#
#           ...          AQI Method Code Method Name Local Site Name  \
# 0         ...           15         NaN          -        Livermore
# 1         ...           17         NaN          -        Livermore
# 2         ...           17         NaN          -        Livermore
# 3         ...           13         NaN          -        Livermore
# 4         ...            8         NaN          -        Livermore
# 5         ...            6         NaN          -        Livermore
# 6         ...            4         NaN          -        Livermore
# 7         ...            2         NaN          -        Livermore
# 8         ...            5         NaN          -        Livermore
# 9         ...            8         NaN          -        Livermore
#
#            Address  State Name  County Name  City Name  \
# 0  793 Rincon Ave.  California      Alameda  Livermore
# 1  793 Rincon Ave.  California      Alameda  Livermore
# 2  793 Rincon Ave.  California      Alameda  Livermore
# 3  793 Rincon Ave.  California      Alameda  Livermore
# 4  793 Rincon Ave.  California      Alameda  Livermore
# 5  793 Rincon Ave.  California      Alameda  Livermore
# 6  793 Rincon Ave.  California      Alameda  Livermore
# 7  793 Rincon Ave.  California      Alameda  Livermore
# 8  793 Rincon Ave.  California      Alameda  Livermore
# 9  793 Rincon Ave.  California      Alameda  Livermore
#
#                            CBSA Name  Date of Last Change
# 0  San Francisco-Oakland-Hayward, CA                42473
# 1  San Francisco-Oakland-Hayward, CA                42473
# 2  San Francisco-Oakland-Hayward, CA                42473
# 3  San Francisco-Oakland-Hayward, CA                42473
# 4  San Francisco-Oakland-Hayward, CA                42473
# 5  San Francisco-Oakland-Hayward, CA                42473
# 6  San Francisco-Oakland-Hayward, CA                42473
# 7  San Francisco-Oakland-Hayward, CA                42473
# 8  San Francisco-Oakland-Hayward, CA                42473
# 9  San Francisco-Oakland-Hayward, CA                42473
#
# [10 rows x 30 columns]

# %%
# display all columns
ozone_2010.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'O3_ppb', 'Arithmetic Mean',
#        '1st Max Value', '1st Max Hour', 'AQI', 'Method Code', 'Method Name',
#        'Local Site Name', 'Address', 'State Name', 'County Name', 'City Name',
#        'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
# use a for loop to remove extraneous columns from every df
sheets = [ozone_2010, ozone_2011, ozone_2012, ozone_2013, ozone_2014, ozone_2015, ozone_2016]
for df in sheets:
    df.drop(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
       'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
       'Pollutant Standard', 'Units of Measure', 'Event Type',
       'Observation Count', 'Observation Percent', 'Method Code', 'Method Name',
       'Local Site Name', 'Address', 'State Name', 'City Name',
       'CBSA Name', 'Date of Last Change'], axis=1, inplace=True)
ozone_2010.head()
# Out:
#   Date Local  O3_ppb  Arithmetic Mean  1st Max Value  1st Max Hour  AQI  \
# 0 2010-01-01   7.632         0.007632          0.018            10   15
# 1 2010-01-02  11.958         0.011958          0.020            11   17
# 2 2010-01-03  14.458         0.014458          0.020             9   17
# 3 2010-01-04   7.958         0.007958          0.015             9   13
# 4 2010-01-05   3.667         0.003667          0.010             9    8
#
#   County Name
# 0     Alameda
# 1     Alameda
# 2     Alameda
# 3     Alameda
# 4     Alameda

# %%
# change the format of 'Data Local' to datetime object in every object and
# create a new column that contains only the year
for df in sheets:
    df['Date Local'] = pd.to_datetime(df['Date Local'], format='%Y-%m-%d')
    df['Year'] = pd.DatetimeIndex(df['Date Local']).year

# %%
ozone_2011.head()
# Out:
#   Date Local  O3_ppb  Arithmetic Mean  1st Max Value  1st Max Hour  AQI  \
# 0 2011-01-01  17.292         0.017292          0.028            23   24
# 1 2011-01-02  22.792         0.022792          0.030             0   25
# 2 2011-01-03   9.917         0.009917          0.019             9   16
# 3 2011-01-04   6.750         0.006750          0.019            10   16
# 4 2011-01-05   6.292         0.006292          0.019            11   16
#
#   County Name  Year
# 0     Alameda  2011
# 1     Alameda  2011
# 2     Alameda  2011
# 3     Alameda  2011
# 4     Alameda  2011

# %%
# combine all individual dataframes into a single dataframe 
all_ozone = pd.concat(sheets, sort=False)
all_ozone
# Out:
#       Date Local  O3_ppb  Arithmetic Mean  1st Max Value  1st Max Hour  AQI  \
# 0     2010-01-01   7.632         0.007632          0.018            10   15
# 1     2010-01-02  11.958         0.011958          0.020            11   17
# 2     2010-01-03  14.458         0.014458          0.020             9   17
# 3     2010-01-04   7.958         0.007958          0.015             9   13
# 4     2010-01-05   3.667         0.003667          0.010             9    8
# 5     2010-01-06   2.167         0.002167          0.007            10    6
# 6     2010-01-07   1.667         0.001667          0.005             8    4
# 7     2010-01-08   1.083         0.001083          0.002             5    2
# 8     2010-01-09   2.292         0.002292          0.006             8    5
# 9     2010-01-10   3.333         0.003333          0.009            10    8
# 10    2010-01-11   1.708         0.001708          0.007            23    6
# 11    2010-01-12  23.167         0.023167          0.036            23   31
# 12    2010-01-13  24.917         0.024917          0.037            10   31
# 13    2010-01-14   9.917         0.009917          0.028            10   24
# 14    2010-01-15   1.750         0.001750          0.005             8    4
# 15    2010-01-16   2.750         0.002750          0.007             9    6
# 16    2010-01-17  20.042         0.020042          0.035            11   30
# 17    2010-01-18  35.583         0.035583          0.038             9   32
# 18    2010-01-19  39.167         0.039167          0.040            10   34
# 19    2010-01-20  38.231         0.038231          0.043            14   36
# 20    2010-01-21  26.375         0.026375          0.033            20   28
# 21    2010-01-22  17.542         0.017542          0.033             9   28
# 22    2010-01-23  12.708         0.012708          0.034             9   29
# 23    2010-01-24   7.917         0.007917          0.019            12   16
# 24    2010-01-25  13.292         0.013292          0.026            15   22
# 25    2010-01-26   6.667         0.006667          0.015            10   13
# 26    2010-01-27   3.292         0.003292          0.010            10    8
# 27    2010-01-28   3.333         0.003333          0.009             9    8
# 28    2010-01-29  14.500         0.014500          0.028            18   24
# 29    2010-01-30  15.125         0.015125          0.034            10   29
# ...          ...     ...              ...            ...           ...  ...
# 64011 2016-12-02  28.059         0.028059          0.034            10   31
# 64012 2016-12-03  15.588         0.015588          0.026            10   24
# 64013 2016-12-04  13.529         0.013529          0.027            10   25
# 64014 2016-12-05  11.118         0.011118          0.024             9   22
# 64015 2016-12-06  12.000         0.012000          0.022             9   20
# 64016 2016-12-07  24.588         0.024588          0.030            19   28
# 64017 2016-12-08  17.412         0.017412          0.020             7   19
# 64018 2016-12-09  15.294         0.015294          0.019            23   18
# 64019 2016-12-10  20.647         0.020647          0.026            16   24
# 64020 2016-12-11  10.765         0.010765          0.022             8   20
# 64021 2016-12-12  12.118         0.012118          0.023             9   21
# 64022 2016-12-13  12.529         0.012529          0.014            16   13
# 64023 2016-12-14  11.647         0.011647          0.013            10   12
# 64024 2016-12-15  20.882         0.020882          0.031            23   29
# 64025 2016-12-16  24.529         0.024529          0.033             8   31
# 64026 2016-12-17  19.765         0.019765          0.034             8   31
# 64027 2016-12-18  23.176         0.023176          0.036             9   33
# 64028 2016-12-19  11.529         0.011529          0.025             9   23
# 64029 2016-12-20  13.647         0.013647          0.024            10   22
# 64030 2016-12-21  13.882         0.013882          0.020            10   19
# 64031 2016-12-22  19.353         0.019353          0.027            10   25
# 64032 2016-12-23  25.941         0.025941          0.030             9   28
# 64033 2016-12-24  22.471         0.022471          0.028            11   26
# 64034 2016-12-25  19.235         0.019235          0.022            13   20
# 64035 2016-12-26  15.118         0.015118          0.028             9   26
# 64036 2016-12-27  10.529         0.010529          0.022             9   20
# 64037 2016-12-28  10.412         0.010412          0.023             9   21
# 64038 2016-12-29   8.824         0.008824          0.020             9   19
# 64039 2016-12-30  18.765         0.018765          0.022            19   20
# 64040 2016-12-31  22.083         0.022083          0.026            11   24
#
#       County Name  Year  Unnamed: 16
# 0         Alameda  2010          NaN
# 1         Alameda  2010          NaN
# 2         Alameda  2010          NaN
# 3         Alameda  2010          NaN
# 4         Alameda  2010          NaN
# 5         Alameda  2010          NaN
# 6         Alameda  2010          NaN
# 7         Alameda  2010          NaN
# 8         Alameda  2010          NaN
# 9         Alameda  2010          NaN
# 10        Alameda  2010          NaN
# 11        Alameda  2010          NaN
# 12        Alameda  2010          NaN
# 13        Alameda  2010          NaN
# 14        Alameda  2010          NaN
# 15        Alameda  2010          NaN
# 16        Alameda  2010          NaN
# 17        Alameda  2010          NaN
# 18        Alameda  2010          NaN
# 19        Alameda  2010          NaN
# 20        Alameda  2010          NaN
# 21        Alameda  2010          NaN
# 22        Alameda  2010          NaN
# 23        Alameda  2010          NaN
# 24        Alameda  2010          NaN
# 25        Alameda  2010          NaN
# 26        Alameda  2010          NaN
# 27        Alameda  2010          NaN
# 28        Alameda  2010          NaN
# 29        Alameda  2010          NaN
# ...           ...   ...          ...
# 64011        Yolo  2016          NaN
# 64012        Yolo  2016          NaN
# 64013        Yolo  2016          NaN
# 64014        Yolo  2016          NaN
# 64015        Yolo  2016          NaN
# 64016        Yolo  2016          NaN
# 64017        Yolo  2016          NaN
# 64018        Yolo  2016          NaN
# 64019        Yolo  2016          NaN
# 64020        Yolo  2016          NaN
# 64021        Yolo  2016          NaN
# 64022        Yolo  2016          NaN
# 64023        Yolo  2016          NaN
# 64024        Yolo  2016          NaN
# 64025        Yolo  2016          NaN
# 64026        Yolo  2016          NaN
# 64027        Yolo  2016          NaN
# 64028        Yolo  2016          NaN
# 64029        Yolo  2016          NaN
# 64030        Yolo  2016          NaN
# 64031        Yolo  2016          NaN
# 64032        Yolo  2016          NaN
# 64033        Yolo  2016          NaN
# 64034        Yolo  2016          NaN
# 64035        Yolo  2016          NaN
# 64036        Yolo  2016          NaN
# 64037        Yolo  2016          NaN
# 64038        Yolo  2016          NaN
# 64039        Yolo  2016          NaN
# 64040        Yolo  2016          NaN
#
# [439883 rows x 9 columns]

# %%
# select only the relevant columns 
all_ozone_conc = all_ozone[['County Name', 'O3_ppb', 'AQI', 'Year']]

# rename the columns
all_ozone_conc = all_ozone_conc.rename(columns={'County Name': 'County', 'O3_ppb': 'Ozone (ppb)'})

# display the new df
all_ozone_conc.head()
# Out:
#     County  Ozone (ppb)  AQI  Year
# 0  Alameda        7.632   15  2010
# 1  Alameda       11.958   17  2010
# 2  Alameda       14.458   17  2010
# 3  Alameda        7.958   13  2010
# 4  Alameda        3.667    8  2010

# %%
# create a new df by grouping the df by year and county and resetting the index
ozone_group = pd.DataFrame(all_ozone_conc.groupby(['Year', 'County']).mean()).reset_index()
ozone_group
# Out:
#      Year           County  Ozone (ppb)        AQI
# 0    2010          Alameda    19.944734  25.596466
# 1    2010           Amador    25.307209  35.798898
# 2    2010            Butte    33.102122  37.502740
# 3    2010        Calaveras    29.328263  39.731507
# 4    2010           Colusa    25.605285  32.310541
# 5    2010     Contra Costa    23.958731  29.296025
# 6    2010        El Dorado    39.921773  44.703401
# 7    2010           Fresno    30.074166  48.199426
# 8    2010            Glenn    27.215805  34.192308
# 9    2010         Humboldt    22.857522  25.192308
# 10   2010         Imperial    29.964244  39.361688
# 11   2010             Inyo    43.204841  41.132132
# 12   2010             Kern    35.106140  49.730837
# 13   2010            Kings    31.589145  51.200927
# 14   2010             Lake    26.760904  30.567493
# 15   2010      Los Angeles    24.933976  36.752485
# 16   2010           Madera    27.618073  43.855576
# 17   2010            Marin    18.809553  23.309589
# 18   2010         Mariposa    44.946201  48.030457
# 19   2010        Mendocino    14.749005  20.629121
# 20   2010           Merced    28.070434  42.973046
# 21   2010         Monterey    24.655564  29.465930
# 22   2010             Napa    23.190504  30.134247
# 23   2010           Nevada    38.863942  41.802198
# 24   2010           Orange    26.043482  34.051120
# 25   2010           Placer    30.709851  39.067704
# 26   2010        Riverside    33.558926  48.199595
# 27   2010       Sacramento    25.301738  35.063025
# 28   2010       San Benito    28.528895  35.087989
# 29   2010   San Bernardino    36.855678  51.914299
# ..    ...              ...          ...        ...
# 313  2016        Mendocino    22.765011  28.682451
# 314  2016           Merced    31.869213  49.655738
# 315  2016         Monterey    25.519740  31.628415
# 316  2016             Napa    22.694197  30.035519
# 317  2016           Nevada    46.106858  54.800546
# 318  2016           Orange    30.510075  42.773103
# 319  2016           Placer    35.625654  50.630402
# 320  2016        Riverside    39.020537  55.318556
# 321  2016       Sacramento    28.669315  40.507160
# 322  2016       San Benito    28.987734  37.262363
# 323  2016   San Bernardino    40.667936  63.997124
# 324  2016        San Diego    35.967362  44.180857
# 325  2016    San Francisco    23.068592  26.358904
# 326  2016      San Joaquin    29.027655  39.647945
# 327  2016  San Luis Obispo    31.413737  37.997257
# 328  2016        San Mateo    21.849249  28.153005
# 329  2016    Santa Barbara    30.737847  35.410575
# 330  2016      Santa Clara    25.692316  34.272066
# 331  2016       Santa Cruz    23.644778  29.659280
# 332  2016           Shasta    30.397085  38.141568
# 333  2016         Siskiyou    20.864424  27.371191
# 334  2016           Solano    26.592784  33.035861
# 335  2016           Sonoma    23.643828  28.891817
# 336  2016       Stanislaus    29.183526  45.990358
# 337  2016           Sutter    34.424153  44.529617
# 338  2016           Tehama    39.765343  50.953819
# 339  2016           Tulare    41.306245  64.298199
# 340  2016         Tuolumne    38.066461  56.483146
# 341  2016          Ventura    31.451104  44.013706
# 342  2016             Yolo    26.591039  36.551867
#
# [343 rows x 4 columns]

# %% [markdown]
# ## Asthma Data Collection/Cleaning

# %%
asthma_df = pd.read_csv('Resources/asthma-ed-visit-rates-lghc-indicator-07.csv')
asthma_df.head()
# Out:
#      LGHC Indicator Name   Geography  Year    Age Group            Strata  \
# 0  Asthma ED Visit Rates     Alameda  2015  18 and Over  Total Population
# 1  Asthma ED Visit Rates      Amador  2015  18 and Over  Total Population
# 2  Asthma ED Visit Rates       Butte  2015  18 and Over  Total Population
# 3  Asthma ED Visit Rates   Calaveras  2015  18 and Over  Total Population
# 4  Asthma ED Visit Rates  California  2015  18 and Over  Total Population
#
#    Strata Name Numerator  Rate  LGHC Indicator ID  LGHC Target Rate
# 0  18 and Over     6,513  53.1                  7                28
# 1  18 and Over       151  49.1                  7                28
# 2  18 and Over       736  43.8                  7                28
# 3  18 and Over       139  42.7                  7                28
# 4  18 and Over   117,854  40.0                  7                28

# %%
# display all the unique counties in the df
asthma_df['Geography'].unique()
# Out:
# array(['Alameda', 'Amador', 'Butte', 'Calaveras', 'California', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba', 'Humbolt'], dtype=object)

# %%
# remove 'California' so only specific counties remain
asthma_df = asthma_df.loc[asthma_df['Geography'] != 'California', :]

# %%
# ensure 'California' has been removed
asthma_df['Geography'].unique()
# Out:
# array(['Alameda', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'Del Norte', 'El Dorado', 'Fresno', 'Glenn',
#        'Humboldt', 'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Lassen',
#        'Los Angeles', 'Madera', 'Marin', 'Mariposa', 'Mendocino',
#        'Merced', 'Modoc', 'Mono', 'Monterey', 'Napa', 'Nevada', 'Orange',
#        'Placer', 'Plumas', 'Riverside', 'Sacramento', 'San Benito',
#        'San Bernardino', 'San Diego', 'San Francisco', 'San Joaquin',
#        'San Luis Obispo', 'San Mateo', 'Santa Barbara', 'Santa Clara',
#        'Santa Cruz', 'Shasta', 'Sierra', 'Siskiyou', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo', 'Yuba', 'Humbolt'], dtype=object)

# %%
# check where null values exist
asthma_df.isnull().sum()
# Out:
# LGHC Indicator Name      0
# Geography                0
# Year                     0
# Age Group                0
# Strata                   0
# Strata Name              0
# Numerator              111
# Rate                   637
# LGHC Indicator ID        0
# LGHC Target Rate         0
# dtype: int64

# %%
# create a df that only selects data for specific races
race_asthma = asthma_df.loc[(asthma_df['Strata Name'] == 'African-American') | (asthma_df['Strata Name'] == 'White') | (asthma_df['Strata Name'] == 'Hispanic') | (asthma_df['Strata Name'] == 'American Indian/Alaskan Native') | (asthma_df['Strata Name'] == 'Asian/Pacific Islander'), ['Geography', 'Strata Name','Year', 'Rate']]

# group df by race and year
race_asthma_df = pd.DataFrame(race_asthma.groupby(['Strata Name', 'Year']).mean())

# plot the grouped df
race_asthma_df.unstack(0).plot()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.ylabel("ED Visits for Asthma (per 10,000)")
plt.title("Hospital Visits for Asthma by Race")
plt.savefig('Images/asthmabyrace.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-fac955026e75> in <module>()
#      10 plt.ylabel("ED Visits for Asthma (per 10,000)")
#      11 plt.title("Hospital Visits for Asthma by Race")
# ---> 12 plt.savefig('Images/asthmabyrace.png')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Images/asthmabyrace.png'

# %%
# create a df that only selects data for age groups
age_asthma = asthma_df.loc[(asthma_df['Strata Name'] == 'Under 18') | (asthma_df['Strata Name'] == '18 and Over'), ['Geography', 'Strata Name','Year', 'Rate']]

# group by age group and year
age_asthma_df = pd.DataFrame(age_asthma.groupby(['Strata Name', 'Year']).mean())

# plot the df
age_asthma_df.unstack(0).plot()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.ylabel("ED Visits for Asthma (per 10,000)")
plt.title("Hospital Visits for Asthma by Age")
plt.savefig('Images/asthmabyage.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-7a3367a39725> in <module>()
#      10 plt.ylabel("ED Visits for Asthma (per 10,000)")
#      11 plt.title("Hospital Visits for Asthma by Age")
# ---> 12 plt.savefig('Images/asthmabyage.png')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     708 def savefig(*args, **kwargs):
#     709     fig = gcf()
# --> 710     res = fig.savefig(*args, **kwargs)
#     711     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     712     return res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Images/asthmabyage.png'

# %%
# create a new df that has only data for children 
asthma_children_df = asthma_df.loc[(asthma_df['Strata'] == 'Total Population') & (asthma_df['Strata Name']=='Under 18'),:]

# rename 'Geography' column to 'County'
asthma_children_df = asthma_children_df.rename(columns={'Geography': 'County'})

# display df
asthma_children_df.head()
# Out:
#        LGHC Indicator Name     County  Year Age Group            Strata  \
# 796  Asthma ED Visit Rates    Alameda  2015  Under 18  Total Population
# 797  Asthma ED Visit Rates     Amador  2015  Under 18  Total Population
# 798  Asthma ED Visit Rates      Butte  2015  Under 18  Total Population
# 799  Asthma ED Visit Rates  Calaveras  2015  Under 18  Total Population
# 801  Asthma ED Visit Rates     Colusa  2015  Under 18  Total Population
#
#     Strata Name Numerator  Rate  LGHC Indicator ID  LGHC Target Rate
# 796    Under 18     3,426  96.7                  7                28
# 797    Under 18        45  85.1                  7                28
# 798    Under 18       308  68.7                  7                28
# 799    Under 18        46  63.0                  7                28
# 801    Under 18        48  77.0                  7                28

# %%
# create a new df that only has data for adults
asthma_adults_df = asthma_df.loc[(asthma_df['Strata'] == 'Total Population') & (asthma_df['Strata Name']=='18 and Over'),:]

# rename 'Geography' column to 'County'
asthma_adults_df = asthma_adults_df.rename(columns={'Geography': 'County'})

# display df
asthma_adults_df.head()
# Out:
#      LGHC Indicator Name     County  Year    Age Group            Strata  \
# 0  Asthma ED Visit Rates    Alameda  2015  18 and Over  Total Population
# 1  Asthma ED Visit Rates     Amador  2015  18 and Over  Total Population
# 2  Asthma ED Visit Rates      Butte  2015  18 and Over  Total Population
# 3  Asthma ED Visit Rates  Calaveras  2015  18 and Over  Total Population
# 5  Asthma ED Visit Rates     Colusa  2015  18 and Over  Total Population
#
#    Strata Name Numerator  Rate  LGHC Indicator ID  LGHC Target Rate
# 0  18 and Over     6,513  53.1                  7                28
# 1  18 and Over       151  49.1                  7                28
# 2  18 and Over       736  43.8                  7                28
# 3  18 and Over       139  42.7                  7                28
# 5  18 and Over        49  29.0                  7                28

# %%
# select only relevant columns for children df
asthma_children_df = asthma_children_df[['Year', 'County', 'Rate']]
asthma_children_df.head()
# Out:
#      Year     County  Rate
# 796  2015    Alameda  96.7
# 797  2015     Amador  85.1
# 798  2015      Butte  68.7
# 799  2015  Calaveras  63.0
# 801  2015     Colusa  77.0

# %%
# select only relevant columns for adult df
asthma_adults_df = asthma_adults_df[['Year', 'County', 'Rate']]
asthma_adults_df.head()
# Out:
#    Year     County  Rate
# 0  2015    Alameda  53.1
# 1  2015     Amador  49.1
# 2  2015      Butte  43.8
# 3  2015  Calaveras  42.7
# 5  2015     Colusa  29.0

# %%
# create a new df by grouping children df by 'Year' and 'County'
asthma_children_group = pd.DataFrame(asthma_children_df.groupby(['Year', 'County']).mean()).reset_index()
asthma_children_group
# Out:
#      Year           County   Rate
# 0    2011          Alameda   75.9
# 1    2011           Amador   91.7
# 2    2011            Butte   63.8
# 3    2011        Calaveras   84.1
# 4    2011           Colusa   49.4
# 5    2011     Contra Costa   93.2
# 6    2011        Del Norte   90.0
# 7    2011        El Dorado   40.4
# 8    2011           Fresno  126.1
# 9    2011            Glenn   53.1
# 10   2011         Humboldt   65.0
# 11   2011         Imperial  143.4
# 12   2011             Inyo   79.9
# 13   2011             Kern   82.1
# 14   2011            Kings  138.3
# 15   2011             Lake   91.8
# 16   2011           Lassen   49.8
# 17   2011      Los Angeles   87.2
# 18   2011           Madera  142.2
# 19   2011            Marin   43.2
# 20   2011         Mariposa   85.3
# 21   2011        Mendocino   73.6
# 22   2011           Merced  110.7
# 23   2011            Modoc    NaN
# 24   2011             Mono    NaN
# 25   2011         Monterey   84.1
# 26   2011             Napa   47.1
# 27   2011           Nevada   66.3
# 28   2011           Orange   50.0
# 29   2011           Placer   37.1
# ..    ...              ...    ...
# 307  2016             Napa   51.6
# 308  2016           Nevada   37.4
# 309  2016           Orange   53.7
# 310  2016           Placer   38.4
# 311  2016           Plumas   70.4
# 312  2016        Riverside   66.5
# 313  2016       Sacramento   78.2
# 314  2016       San Benito   83.2
# 315  2016   San Bernardino   81.2
# 316  2016        San Diego   51.0
# 317  2016    San Francisco   67.7
# 318  2016      San Joaquin   80.1
# 319  2016  San Luis Obispo   54.3
# 320  2016        San Mateo   48.2
# 321  2016    Santa Barbara   67.8
# 322  2016      Santa Clara   37.4
# 323  2016       Santa Cruz   56.0
# 324  2016           Shasta   68.5
# 325  2016         Siskiyou   33.2
# 326  2016           Solano  108.9
# 327  2016           Sonoma   55.1
# 328  2016       Stanislaus   73.3
# 329  2016           Sutter   50.7
# 330  2016           Tehama   72.6
# 331  2016          Trinity   56.9
# 332  2016           Tulare   66.4
# 333  2016         Tuolumne   59.3
# 334  2016          Ventura   58.8
# 335  2016             Yolo   59.4
# 336  2016             Yuba   43.7
#
# [337 rows x 3 columns]

# %%
# create a new df by grouping adult df by 'Year' and 'County'
asthma_adults_group = pd.DataFrame(asthma_adults_df.groupby(['Year', 'County']).mean()).reset_index()
asthma_adults_group
# Out:
#      Year           County  Rate
# 0    2011          Alameda  56.6
# 1    2011           Amador  58.1
# 2    2011            Butte  49.9
# 3    2011        Calaveras  49.5
# 4    2011           Colusa  23.4
# 5    2011     Contra Costa  67.3
# 6    2011        Del Norte  46.7
# 7    2011        El Dorado  30.3
# 8    2011           Fresno  53.0
# 9    2011            Glenn  39.9
# 10   2011         Humboldt  67.2
# 11   2011         Imperial  53.2
# 12   2011             Inyo  52.4
# 13   2011             Kern  42.2
# 14   2011            Kings  64.4
# 15   2011             Lake  59.0
# 16   2011           Lassen  26.8
# 17   2011      Los Angeles  36.5
# 18   2011           Madera  44.8
# 19   2011            Marin  27.0
# 20   2011         Mariposa  28.6
# 21   2011        Mendocino  63.4
# 22   2011           Merced  63.1
# 23   2011            Modoc  64.4
# 24   2011             Mono  12.4
# 25   2011         Monterey  30.7
# 26   2011             Napa  41.2
# 27   2011           Nevada  44.5
# 28   2011           Orange  22.5
# 29   2011           Placer  28.2
# ..    ...              ...   ...
# 311  2016           Nevada  32.3
# 312  2016           Orange  20.7
# 313  2016           Placer  24.8
# 314  2016           Plumas  58.3
# 315  2016        Riverside  32.7
# 316  2016       Sacramento  54.7
# 317  2016       San Benito  36.8
# 318  2016   San Bernardino  41.8
# 319  2016        San Diego  24.0
# 320  2016    San Francisco  28.4
# 321  2016      San Joaquin  49.6
# 322  2016  San Luis Obispo  32.4
# 323  2016        San Mateo  27.0
# 324  2016    Santa Barbara  27.3
# 325  2016      Santa Clara  26.1
# 326  2016       Santa Cruz  26.9
# 327  2016           Shasta  38.7
# 328  2016           Sierra   NaN
# 329  2016         Siskiyou  33.9
# 330  2016           Solano  71.0
# 331  2016           Sonoma  30.2
# 332  2016       Stanislaus  43.6
# 333  2016           Sutter  27.8
# 334  2016           Tehama  50.2
# 335  2016          Trinity  51.2
# 336  2016           Tulare  31.6
# 337  2016         Tuolumne  42.6
# 338  2016          Ventura  23.2
# 339  2016             Yolo  31.1
# 340  2016             Yuba  37.7
#
# [341 rows x 3 columns]

# %% [markdown]
# ## Combining Ozone/AQI & Asthma Data

# %%
# merge children df with ozone data
oa_children_df = pd.merge(ozone_group, asthma_children_group, on=['Year','County'])
oa_children_df
# Out:
#      Year           County  Ozone (ppb)        AQI   Rate
# 0    2011          Alameda    21.322507  26.141045   75.9
# 1    2011           Amador    25.426951  36.361644   91.7
# 2    2011            Butte    32.591449  37.293151   63.8
# 3    2011        Calaveras    29.013634  40.358127   84.1
# 4    2011           Colusa    25.211324  32.066482   49.4
# 5    2011     Contra Costa    22.785799  28.416667   93.2
# 6    2011        El Dorado    39.995495  47.191280   40.4
# 7    2011           Fresno    31.305375  49.700969  126.1
# 8    2011            Glenn    27.425226  34.767908   53.1
# 9    2011         Humboldt    22.321125  24.102996   65.0
# 10   2011         Imperial    30.508806  39.826339  143.4
# 11   2011             Inyo    47.201216  46.980609   79.9
# 12   2011             Kern    34.848191  50.610548   82.1
# 13   2011            Kings    29.942402  44.382560  138.3
# 14   2011             Lake    26.696362  30.605479   91.8
# 15   2011      Los Angeles    25.351224  37.913646   87.2
# 16   2011           Madera    31.384872  45.434625  142.2
# 17   2011            Marin    18.866038  23.810959   43.2
# 18   2011         Mariposa    43.731583  47.423575   85.3
# 19   2011        Mendocino    14.289593  20.184066   73.6
# 20   2011           Merced    32.750680  48.915493  110.7
# 21   2011         Monterey    25.173607  29.934982   84.1
# 22   2011             Napa    21.989811  28.838356   47.1
# 23   2011           Nevada    40.158511  42.139850   66.3
# 24   2011           Orange    26.415068  34.497222   50.0
# 25   2011           Placer    30.705158  39.859890   37.1
# 26   2011        Riverside    36.232446  50.791700   66.0
# 27   2011       Sacramento    26.501547  37.572188   79.8
# 28   2011       San Benito    27.738587  34.138736  100.3
# 29   2011   San Bernardino    37.264650  53.440753   89.6
# ..    ...              ...          ...        ...    ...
# 264  2016        Mendocino    22.765011  28.682451   66.7
# 265  2016           Merced    31.869213  49.655738  130.9
# 266  2016         Monterey    25.519740  31.628415   65.4
# 267  2016             Napa    22.694197  30.035519   51.6
# 268  2016           Nevada    46.106858  54.800546   37.4
# 269  2016           Orange    30.510075  42.773103   53.7
# 270  2016           Placer    35.625654  50.630402   38.4
# 271  2016        Riverside    39.020537  55.318556   66.5
# 272  2016       Sacramento    28.669315  40.507160   78.2
# 273  2016       San Benito    28.987734  37.262363   83.2
# 274  2016   San Bernardino    40.667936  63.997124   81.2
# 275  2016        San Diego    35.967362  44.180857   51.0
# 276  2016    San Francisco    23.068592  26.358904   67.7
# 277  2016      San Joaquin    29.027655  39.647945   80.1
# 278  2016  San Luis Obispo    31.413737  37.997257   54.3
# 279  2016        San Mateo    21.849249  28.153005   48.2
# 280  2016    Santa Barbara    30.737847  35.410575   67.8
# 281  2016      Santa Clara    25.692316  34.272066   37.4
# 282  2016       Santa Cruz    23.644778  29.659280   56.0
# 283  2016           Shasta    30.397085  38.141568   68.5
# 284  2016         Siskiyou    20.864424  27.371191   33.2
# 285  2016           Solano    26.592784  33.035861  108.9
# 286  2016           Sonoma    23.643828  28.891817   55.1
# 287  2016       Stanislaus    29.183526  45.990358   73.3
# 288  2016           Sutter    34.424153  44.529617   50.7
# 289  2016           Tehama    39.765343  50.953819   72.6
# 290  2016           Tulare    41.306245  64.298199   66.4
# 291  2016         Tuolumne    38.066461  56.483146   59.3
# 292  2016          Ventura    31.451104  44.013706   58.8
# 293  2016             Yolo    26.591039  36.551867   59.4
#
# [294 rows x 5 columns]

# %%
# check for null values
oa_children_df.isnull().sum()
# Out:
# Year            0
# County          0
# Ozone (ppb)    49
# AQI             0
# Rate            2
# dtype: int64

# %%
# drop counties where rate is null
oa_children_df = oa_df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2c2abd3f9ef6> in <module>()
#       1 # drop counties where rate is null
# ----> 2 oa_children_df = oa_df.dropna()
#
# NameError: name 'oa_df' is not defined

# %%
# merge adult df with ozone data
oa_adults_df = pd.merge(ozone_group, asthma_adults_group, on=['Year','County'])
oa_adults_df
# Out:
#      Year           County  Ozone (ppb)        AQI  Rate
# 0    2011          Alameda    21.322507  26.141045  56.6
# 1    2011           Amador    25.426951  36.361644  58.1
# 2    2011            Butte    32.591449  37.293151  49.9
# 3    2011        Calaveras    29.013634  40.358127  49.5
# 4    2011           Colusa    25.211324  32.066482  23.4
# 5    2011     Contra Costa    22.785799  28.416667  67.3
# 6    2011        El Dorado    39.995495  47.191280  30.3
# 7    2011           Fresno    31.305375  49.700969  53.0
# 8    2011            Glenn    27.425226  34.767908  39.9
# 9    2011         Humboldt    22.321125  24.102996  67.2
# 10   2011         Imperial    30.508806  39.826339  53.2
# 11   2011             Inyo    47.201216  46.980609  52.4
# 12   2011             Kern    34.848191  50.610548  42.2
# 13   2011            Kings    29.942402  44.382560  64.4
# 14   2011             Lake    26.696362  30.605479  59.0
# 15   2011      Los Angeles    25.351224  37.913646  36.5
# 16   2011           Madera    31.384872  45.434625  44.8
# 17   2011            Marin    18.866038  23.810959  27.0
# 18   2011         Mariposa    43.731583  47.423575  28.6
# 19   2011        Mendocino    14.289593  20.184066  63.4
# 20   2011           Merced    32.750680  48.915493  63.1
# 21   2011         Monterey    25.173607  29.934982  30.7
# 22   2011             Napa    21.989811  28.838356  41.2
# 23   2011           Nevada    40.158511  42.139850  44.5
# 24   2011           Orange    26.415068  34.497222  22.5
# 25   2011           Placer    30.705158  39.859890  28.2
# 26   2011        Riverside    36.232446  50.791700  35.2
# 27   2011       Sacramento    26.501547  37.572188  56.2
# 28   2011       San Benito    27.738587  34.138736  39.5
# 29   2011   San Bernardino    37.264650  53.440753  48.0
# ..    ...              ...          ...        ...   ...
# 264  2016        Mendocino    22.765011  28.682451  52.8
# 265  2016           Merced    31.869213  49.655738  61.2
# 266  2016         Monterey    25.519740  31.628415  37.0
# 267  2016             Napa    22.694197  30.035519  27.2
# 268  2016           Nevada    46.106858  54.800546  32.3
# 269  2016           Orange    30.510075  42.773103  20.7
# 270  2016           Placer    35.625654  50.630402  24.8
# 271  2016        Riverside    39.020537  55.318556  32.7
# 272  2016       Sacramento    28.669315  40.507160  54.7
# 273  2016       San Benito    28.987734  37.262363  36.8
# 274  2016   San Bernardino    40.667936  63.997124  41.8
# 275  2016        San Diego    35.967362  44.180857  24.0
# 276  2016    San Francisco    23.068592  26.358904  28.4
# 277  2016      San Joaquin    29.027655  39.647945  49.6
# 278  2016  San Luis Obispo    31.413737  37.997257  32.4
# 279  2016        San Mateo    21.849249  28.153005  27.0
# 280  2016    Santa Barbara    30.737847  35.410575  27.3
# 281  2016      Santa Clara    25.692316  34.272066  26.1
# 282  2016       Santa Cruz    23.644778  29.659280  26.9
# 283  2016           Shasta    30.397085  38.141568  38.7
# 284  2016         Siskiyou    20.864424  27.371191  33.9
# 285  2016           Solano    26.592784  33.035861  71.0
# 286  2016           Sonoma    23.643828  28.891817  30.2
# 287  2016       Stanislaus    29.183526  45.990358  43.6
# 288  2016           Sutter    34.424153  44.529617  27.8
# 289  2016           Tehama    39.765343  50.953819  50.2
# 290  2016           Tulare    41.306245  64.298199  31.6
# 291  2016         Tuolumne    38.066461  56.483146  42.6
# 292  2016          Ventura    31.451104  44.013706  23.2
# 293  2016             Yolo    26.591039  36.551867  31.1
#
# [294 rows x 5 columns]

# %%
# check for null values
oa_adults_df.isnull().sum()
# Out:
# Year            0
# County          0
# Ozone (ppb)    49
# AQI             0
# Rate            0
# dtype: int64

# %%
# perform ANOVA to see if ozone concentration is significantly different from 2011 to 2016
ozone_2011 = list(oa_children_df.loc[oa_df['Year']==2011,:]['Ozone (ppb)'])
ozone_2012 = list(oa_children_df.loc[oa_df['Year']==2012,:]['Ozone (ppb)'])
ozone_2013 = list(oa_children_df.loc[oa_df['Year']==2013,:]['Ozone (ppb)'])
ozone_2014 = list(oa_children_df.loc[oa_df['Year']==2014,:]['Ozone (ppb)'])
ozone_2015 = list(oa_children_df.loc[oa_df['Year']==2015,:]['Ozone (ppb)'])
ozone_2016 = list(oa_children_df.loc[oa_df['Year']==2016,:]['Ozone (ppb)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-96d423a65cd5> in <module>()
#       1 # perform ANOVA to see if ozone concentration is significantly different from 2011 to 2016
# ----> 2 ozone_2011 = list(oa_children_df.loc[oa_df['Year']==2011,:]['Ozone (ppb)'])
#       3 ozone_2012 = list(oa_children_df.loc[oa_df['Year']==2012,:]['Ozone (ppb)'])
#       4 ozone_2013 = list(oa_children_df.loc[oa_df['Year']==2013,:]['Ozone (ppb)'])
#       5 ozone_2014 = list(oa_children_df.loc[oa_df['Year']==2014,:]['Ozone (ppb)'])
#
# NameError: name 'oa_df' is not defined

# %%
stats.f_oneway(ozone_2011, ozone_2012, ozone_2013, ozone_2014, ozone_2015, ozone_2016)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-cedc830fa480> in <module>()
# ----> 1 stats.f_oneway(ozone_2011, ozone_2012, ozone_2013, ozone_2014, ozone_2015, ozone_2016)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\stats.py in f_oneway(*args)
#    2905
#    2906     """
# -> 2907     args = [np.asarray(arg, dtype=float) for arg in args]
#    2908     # ANOVA on N groups, each in its own array
#    2909     num_groups = len(args)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\stats.py in <listcomp>(.0)
#    2905
#    2906     """
# -> 2907     args = [np.asarray(arg, dtype=float) for arg in args]
#    2908     # ANOVA on N groups, each in its own array
#    2909     num_groups = len(args)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# ValueError: could not convert string to float: 'Yolo'

# %% [markdown]
# P-value is >0.05 which indicates there is no statistically significant difference in ozone ppb from 2011 to 2016

# %%
# # perform ANOVA to see if AQI is significantly different from 2011 to 2016
aqi_2011 = list(oa_children_df.loc[oa_df['Year']==2011,:]['AQI'])
aqi_2012 = list(oa_children_df.loc[oa_df['Year']==2012,:]['AQI'])
aqi_2013 = list(oa_children_df.loc[oa_df['Year']==2013,:]['AQI'])
aqi_2014 = list(oa_children_df.loc[oa_df['Year']==2014,:]['AQI'])
aqi_2015 = list(oa_children_df.loc[oa_df['Year']==2015,:]['AQI'])
aqi_2016 = list(oa_children_df.loc[oa_df['Year']==2016,:]['AQI'])
stats.f_oneway(aqi_2011, aqi_2012, aqi_2013, aqi_2014, aqi_2015, aqi_2016)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-2607b88e0775> in <module>()
#       1 # # perform ANOVA to see if AQI is significantly different from 2011 to 2016
# ----> 2 aqi_2011 = list(oa_children_df.loc[oa_df['Year']==2011,:]['AQI'])
#       3 aqi_2012 = list(oa_children_df.loc[oa_df['Year']==2012,:]['AQI'])
#       4 aqi_2013 = list(oa_children_df.loc[oa_df['Year']==2013,:]['AQI'])
#       5 aqi_2014 = list(oa_children_df.loc[oa_df['Year']==2014,:]['AQI'])
#
# NameError: name 'oa_df' is not defined

# %% [markdown]
# P-value is >0.05 which indicates there is no statistically significant difference in ozone ppb from 2011 to 2016

# %%
counties = oa_children_df['County'].unique()
counties
# Out:
# array(['Alameda', 'Amador', 'Butte', 'Calaveras', 'Colusa',
#        'Contra Costa', 'El Dorado', 'Fresno', 'Glenn', 'Humboldt',
#        'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Los Angeles',
#        'Madera', 'Marin', 'Mariposa', 'Mendocino', 'Merced', 'Monterey',
#        'Napa', 'Nevada', 'Orange', 'Placer', 'Riverside', 'Sacramento',
#        'San Benito', 'San Bernardino', 'San Diego', 'San Francisco',
#        'San Joaquin', 'San Luis Obispo', 'San Mateo', 'Santa Barbara',
#        'Santa Clara', 'Santa Cruz', 'Shasta', 'Siskiyou', 'Solano',
#        'Sonoma', 'Stanislaus', 'Sutter', 'Tehama', 'Tulare', 'Tuolumne',
#        'Ventura', 'Yolo'], dtype=object)

# %%
# ANOVA - Counties (Mean Ozone)
ozone_dict = {}
for county in counties:
    if county not in ozone_dict:
        ozone_dict[county] = list(oa_children_df.loc[oa_df['County']==county,:]['Ozone (ppb)'])
        
print("ANOVA analysis comparing ozone concentration between two ounties in California ")
try:
    ozone_compare1 = input("Choose a county: ")
    ozone_compare2 = input("Choose another county: ")
    print(stats.f_oneway(ozone_dict[ozone_compare1], ozone_dict[ozone_compare2]))
    comparison_df = pd.DataFrame(oa_children_df.loc[(oa_children_df['County']==ozone_compare1) | (oa_children_df['County']==ozone_compare2),:])
    comparison_df.boxplot('Ozone (ppb)', by='County')
    plt.ylabel("Average Ozone (ppb) from 2011-2016")
except KeyError: 
    print("Could not find county")
#comparison_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-6bc2a426f576> in <module>()
#       3 for county in counties:
#       4     if county not in ozone_dict:
# ----> 5         ozone_dict[county] = list(oa_children_df.loc[oa_df['County']==county,:]['Ozone (ppb)'])
#       6
#       7 print("ANOVA analysis comparing ozone concentration between two ounties in California ")
#
# NameError: name 'oa_df' is not defined

# %%
# ANOVA - Counties (Mean AQI)
aqi_dict = {}
for county in counties:
    if county not in aqi_dict:
        aqi_dict[county] = list(oa_df.loc[oa_children_df['County']==county,:]['AQI'])
try:
    aqi_compare1 = input("Choose a county: ")
    aqi_compare2 = input("Choose another county: ")
    print(stats.f_oneway(aqi_dict[aqi_compare1], aqi_dict[aqi_compare2]))
except KeyError: 
    print("Could not find county")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-02dc7034cd23> in <module>()
#       3 for county in counties:
#       4     if county not in aqi_dict:
# ----> 5         aqi_dict[county] = list(oa_df.loc[oa_children_df['County']==county,:]['AQI'])
#       6 try:
#       7     aqi_compare1 = input("Choose a county: ")
#
# NameError: name 'oa_df' is not defined

# %%
# ANOVA - Counties (Raw AQI + Raw Ozone) for chosen year

year = input("Choose a year: ")
ozone_yr = all_ozone.loc[all_ozone['Year']==int(year), :]
o3aqi_dict = {}
for county in counties:
    if county not in o3aqi_dict:
        o3aqi_dict[county] = {}
        o3aqi_dict[county]['Ozone'] = list(ozone_yr.loc[ozone_yr['County Name']==county,:]['O3_ppb'])
        o3aqi_dict[county]['AQI'] = list(ozone_yr.loc[ozone_yr['County Name']==county,:]['AQI'])
#print(o3aqi_dict)
        
try:
    parameter = input("Choose a parameter (AQI or Ozone): ")
    compare1 = input("Choose a county: ")
    compare2 = input("Choose another county: ")
    
    print(f"ANOVA analysis comparing {parameter} between {compare1} and {compare2} in California in {year}")

    print(stats.f_oneway(o3aqi_dict[compare1][parameter], o3aqi_dict[compare2][parameter]))
    comparison_df = pd.DataFrame(ozone_yr.loc[(ozone_yr['County Name']==compare1) | (ozone_yr['County Name']==compare2),:])
    if parameter == 'AQI':
        comparison_df.boxplot(parameter, by='County Name')
    if parameter == 'Ozone':
        comparison_df.boxplot('O3_ppb', by='County Name')
    plt.ylabel(f"{parameter} in {year}")
except KeyError: 
    print("Could not find county")
# Out:
# Choose a year: 2013
# Choose a parameter (AQI or Ozone): Ozone
# Choose a county: Mendocino
# Choose another county: Inyo
# ANOVA analysis comparing Ozone between Mendocino and Inyo in California in 2013
# F_onewayResult(statistic=927.0079404726041, pvalue=2.6119328594360543e-137)

# %%
# 3D PLOT - AQI & Ozone vs Asthma Rates

# select only data for 2011
test_df = oa_adults_df.loc[oa_adults_df['Year']==2011, :]

# plot data (x-axis = AQI, y-axis = Ozone (ppb), x-axis = ED visit rate for asthma)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(test_df['AQI'], test_df['Ozone (ppb)'], test_df['Rate'])
plt.gca().invert_yaxis()

ax.set_xlabel('AQI')
ax.set_ylabel('Ozone (ppb)')
ax.set_zlabel('Asthma Rates')
# Out:
# Text(0.5,0,'Asthma Rates')

# %% [markdown]
# ## Asthma vs AQI Analysis

# %%
# Graph ADULTS ED rates vs AQI & CHILDREN ED rates vs AQI for each individual year
# Subplots: 1st graph contains data for children, 2nd graph contains data for adults
years = ['2011', '2012', '2013', '2014', '2015', '2016']

# create a subplot for each year
for year in years:
    # create copies of children/adult df by selecting only specific year in for loop
    child_df = oa_children_df.loc[oa_children_df['Year']==int(year), :]
    adult_df = oa_adults_df.loc[oa_adults_df['Year']==int(year), :]
    
    # linear regression for children
    (child_slope, child_intercept, child_r, _, _) = linregress(child_df['AQI'],child_df['Rate'])
    child_fit = child_slope * child_df['AQI'] + child_intercept
    
    # linear regression for adults
    (adult_slope, adult_intercept, adult_r, _, _) = linregress(adult_df['AQI'],adult_df['Rate'])
    adult_fit = adult_slope * adult_df['AQI'] + adult_intercept
    
    # create 2 subplots that share x-axis
    f, axarr = plt.subplots(2, sharex=True, figsize=(7, 7))
    
    # 1st plot (asthma in children vs AQI)
    axarr[0].plot(child_df['AQI'], child_fit, c='#30336b', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(child_slope, child_intercept, child_r))
    axarr[0].legend(loc="upper right")
    axarr[0].scatter(child_df['AQI'], child_df['Rate'], c='red')
    axarr[0].set_title(f'{year}')
    axarr[0].set_ylabel("\n".join(wrap("Rate of Under 18 ED Visits for Asthma (per 10,000)", 30)))
    
    # 2nd plot (asthma in adults vs AQI)
    axarr[1].plot(adult_df['AQI'], adult_fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(adult_slope, adult_intercept, adult_r))
    axarr[1].legend(loc="upper right")
    axarr[1].scatter(adult_df['AQI'], adult_df['Rate'], c='blue')
    axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
    axarr[1].set_xlabel('AQI') 
    f.savefig(f'Images/aqivsasthma_{year}.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-e510c17a9641> in <module>()
#      33     axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
#      34     axarr[1].set_xlabel('AQI')
# ---> 35     f.savefig(f'Images/aqivsasthma_{year}.png')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Images/aqivsasthma_2011.png'

# %%
# Graph ADULTS ED rates vs AQI & CHILDREN ED rates vs AQI for all years
# Subplot: 1st graph contains data for children, 2nd graph contains data for adults

# create copies of merged adult/children dfs that contains data from all years
child_df = oa_children_df.loc[:]
adult_df = oa_adults_df.loc[:]
  
# linear regression for children data
(child_slope, child_intercept, child_r, _, _) = linregress(child_df['AQI'],child_df['Rate'])
child_fit = child_slope * child_df['AQI'] + child_intercept
  
# linear regression for adult data
(adult_slope, adult_intercept, adult_r, _, _) = linregress(adult_df['AQI'],adult_df['Rate'])
adult_fit = adult_slope * adult_df['AQI'] + adult_intercept

# create 2 subplots that share x-axis
f, axarr = plt.subplots(2, sharex=True, figsize=(7, 7))

# 1st subplot (asthma in children vs AQI)
axarr[0].plot(child_df['AQI'], child_fit, c='#30336b', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(child_slope, child_intercept, child_r))
axarr[0].legend(loc="upper right")
axarr[0].scatter(child_df['AQI'], child_df['Rate'], c='red')
axarr[0].set_title(f'2011-2016')
axarr[0].set_ylabel("\n".join(wrap("Rate of Under 18 ED Visits for Asthma (per 10,000)", 30)))

# 2nd subplot (asthma in adults vs AQI)
axarr[1].plot(adult_df['AQI'], adult_fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(adult_slope, adult_intercept, adult_r))
axarr[1].legend(loc="upper right")
axarr[1].scatter(adult_df['AQI'], adult_df['Rate'], c='blue')
axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
axarr[1].set_xlabel('AQI')
f.savefig(f'Images/aqivsasthma2011to2016.png')
# Out:
# C:\Users\shaheen\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\shaheen\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\shaheen\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-53-2a59d1180af9> in <module>()
#      30 axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
#      31 axarr[1].set_xlabel('AQI')
# ---> 32 f.savefig(f'Images/aqivsasthma2011to2016.png')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Images/aqivsasthma2011to2016.png'

# %% [markdown]
# ## Asthma vs Ozone Analysis

# %%
# Graph ADULTS ED rates vs Ozone & CHILDREN ED rates vs Ozone for each individual year
# Subplot: 1st graph contains data for children, 2nd graph contains data for adults

years = ['2011', '2012', '2013', '2014', '2015', '2016']

# create a subplot for each year
for year in years:
    # create copies of children/adult df by selecting data from specific year in for loop
    child_df = oa_children_df.loc[oa_children_df['Year']==int(year), :]
    adult_df = oa_adults_df.loc[oa_adults_df['Year']==int(year), :]
    
    # linear regression for children
    (child_slope, child_intercept, child_r, _, _) = linregress(child_df['Ozone (ppb)'],child_df['Rate'])
    child_fit = child_slope * child_df['Ozone (ppb)'] + child_intercept
    
    # linear regression for adults
    (adult_slope, adult_intercept, adult_r, _, _) = linregress(adult_df['Ozone (ppb)'],adult_df['Rate'])
    adult_fit = adult_slope * adult_df['Ozone (ppb)'] + adult_intercept
    
    # create 2 subplots that share x-axis
    f, axarr = plt.subplots(2, sharex=True, figsize=(7, 7))
    
    # 1st subplot (asthma in children vs ozone (ppb))
    axarr[0].plot(child_df['Ozone (ppb)'], child_fit, c='#30336b', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(child_slope, child_intercept, child_r))
    axarr[0].legend(loc="upper right")
    axarr[0].scatter(child_df['Ozone (ppb)'], child_df['Rate'], c='red', marker="^")
    axarr[0].set_title(f'{year}')
    axarr[0].set_ylabel("\n".join(wrap("Rate of Under 18 ED Visits for Asthma (per 10,000)", 30)))
    
    # 2nd subplot (asthma in adults vs ozone (ppb))
    axarr[1].plot(adult_df['Ozone (ppb)'], adult_fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(adult_slope, adult_intercept, adult_r))
    axarr[1].legend(loc="upper right")
    axarr[1].scatter(adult_df['Ozone (ppb)'], adult_df['Rate'], c='blue', marker="^")
    axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
    axarr[1].set_xlabel('Ozone (ppb)')    
    
    f.savefig(f'Images/ozonevsasthma_{year}.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-54-ddfaca225469> in <module>()
#      35     axarr[1].set_xlabel('Ozone (ppb)')
#      36
# ---> 37     f.savefig(f'Images/ozonevsasthma_{year}.png')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Images/ozonevsasthma_2011.png'

# %%
# Graph ADULTS ED rates vs Ozone & CHILDREN ED rates vs Ozone for all years
# Subplot: 1st graph contains data for children, 2nd graph contains data for adults

# create a copy of adult/children dfs that contains data for all years
child_df = oa_children_df.loc[:]
adult_df = oa_adults_df.loc[:]

# linear regression for children    
(child_slope, child_intercept, child_r, _, _) = linregress(child_df['Ozone (ppb)'],child_df['Rate'])
child_fit = child_slope * child_df['Ozone (ppb)'] + child_intercept
    
# linear regression for adults
(adult_slope, adult_intercept, adult_r, _, _) = linregress(adult_df['Ozone (ppb)'],adult_df['Rate'])
adult_fit = adult_slope * adult_df['Ozone (ppb)'] + adult_intercept
    
# create 2 subplots that share x-axis
f, axarr = plt.subplots(2, sharex=True, figsize=(7, 7))
    
# 1st subplot (asthma in children vs ozone (ppb))
axarr[0].plot(child_df['Ozone (ppb)'], child_fit, c='#30336b', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(child_slope, child_intercept, child_r))
axarr[0].legend(loc="upper right")
axarr[0].scatter(child_df['Ozone (ppb)'], child_df['Rate'], c='red', marker="^")
axarr[0].set_title(f'2011-2016')
axarr[0].set_ylabel("\n".join(wrap("Rate of Under 18 ED Visits for Asthma (per 10,000)", 30)))
    
# 2nd subplot (asthma in adults vs ozone (ppb))
axarr[1].plot(adult_df['Ozone (ppb)'], adult_fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(adult_slope, adult_intercept, adult_r))
axarr[1].legend(loc="upper right")
axarr[1].scatter(adult_df['Ozone (ppb)'], adult_df['Rate'], c='blue', marker="^")
axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
axarr[1].set_xlabel('Ozone (ppb)')

f.savefig(f'Images/aqivsozone2011to2016.png')
# Out:
# C:\Users\shaheen\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\shaheen\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\shaheen\Anaconda3\envs\PythonData\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-55-b4bfafa6b283> in <module>()
#      31 axarr[1].set_xlabel('Ozone (ppb)')
#      32
# ---> 33 f.savefig(f'Images/aqivsozone2011to2016.png')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524
#     525         try:
# --> 526             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     527                 _png.write_png(renderer._renderer, fh,
#     528                                self.figure.dpi, metadata=metadata)
#
# ~\Anaconda3\envs\PythonData\lib\contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in open_file_cm(path_or_file, mode, encoding)
#     622 def open_file_cm(path_or_file, mode="r", encoding=None):
#     623     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 624     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     625     if opened:
#     626         with fh:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\cbook\__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     607             fh = bz2.BZ2File(fname, flag)
#     608         else:
# --> 609             fh = io.open(fname, flag, encoding=encoding)
#     610         opened = True
#     611     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Images/aqivsozone2011to2016.png'

# %% [markdown]
# ## PM2.5 Data Collection/Clean-up

# %%
pm25_df = pd.read_csv('Resources/CA_Counties_PM25_2011-2016.csv')
del pm25_df['Unnamed: 0']
pm25_df = pm25_df.rename(columns={"County Names": "County"})
pm25_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-ea765da96464> in <module>()
# ----> 1 pm25_df = pd.read_csv('Resources/CA_Counties_PM25_2011-2016.csv')
#       2 del pm25_df['Unnamed: 0']
#       3 pm25_df = pm25_df.rename(columns={"County Names": "County"})
#       4 pm25_df.head()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'Resources/CA_Counties_PM25_2011-2016.csv' does not exist

# %%
# ADULTS
# for each year, combine data from the ozone & asthma adults df for that specific year with the corresponding PM2.5 column and create a new df
# then rename the column name from "{year} PM2.5" in the new df simply to "PM2.5"
pm25_a_2011 = oa_adults_df.loc[oa_adults_df['Year']==2011,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2011 PM2.5']], on='County', how='inner')
pm25_a_2011 = pm25_a_2011.rename(columns={"2011 PM2.5": "PM2.5"})
pm25_a_2012 = oa_adults_df.loc[oa_adults_df['Year']==2012,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2012 PM2.5']], on='County', how='inner')
pm25_a_2012 = pm25_a_2012.rename(columns={"2012 PM2.5": "PM2.5"})
pm25_a_2013 = oa_adults_df.loc[oa_adults_df['Year']==2013,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2013 PM2.5']], on='County', how='inner')
pm25_a_2013 = pm25_a_2013.rename(columns={"2013 PM2.5": "PM2.5"})
pm25_a_2014 = oa_adults_df.loc[oa_adults_df['Year']==2014,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2014 PM2.5']], on='County', how='inner')
pm25_a_2014 = pm25_a_2014.rename(columns={"2014 PM2.5": "PM2.5"})
pm25_a_2015 = oa_adults_df.loc[oa_adults_df['Year']==2015,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2015 PM2.5']], on='County', how='inner')
pm25_a_2015 = pm25_a_2015.rename(columns={"2015 PM2.5": "PM2.5"})
pm25_a_2016 = oa_adults_df.loc[oa_adults_df['Year']==2016,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2016 PM2.5']], on='County', how='inner')
pm25_a_2016 = pm25_a_2016.rename(columns={"2016 PM2.5": "PM2.5"})

# CHILDREN
# for each year, combine data from the ozone & asthma children df for that specific year with the corresponding PM2.5 column and create a new df
# then rename the column name from "{year} PM2.5" in the new df simply to "PM2.5"
pm25_c_2011 = oa_children_df.loc[oa_children_df['Year']==2011,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2011 PM2.5']], on='County', how='inner')
pm25_c_2011 = pm25_c_2011.rename(columns={"2011 PM2.5": "PM2.5"})
pm25_c_2012 = oa_children_df.loc[oa_children_df['Year']==2012,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2012 PM2.5']], on='County', how='inner')
pm25_c_2012 = pm25_c_2012.rename(columns={"2012 PM2.5": "PM2.5"})
pm25_c_2013 = oa_children_df.loc[oa_children_df['Year']==2013,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2013 PM2.5']], on='County', how='inner')
pm25_c_2013 = pm25_c_2013.rename(columns={"2013 PM2.5": "PM2.5"})
pm25_c_2014 = oa_children_df.loc[oa_children_df['Year']==2014,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2014 PM2.5']], on='County', how='inner')
pm25_c_2014 = pm25_c_2014.rename(columns={"2014 PM2.5": "PM2.5"})
pm25_c_2015 = oa_children_df.loc[oa_children_df['Year']==2015,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2015 PM2.5']], on='County', how='inner')
pm25_c_2015 = pm25_c_2015.rename(columns={"2015 PM2.5": "PM2.5"})
pm25_c_2016 = oa_children_df.loc[oa_children_df['Year']==2016,['Year','County', 'Rate']].merge(pm25_df.loc[:,['County','2016 PM2.5']], on='County', how='inner')
pm25_c_2016 = pm25_c_2016.rename(columns={"2016 PM2.5": "PM2.5"})

# %%
# display 1 of the newly created dataframes
pm25_a_2016
# Out:
#     Year           County  Rate      PM2.5
# 0   2016          Alameda  43.7   7.695975
# 1   2016            Butte  34.0   7.600915
# 2   2016        Calaveras  42.3   8.101435
# 3   2016           Colusa  25.0   4.665881
# 4   2016     Contra Costa  45.7   7.098265
# 5   2016           Fresno  41.1  11.279234
# 6   2016         Humboldt  66.8   5.962855
# 7   2016         Imperial  43.1  11.664553
# 8   2016             Inyo  38.8   5.352194
# 9   2016             Kern  43.3   8.040060
# 10  2016            Kings  49.0  15.655332
# 11  2016             Lake  79.4   2.985246
# 12  2016      Los Angeles  38.6  10.995261
# 13  2016           Madera  32.3  12.134698
# 14  2016            Marin  19.7   6.486877
# 15  2016           Merced  61.2  11.994774
# 16  2016         Monterey  37.0   5.804339
# 17  2016           Nevada  32.3   5.712717
# 18  2016           Orange  20.7   8.874678
# 19  2016           Placer  24.8   6.013099
# 20  2016        Riverside  32.7  10.204809
# 21  2016       Sacramento  54.7   6.385563
# 22  2016       San Benito  36.8   4.287063
# 23  2016   San Bernardino  41.8  10.167431
# 24  2016        San Diego  24.0   6.338994
# 25  2016    San Francisco  28.4   7.620439
# 26  2016      San Joaquin  49.6  11.700175
# 27  2016  San Luis Obispo  32.4   6.924913
# 28  2016        San Mateo  27.0   8.327174
# 29  2016    Santa Barbara  27.3   7.057402
# 30  2016      Santa Clara  26.1   7.743220
# 31  2016       Santa Cruz  26.9   5.296084
# 32  2016           Shasta  38.7   5.050000
# 33  2016         Siskiyou  33.9   4.936207
# 34  2016           Solano  71.0   7.949480
# 35  2016           Sonoma  30.2   4.678414
# 36  2016       Stanislaus  43.6  12.001235
# 37  2016           Sutter  27.8   8.118519
# 38  2016           Tulare  31.6  14.706780
# 39  2016          Ventura  23.2   8.791687
# 40  2016             Yolo  31.1   6.316667

# %% [markdown]
# ## Asthma vs PM2.5 Analysis

# %%
# Graph ADULTS ED rates vs PM2.5 & CHILDREN ED rates vs PM2.5 for each individual year
# Subplot: 1st graph contains data for children, 2nd graph contains data for adults
years = ['2011', '2012', '2013', '2014', '2015', '2016']

# dictionary that has corresponding children/adult df for each year
df_dict = {'2011': [pm25_c_2011, pm25_a_2011],
           '2012': [pm25_c_2012, pm25_a_2012],
           '2013': [pm25_c_2013, pm25_a_2013],
           '2014': [pm25_c_2014, pm25_a_2014],
           '2015': [pm25_c_2015, pm25_a_2015],
           '2016': [pm25_c_2016, pm25_a_2016],}

# create a subplot for each year
for year in years:
    # create temporary df that is a copy of the first element of the list corresponding to the current year in the for loop
    child_df = df_dict[year][0].loc[:]
    
    # create temporary df that is a copy of the second element of the list corresponding to the current year in the for loop
    adult_df = df_dict[year][1].loc[:]
    
    # linear regression for children
    (child_slope, child_intercept, child_r, _, _) = linregress(child_df['PM2.5'],child_df['Rate'])
    child_fit = child_slope * child_df['PM2.5'] + child_intercept
    
    # linear regression for adults 
    (adult_slope, adult_intercept, adult_r, _, _) = linregress(adult_df['PM2.5'],adult_df['Rate'])
    adult_fit = adult_slope * adult_df['PM2.5'] + adult_intercept
    
    # create 2 subplots that share x-axis
    f, axarr = plt.subplots(2, sharex=True, figsize=(7, 7))
    
    # 1st plot (asthma in children vs PM2.5)
    axarr[0].plot(child_df['PM2.5'], child_fit, c='#30336b', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(child_slope, child_intercept, child_r))
    axarr[0].legend(loc="upper right")
    axarr[0].scatter(child_df['PM2.5'], child_df['Rate'], c='red', marker='s')
    axarr[0].set_title(f'{year}')
    axarr[0].set_ylabel("\n".join(wrap("Rate of Under 18 ED Visits for Asthma (per 10,000)", 30)))
    
    # 2nd plot (asthma in adults vs PM2.5)
    axarr[1].plot(adult_df['PM2.5'], adult_fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(adult_slope, adult_intercept, adult_r))
    axarr[1].legend(loc="upper right")
    axarr[1].scatter(adult_df['PM2.5'], adult_df['Rate'], c='blue', marker='s')
    axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
    axarr[1].set_xlabel('PM2.5')    
    f.savefig(f'Images/pm25vsasthma_{year}.png')

# %%
# create list of all pm2.5 dfs with adult data
adults_pm25 = [pm25_a_2011, pm25_a_2012, pm25_a_2013, pm25_a_2014, pm25_a_2015, pm25_a_2016]

# create list of all pm2.5 dfs with children data
child_pm25 = [pm25_c_2011, pm25_c_2012, pm25_c_2013, pm25_c_2014, pm25_c_2015, pm25_c_2016]

# concatenate each individual PM2.5 df w/ adult data into one 
all_pm25_a = pd.concat(adults_pm25, sort=False)

# concatenate each individual PM2.5 df w/ children data into one 
all_pm25_c = pd.concat(child_pm25, sort=False)

# display combined adult pm2.5 df
all_pm25_a
# Out:
#     Year           County  Rate      PM2.5
# 0   2011          Alameda  56.6   9.319157
# 1   2011            Butte  49.9  12.003279
# 2   2011        Calaveras  49.5   9.242926
# 3   2011           Colusa  23.4   5.830245
# 4   2011     Contra Costa  67.3   8.458423
# 5   2011           Fresno  53.0  15.162573
# 6   2011         Humboldt  67.2   8.803835
# 7   2011         Imperial  53.2   9.759794
# 8   2011             Inyo  52.4   8.444740
# 9   2011             Kern  42.2   8.260165
# 10  2011            Kings  64.4  17.077427
# 11  2011             Lake  59.0   3.518033
# 12  2011      Los Angeles  36.5  11.831937
# 13  2011           Madera  44.8  17.675338
# 14  2011            Marin  27.0  10.112664
# 15  2011           Merced  63.1  15.719372
# 16  2011         Monterey  30.7   6.307555
# 17  2011           Nevada  44.5   4.676471
# 18  2011           Orange  22.5  10.358658
# 19  2011           Placer  28.2   8.462295
# 20  2011        Riverside  35.2   8.651490
# 21  2011       Sacramento  56.2  10.444872
# 22  2011       San Benito  39.5   5.781962
# 23  2011   San Bernardino  48.0  11.093348
# 24  2011        San Diego  27.4  10.154534
# 25  2011    San Francisco  36.2   9.554208
# 26  2011      San Joaquin  55.2  12.039680
# 27  2011  San Luis Obispo  29.3   8.897803
# 28  2011        San Mateo  34.2   8.867821
# 29  2011    Santa Barbara  23.9   9.420523
# ..   ...              ...   ...        ...
# 11  2016             Lake  79.4   2.985246
# 12  2016      Los Angeles  38.6  10.995261
# 13  2016           Madera  32.3  12.134698
# 14  2016            Marin  19.7   6.486877
# 15  2016           Merced  61.2  11.994774
# 16  2016         Monterey  37.0   5.804339
# 17  2016           Nevada  32.3   5.712717
# 18  2016           Orange  20.7   8.874678
# 19  2016           Placer  24.8   6.013099
# 20  2016        Riverside  32.7  10.204809
# 21  2016       Sacramento  54.7   6.385563
# 22  2016       San Benito  36.8   4.287063
# 23  2016   San Bernardino  41.8  10.167431
# 24  2016        San Diego  24.0   6.338994
# 25  2016    San Francisco  28.4   7.620439
# 26  2016      San Joaquin  49.6  11.700175
# 27  2016  San Luis Obispo  32.4   6.924913
# 28  2016        San Mateo  27.0   8.327174
# 29  2016    Santa Barbara  27.3   7.057402
# 30  2016      Santa Clara  26.1   7.743220
# 31  2016       Santa Cruz  26.9   5.296084
# 32  2016           Shasta  38.7   5.050000
# 33  2016         Siskiyou  33.9   4.936207
# 34  2016           Solano  71.0   7.949480
# 35  2016           Sonoma  30.2   4.678414
# 36  2016       Stanislaus  43.6  12.001235
# 37  2016           Sutter  27.8   8.118519
# 38  2016           Tulare  31.6  14.706780
# 39  2016          Ventura  23.2   8.791687
# 40  2016             Yolo  31.1   6.316667
#
# [246 rows x 4 columns]

# %%
# Graph ADULTS ED rates vs PM2.5 & CHILDREN ED rates vs PM2.5 for all years
# Subplot: 1st graph contains data for children, 2nd graph contains data for adults

# create a temporary df that is a copy of children pm2.5 df
child_df = all_pm25_c.loc[:]

# create a temporary df that is a copy of adult pm2.5 df
adult_df = all_pm25_a.loc[:]
    
# linear regression for children
(child_slope, child_intercept, child_r, _, _) = linregress(child_df['PM2.5'],child_df['Rate'])
child_fit = child_slope * child_df['PM2.5'] + child_intercept

# linear regression for adults
(adult_slope, adult_intercept, adult_r, _, _) = linregress(adult_df['PM2.5'],adult_df['Rate'])
adult_fit = adult_slope * adult_df['PM2.5'] + adult_intercept
    
# create 2 subplots that share x-axis
f, axarr = plt.subplots(2, sharex=True, figsize=(7, 7))
 
# 1st subplot (asthma in children vs pm2.5)
axarr[0].plot(child_df['PM2.5'], child_fit, c='#30336b', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(child_slope, child_intercept, child_r))
axarr[0].legend(loc="upper right")
axarr[0].scatter(child_df['PM2.5'], child_df['Rate'], c='red', marker='s')
axarr[0].set_title(f'2011-2016')
axarr[0].set_ylabel("\n".join(wrap("Rate of Under 18 ED Visits for Asthma (per 10,000)", 30)))
    
# 2nd subplot (asthma in adults vs pm2.5)
axarr[1].plot(adult_df['PM2.5'], adult_fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(adult_slope, adult_intercept, adult_r))
axarr[1].legend(loc="upper right")
axarr[1].scatter(adult_df['PM2.5'], adult_df['Rate'], c='blue', marker='s')
axarr[1].set_ylabel("\n".join(wrap("Rate of Over 18 ED Visits for Asthma (per 10,000)", 30)))
axarr[1].set_xlabel('PM2.5')
f.savefig(f'Images/aqivspm252011to2016.png')

# %% [markdown]
# ## Temperature Analysis

# %%
xls = pd.ExcelFile('Resources/CA-daily_Temp_2010-2016_Ruby.xlsx', )
temp_2010 = pd.read_excel(xls, '2010', encoding='utf8')
temp_2011 = pd.read_excel(xls, '2011', encoding='utf8')
temp_2012 = pd.read_excel(xls, '2012', encoding='utf8')
temp_2013 = pd.read_excel(xls, '2013', encoding='utf8')
temp_2014 = pd.read_excel(xls, '2014', encoding='utf8')
temp_2015 = pd.read_excel(xls, '2015', encoding='utf8')
temp_2016 = pd.read_excel(xls, '2016', encoding='utf8')
temp_2010.head(10)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           6            5         2           62101    1  38.339905
# 1           6            5         2           62101    1  38.339905
# 2           6            5         2           62101    1  38.339905
# 3           6            5         2           62101    1  38.339905
# 4           6            5         2           62101    1  38.339905
# 5           6            5         2           62101    1  38.339905
# 6           6            5         2           62101    1  38.339905
# 7           6            5         2           62101    1  38.339905
# 8           6            5         2           62101    1  38.339905
# 9           6            5         2           62101    1  38.339905
#
#     Longitude  Datum       Parameter Name Sample Duration  \
# 0 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 1 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 2 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 3 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 4 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 5 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 6 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 7 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 8 -120.763515  WGS84  Outdoor Temperature          1 HOUR
# 9 -120.763515  WGS84  Outdoor Temperature          1 HOUR
#
#           ...           AQI Method Code  \
# 0         ...           NaN          40
# 1         ...           NaN          40
# 2         ...           NaN          40
# 3         ...           NaN          40
# 4         ...           NaN          40
# 5         ...           NaN          40
# 6         ...           NaN          40
# 7         ...           NaN          40
# 8         ...           NaN          40
# 9         ...           NaN          40
#
#                                  Method Name       Local Site Name  \
# 0  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 1  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 2  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 3  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 4  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 5  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 6  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 7  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 8  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
# 9  INSTRUMENTAL - ELECTRONIC OR MACHINE AVG.  Jackson-Clinton Road
#
#                                 Address  State Name  County Name  City Name  \
# 0   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 1   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 2   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 3   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 4   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 5   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 6   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 7   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 8   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
# 9   201 CLINTON ROAD, JACKSON, CA 95642  California       Amador    Jackson
#
#    CBSA Name  Date of Last Change
# 0        NaN                41435
# 1        NaN                41435
# 2        NaN                41435
# 3        NaN                41435
# 4        NaN                41435
# 5        NaN                41435
# 6        NaN                41435
# 7        NaN                41435
# 8        NaN                41435
# 9        NaN                41435
#
# [10 rows x 30 columns]

# %%
temp_2010.columns
# Out:
# Index(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
#        'Pollutant Standard', 'Date Local', 'Units of Measure', 'Event Type',
#        'Observation Count', 'Observation Percent', 'Arithmetic Mean',
#        'Temp Celsius', '1st Max Value', '1st Max Hour', 'AQI', 'Method Code',
#        'Method Name', 'Local Site Name', 'Address', 'State Name',
#        'County Name', 'City Name', 'CBSA Name', 'Date of Last Change'],
#       dtype='object')

# %%
# remove extraneous columns from every df
sheets = [temp_2010, temp_2011,temp_2012, temp_2013, temp_2014, temp_2015, temp_2016]
for df in sheets:
    df.drop(['State Code', 'County Code', 'Site Num', 'Parameter Code', 'POC',
       'Latitude', 'Longitude', 'Datum', 'Parameter Name', 'Sample Duration',
       'Pollutant Standard', 'Units of Measure', 'Event Type',
       'Observation Count', 'Observation Percent', 'Method Code', 'Method Name',
       'Local Site Name', 'Address', 'State Name', 'City Name',
       'CBSA Name', 'Date of Last Change'], axis=1, inplace=True)
temp_2010.head()
# Out:
#   Date Local  Arithmetic Mean  Temp Celsius  1st Max Value  1st Max Hour  AQI  \
# 0 2010-01-01        49.250000      9.583333           55.0            11  NaN
# 1 2010-01-02        48.083333      8.935185           57.0            12  NaN
# 2 2010-01-03        43.916667      6.620371           55.0            12  NaN
# 3 2010-01-04        45.166667      7.314815           57.0            15  NaN
# 4 2010-01-05        40.166667      4.537037           50.0            11  NaN
#
#   County Name
# 0      Amador
# 1      Amador
# 2      Amador
# 3      Amador
# 4      Amador

# %%
for df in sheets:
    df['Date Local'] = pd.to_datetime(df['Date Local'], format='%Y-%m-%d')
    df['Year'] = pd.DatetimeIndex(df['Date Local']).year

# %%
temp_2015.head()
# Out:
#   Date Local  Arithmetic Mean  Temp Celsius  1st Max Value  1st Max Hour  AQI  \
# 0 2015-08-01        75.433333     24.129629           88.9            16  NaN
# 1 2015-08-02        73.833333     23.240741           89.8            15  NaN
# 2 2015-08-03        70.137500     21.187500           86.5            15  NaN
# 3 2015-08-04        65.766667     18.759259           79.0            15  NaN
# 4 2015-08-05        69.937500     21.076389           87.4            16  NaN
#
#   County Name  Year
# 0      Amador  2015
# 1      Amador  2015
# 2      Amador  2015
# 3      Amador  2015
# 4      Amador  2015

# %%
all_temp = pd.concat(sheets, sort=False)
all_temp.head()
# Out:
#   Date Local  Arithmetic Mean  Temp Celsius  1st Max Value  1st Max Hour  AQI  \
# 0 2010-01-01        49.250000      9.583333           55.0            11  NaN
# 1 2010-01-02        48.083333      8.935185           57.0            12  NaN
# 2 2010-01-03        43.916667      6.620371           55.0            12  NaN
# 3 2010-01-04        45.166667      7.314815           57.0            15  NaN
# 4 2010-01-05        40.166667      4.537037           50.0            11  NaN
#
#   County Name  Year
# 0      Amador  2010
# 1      Amador  2010
# 2      Amador  2010
# 3      Amador  2010
# 4      Amador  2010

# %%
all_temp.isnull().sum()
# Out:
# Date Local              0
# Arithmetic Mean         0
# Temp Celsius            0
# 1st Max Value           0
# 1st Max Hour            0
# AQI                364657
# County Name             0
# Year                    0
# dtype: int64

# %%
all_temp = all_temp[['County Name', 'Arithmetic Mean', 'Temp Celsius', 'Year']]
all_temp = all_temp.rename(columns={'County Name': 'County', 'Arithmetic Mean': 'Temp (F)', 'Temp Celsius': 'Temp (C)'})
all_temp.head()
# Out:
#    County   Temp (F)  Temp (C)  Year
# 0  Amador  49.250000  9.583333  2010
# 1  Amador  48.083333  8.935185  2010
# 2  Amador  43.916667  6.620371  2010
# 3  Amador  45.166667  7.314815  2010
# 4  Amador  40.166667  4.537037  2010

# %%
# Taking mean of all temperatures for plot with error bar
mean_temp_group = pd.DataFrame(all_temp.groupby(['Year', 'County']).mean()).reset_index()
mean_temp_group = mean_temp_group[['Year', 'County', 'Temp (C)']]
mean_temp_group = mean_temp_group.rename(columns={'Temp (C)': 'Mean Temp (C)'})
mean_temp_group.head()
# Out:
#    Year     County  Mean Temp (C)
# 0  2010     Amador      13.613824
# 1  2010      Butte      15.786831
# 2  2010  Calaveras      14.539423
# 3  2010     Colusa      16.030518
# 4  2010  Del Norte      11.256211

# %%
# Taking SEM for plot
sem_temp_group = pd.DataFrame(all_temp.groupby(['Year', 'County']).sem()).reset_index()
sem_temp_group = sem_temp_group[['Year', 'County', 'Temp (C)']]
sem_temp_group = sem_temp_group.rename(columns={'Temp (C)': 'Temp (C) SEM'})
sem_temp_group.head()
# Out:
#    Year     County  Temp (C) SEM
# 0  2010     Amador      0.330683
# 1  2010      Butte      0.191291
# 2  2010  Calaveras      0.326720
# 3  2010     Colusa      0.330123
# 4  2010  Del Norte      0.173539

# %%
# To measure Max values
max_temp_group = pd.DataFrame(all_temp.groupby(['Year', 'County']).max()).reset_index()
max_temp_group = max_temp_group[['Year', 'County', 'Temp (C)']]
max_temp_group = max_temp_group.rename(columns={'Temp (C)': 'Max Temp (C)'})
max_temp_group.head()
# Out:
#    Year     County  Max Temp (C)
# 0  2010     Amador     28.657407
# 1  2010      Butte     35.023148
# 2  2010  Calaveras     30.046296
# 3  2010     Colusa     30.416667
# 4  2010  Del Norte     19.375000

# %%
meanmax_temp = pd.merge(mean_temp_group, max_temp_group, on=['Year', 'County'])
meanmaxsem_temp = pd.merge(meanmax_temp, sem_temp_group, on=['Year', 'County'])
meanmaxsem_temp
# Out:
#      Year           County  Mean Temp (C)  Max Temp (C)  Temp (C) SEM
# 0    2010           Amador      13.613824     28.657407      0.330683
# 1    2010            Butte      15.786831     35.023148      0.191291
# 2    2010        Calaveras      14.539423     30.046296      0.326720
# 3    2010           Colusa      16.030518     30.416667      0.330123
# 4    2010        Del Norte      11.256211     19.375000      0.173539
# 5    2010        El Dorado      12.458597     32.986111      0.250222
# 6    2010           Fresno      17.056867     33.032407      0.170973
# 7    2010            Glenn      16.175942     30.277778      0.342094
# 8    2010         Humboldt      12.535193     24.791667      0.314701
# 9    2010         Imperial      23.523352     41.111111      0.177085
# 10   2010             Inyo      15.604420     34.212963      0.130054
# 11   2010             Kern      18.467019     37.199074      0.139094
# 12   2010            Kings      17.169269     32.245371      0.265925
# 13   2010             Lake      12.209273     30.277778      0.175671
# 14   2010      Los Angeles      16.825605     34.745371      0.072546
# 15   2010           Madera      17.126362     33.015873      0.304653
# 16   2010            Marin      11.557183     22.777778      0.122803
# 17   2010         Mariposa      12.855586     27.500000      0.215003
# 18   2010           Merced      16.180621     31.111111      0.352425
# 19   2010             Mono       7.039094     22.939815      0.254698
# 20   2010         Monterey      13.049688     27.870371      0.101611
# 21   2010           Nevada      17.645747     29.166667      0.453654
# 22   2010           Orange      17.112771     32.185185      0.143594
# 23   2010           Placer      16.288521     32.361111      0.331340
# 24   2010        Riverside      19.959782     40.629629      0.126092
# 25   2010       Sacramento      16.093839     33.611111      0.130514
# 26   2010       San Benito      13.621359     28.564815      0.179095
# 27   2010   San Bernardino      16.995073     36.435185      0.125187
# 28   2010        San Diego      16.166272     33.101852      0.069964
# 29   2010      San Joaquin      15.955392     31.898148      0.225777
# ..    ...              ...            ...           ...           ...
# 232  2016             Inyo      17.800046     44.861111      0.126978
# 233  2016             Kern      18.954883     37.328704      0.147445
# 234  2016            Kings      18.741419     32.847222      0.272359
# 235  2016             Lake      14.071565     30.208333      0.221254
# 236  2016      Los Angeles      18.699767     34.092593      0.082306
# 237  2016           Madera      17.893726     32.175926      0.257296
# 238  2016         Mariposa      14.888961     29.516204      0.337080
# 239  2016           Merced      17.651003     31.458333      0.360283
# 240  2016             Mono       8.332332     23.263889      0.288052
# 241  2016         Monterey      14.581320     25.254629      0.096097
# 242  2016           Orange      19.027802     31.875000      0.122141
# 243  2016           Placer      19.563805     31.969907      0.496031
# 244  2016        Riverside      21.241518     40.810185      0.113257
# 245  2016       Sacramento      17.551497     34.398148      0.143007
# 246  2016       San Benito      14.890420     28.842593      0.180176
# 247  2016   San Bernardino      18.250462     36.345029      0.104783
# 248  2016        San Diego      18.193684     32.615741      0.075866
# 249  2016      San Joaquin      17.664657     33.527778      0.184732
# 250  2016  San Luis Obispo      14.620659     31.087963      0.100300
# 251  2016    Santa Barbara      15.610182     32.361111      0.047831
# 252  2016      Santa Clara      16.259495     26.712963      0.206392
# 253  2016       Santa Cruz      13.451043     24.189815      0.130502
# 254  2016           Shasta       6.959887     20.902778      0.375892
# 255  2016       Stanislaus      19.422336     32.986111      0.277791
# 256  2016           Sutter      18.685416     31.384259      0.292161
# 257  2016           Tehama      22.916165     32.729167      0.488437
# 258  2016           Tulare      17.719403     33.750000      0.202788
# 259  2016         Tuolumne      17.611035     30.254629      0.432658
# 260  2016          Ventura      17.291448     32.268518      0.094760
# 261  2016             Yolo      16.600484     28.796296      0.306385
#
# [262 rows x 5 columns]

# %%
all_mean_temp_group = all_mean_temp_group.unstack(1).reset_index()
all_mean_temp_group = all_mean_temp_group.loc[:,['Year', 'County', 0]]
all_mean_temp_group.columns = ['Year', 'County', 'Temp (C)']
all_mean_temp_group
# Out:
#      Year           County   Temp (C)
# 0    2010           Amador  13.613824
# 1    2010            Butte  15.786831
# 2    2010        Calaveras  14.539423
# 3    2010           Colusa  16.030518
# 4    2010        Del Norte  11.256211
# 5    2010        El Dorado  12.458597
# 6    2010           Fresno  17.056867
# 7    2010            Glenn  16.175942
# 8    2010         Humboldt  12.535193
# 9    2010         Imperial  23.523352
# 10   2010             Inyo  15.604420
# 11   2010             Kern  18.467019
# 12   2010            Kings  17.169269
# 13   2010             Lake  12.209273
# 14   2010      Los Angeles  16.825605
# 15   2010           Madera  17.126362
# 16   2010            Marin  11.557183
# 17   2010         Mariposa  12.855586
# 18   2010           Merced  16.180621
# 19   2010             Mono   7.039094
# 20   2010         Monterey  13.049688
# 21   2010           Nevada  17.645747
# 22   2010           Orange  17.112771
# 23   2010           Placer  16.288521
# 24   2010        Riverside  19.959782
# 25   2010       Sacramento  16.093839
# 26   2010       San Benito  13.621359
# 27   2010   San Bernardino  16.995073
# 28   2010        San Diego  16.166272
# 29   2010      San Joaquin  15.955392
# ..    ...              ...        ...
# 264  2016            Kings  18.741419
# 265  2016             Lake  14.071565
# 266  2016      Los Angeles  18.699767
# 267  2016           Madera  17.893726
# 268  2016            Marin        NaN
# 269  2016         Mariposa  14.888961
# 270  2016           Merced  17.651003
# 271  2016             Mono   8.332332
# 272  2016         Monterey  14.581320
# 273  2016           Nevada        NaN
# 274  2016           Orange  19.027802
# 275  2016           Placer  19.563805
# 276  2016        Riverside  21.241518
# 277  2016       Sacramento  17.551497
# 278  2016       San Benito  14.890420
# 279  2016   San Bernardino  18.250462
# 280  2016        San Diego  18.193684
# 281  2016      San Joaquin  17.664657
# 282  2016  San Luis Obispo  14.620659
# 283  2016    Santa Barbara  15.610182
# 284  2016      Santa Clara  16.259495
# 285  2016       Santa Cruz  13.451043
# 286  2016           Shasta   6.959887
# 287  2016       Stanislaus  19.422336
# 288  2016           Sutter  18.685416
# 289  2016           Tehama  22.916165
# 290  2016           Tulare  17.719403
# 291  2016         Tuolumne  17.611035
# 292  2016          Ventura  17.291448
# 293  2016             Yolo  16.600484
#
# [294 rows x 3 columns]

# %%
ozone_group_2010 = ozone_group.loc[ozone_group['Year']==2010,:]
ozone_group_2011 = ozone_group.loc[ozone_group['Year']==2011,:]
ozone_group_2012 = ozone_group.loc[ozone_group['Year']==2012,:]
ozone_group_2013 = ozone_group.loc[ozone_group['Year']==2013,:]
ozone_group_2014 = ozone_group.loc[ozone_group['Year']==2014,:]
ozone_group_2015 = ozone_group.loc[ozone_group['Year']==2015,:]
ozone_group_2016 = ozone_group.loc[ozone_group['Year']==2016,:]
ozone_group_2010.head()
# Out:
#    Year     County  Ozone (ppb)        AQI
# 0  2010    Alameda    19.944734  25.596466
# 1  2010     Amador    25.307209  35.798898
# 2  2010      Butte    33.102122  37.502740
# 3  2010  Calaveras    29.328263  39.731507
# 4  2010     Colusa    25.605285  32.310541

# %%
max_ppb = ozone_group_2011['Ozone (ppb)'].max()
max_county_2011 = ozone_group_2011.loc[ozone_group_2011['Ozone (ppb)'] == max_ppb,:] 
max_county_2011
# Out:
#     Year County  Ozone (ppb)        AQI
# 60  2011   Inyo    47.201216  46.980609

# %%
min_ppb = ozone_group_2011['Ozone (ppb)'].min()
min_county_2011 = ozone_group_2011.loc[ozone_group_2011['Ozone (ppb)'] == min_ppb,:] 
min_county_2011
# Out:
#     Year     County  Ozone (ppb)        AQI
# 68  2011  Mendocino    14.289593  20.184066

# %%
all_pm25_a.head()
# Out:
#    Year        County  Rate      PM2.5
# 0  2011       Alameda  56.6   9.319157
# 1  2011         Butte  49.9  12.003279
# 2  2011     Calaveras  49.5   9.242926
# 3  2011        Colusa  23.4   5.830245
# 4  2011  Contra Costa  67.3   8.458423

# %%
all_pm25 = all_pm25_a[['Year', 'County', 'PM2.5']]
all_pm25
# Out:
#     Year           County      PM2.5
# 0   2011          Alameda   9.319157
# 1   2011            Butte  12.003279
# 2   2011        Calaveras   9.242926
# 3   2011           Colusa   5.830245
# 4   2011     Contra Costa   8.458423
# 5   2011           Fresno  15.162573
# 6   2011         Humboldt   8.803835
# 7   2011         Imperial   9.759794
# 8   2011             Inyo   8.444740
# 9   2011             Kern   8.260165
# 10  2011            Kings  17.077427
# 11  2011             Lake   3.518033
# 12  2011      Los Angeles  11.831937
# 13  2011           Madera  17.675338
# 14  2011            Marin  10.112664
# 15  2011           Merced  15.719372
# 16  2011         Monterey   6.307555
# 17  2011           Nevada   4.676471
# 18  2011           Orange  10.358658
# 19  2011           Placer   8.462295
# 20  2011        Riverside   8.651490
# 21  2011       Sacramento  10.444872
# 22  2011       San Benito   5.781962
# 23  2011   San Bernardino  11.093348
# 24  2011        San Diego  10.154534
# 25  2011    San Francisco   9.554208
# 26  2011      San Joaquin  12.039680
# 27  2011  San Luis Obispo   8.897803
# 28  2011        San Mateo   8.867821
# 29  2011    Santa Barbara   9.420523
# ..   ...              ...        ...
# 11  2016             Lake   2.985246
# 12  2016      Los Angeles  10.995261
# 13  2016           Madera  12.134698
# 14  2016            Marin   6.486877
# 15  2016           Merced  11.994774
# 16  2016         Monterey   5.804339
# 17  2016           Nevada   5.712717
# 18  2016           Orange   8.874678
# 19  2016           Placer   6.013099
# 20  2016        Riverside  10.204809
# 21  2016       Sacramento   6.385563
# 22  2016       San Benito   4.287063
# 23  2016   San Bernardino  10.167431
# 24  2016        San Diego   6.338994
# 25  2016    San Francisco   7.620439
# 26  2016      San Joaquin  11.700175
# 27  2016  San Luis Obispo   6.924913
# 28  2016        San Mateo   8.327174
# 29  2016    Santa Barbara   7.057402
# 30  2016      Santa Clara   7.743220
# 31  2016       Santa Cruz   5.296084
# 32  2016           Shasta   5.050000
# 33  2016         Siskiyou   4.936207
# 34  2016           Solano   7.949480
# 35  2016           Sonoma   4.678414
# 36  2016       Stanislaus  12.001235
# 37  2016           Sutter   8.118519
# 38  2016           Tulare  14.706780
# 39  2016          Ventura   8.791687
# 40  2016             Yolo   6.316667
#
# [246 rows x 3 columns]

# %%
meanmaxsem_temp.count()
# Out:
# Year             262
# County           262
# Mean Temp (C)    262
# Max Temp (C)     262
# Temp (C) SEM     262
# dtype: int64

# %%
ozone_temp_df = pd.merge(meanmaxsem_temp, ozone_group, on=['Year', 'County'])
ozone_temp_df.head()
# Out:
#    Year     County  Mean Temp (C)  Max Temp (C)  Temp (C) SEM  Ozone (ppb)  \
# 0  2010     Amador      13.613824     28.657407      0.330683    25.307209
# 1  2010      Butte      15.786831     35.023148      0.191291    33.102122
# 2  2010  Calaveras      14.539423     30.046296      0.326720    29.328263
# 3  2010     Colusa      16.030518     30.416667      0.330123    25.605285
# 4  2010  El Dorado      12.458597     32.986111      0.250222    39.921773
#
#          AQI
# 0  35.798898
# 1  37.502740
# 2  39.731507
# 3  32.310541
# 4  44.703401

# %%
ozone_temp_df.count()
# Out:
# Year             250
# County           250
# Mean Temp (C)    250
# Max Temp (C)     250
# Temp (C) SEM     250
# Ozone (ppb)      250
# AQI              250
# dtype: int64

# %%
ozone_temp_pm25_df = pd.merge(ozone_temp_df, all_pm25, on=['Year', 'County'])
ozone_temp_pm25_df.head()
# Out:
#    Year     County  Mean Temp (C)  Max Temp (C)  Temp (C) SEM  Ozone (ppb)  \
# 0  2011      Butte      15.256110     32.731482      0.190859    32.591449
# 1  2011  Calaveras      14.037498     28.449074      0.380302    29.013634
# 2  2011     Colusa      15.569444     29.699074      0.361741    25.211324
# 3  2011     Fresno      16.782414     32.222222      0.179009    31.305375
# 4  2011   Humboldt      10.977861     27.777778      0.305376    22.321125
#
#          AQI      PM2.5
# 0  37.293151  12.003279
# 1  40.358127   9.242926
# 2  32.066482   5.830245
# 3  49.700969  15.162573
# 4  24.102996   8.803835

# %%
ozone_temp_pm25_df.count()
# Out:
# Year             185
# County           185
# Mean Temp (C)    185
# Max Temp (C)     185
# Temp (C) SEM     185
# Ozone (ppb)      185
# AQI              185
# PM2.5            185
# dtype: int64

# %%
min_temp = ozone_temp_pm25_df['Max Temp (C)'].min()
min_county = ozone_temp_pm25_df.loc[ozone_temp_pm25_df['Max Temp (C)']==min_temp]['County']
min_county
# Out:
# 28    Shasta
# Name: County, dtype: object

# %%
max_temp = ozone_temp_pm25_df['Max Temp (C)'].max()
max_county = ozone_temp_pm25_df.loc[ozone_temp_pm25_df['Max Temp (C)']==max_temp]['County']
max_county
# Out:
# 73    Inyo
# Name: County, dtype: object

# %%
plt.scatter(ozone_temp_pm25_df['Mean Temp (C)'], ozone_temp_pm25_df['PM2.5'])
plt.xlabel("Mean Temperature (C)")
plt.ylabel("PM2.5")
(slope, intercept, r, _, _) = linregress(ozone_temp_pm25_df['Mean Temp (C)'], ozone_temp_pm25_df['PM2.5'])
fit = slope * ozone_temp_pm25_df['Mean Temp (C)'] + intercept
plt.plot(ozone_temp_pm25_df['Mean Temp (C)'], fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(slope, intercept, r))

# %%
plt.scatter(ozone_temp_pm25_df['PM2.5'], ozone_temp_pm25_df['Ozone (ppb)'])
plt.xlabel("PM2.5")
plt.ylabel("Ozone (ppb)")
(slope, intercept, r, _, _) = linregress(ozone_temp_pm25_df['PM2.5'], ozone_temp_pm25_df['Ozone (ppb)'])
fit = slope * ozone_temp_pm25_df['PM2.5'] + intercept
plt.plot(ozone_temp_pm25_df['PM2.5'], fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(slope, intercept, r))

# %%
plt.scatter(ozone_temp_pm25_df['Mean Temp (C)'], ozone_temp_pm25_df['Ozone (ppb)'])
plt.xlabel("Mean Temperature (C)")
plt.ylabel("Ozone (ppb)")
(slope, intercept, r, _, _) = linregress(ozone_temp_pm25_df['Mean Temp (C)'], ozone_temp_pm25_df['Ozone (ppb)'])
fit = slope * ozone_temp_pm25_df['Mean Temp (C)'] + intercept
plt.plot(ozone_temp_pm25_df['Mean Temp (C)'], fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(slope, intercept, r))

# %%
plt.scatter(ozone_temp_pm25_df['Mean Temp (C)'], ozone_temp_pm25_df['AQI'])
plt.xlabel("Mean Temperature (C)")
plt.ylabel("AQI")
(slope, intercept, r, _, _) = linregress(ozone_temp_pm25_df['Mean Temp (C)'], ozone_temp_pm25_df['AQI'])
fit = slope * ozone_temp_pm25_df['Mean Temp (C)'] + intercept
plt.plot(ozone_temp_pm25_df['Mean Temp (C)'], fit, c='#130f40', linewidth=3, label='y={:.2f}x+{:.2f}\nR-value: {:.2f}'.format(slope, intercept, r))

# %%
minmax_df
# Out:
#      Year  County  Mean Temp (C)  Max Temp (C)  Temp (C) SEM  Ozone (ppb)  \
# 6    2011    Inyo      15.875386     42.175926      0.126533    47.201216
# 28   2011  Shasta       6.012913     19.814815      0.361575    28.050394
# 40   2012    Inyo      17.763418     44.930556      0.127909    45.753145
# 62   2012  Shasta       6.844005     21.273148      0.392483    30.033558
# 73   2013    Inyo      17.366175     45.092593      0.140442    44.951532
# 94   2013  Shasta       7.174482     24.189815      0.379582    28.769613
# 101  2014    Inyo      17.744876     42.824074      0.150372    45.030321
# 120  2014  Shasta       8.182816     22.199074      0.360026    30.163936
# 130  2015    Inyo      17.421616     42.847222      0.131362    42.053497
# 149  2015  Shasta       7.784230     21.666667      0.365982    32.076838
# 159  2016    Inyo      17.800046     44.861111      0.126978    37.837021
# 179  2016  Shasta       6.959887     20.902778      0.375892    30.397085
#
#            AQI     PM2.5
# 6    46.980609  8.444740
# 28   32.612681  5.169643
# 40   50.150273  7.558449
# 62   37.134576  5.905521
# 73   47.356546  7.995986
# 94   34.940115  5.541772
# 101  47.210959  7.919697
# 120  37.550388  5.292638
# 130  46.332407  7.051229
# 149  40.986321  7.452632
# 159  41.979544  5.352194
# 179  38.141568  5.050000

# %%
min_df = ozone_temp_pm25_df.loc[(ozone_temp_pm25_df['County']=='Shasta'),:] 
min_df
max_df = ozone_temp_pm25_df.loc[(ozone_temp_pm25_df['County']=='Inyo'),:] 
max_df
plt.errorbar(min_df['Year'], min_df['Mean Temp (C)'], yerr=min_df['Temp (C) SEM'], marker='o', color='red', label="Shasta")
plt.errorbar(max_df['Year'], max_df['Mean Temp (C)'], yerr=max_df['Temp (C) SEM'], marker='o', color='blue', label="Inyo")
plt.xlabel("Year")
plt.ylabel("Mean Temperature (C)")
plt.legend()

# %%
plt.scatter(min_df['Ozone (ppb)'], min_df['Mean Temp (C)'], color='red', label="Shasta")
plt.scatter(max_df['Ozone (ppb)'], max_df['Mean Temp (C)'], color='blue', label="Inyo")
#plt.errorbar(max_df['Year'], max_df['Mean Temp (C)'], yerr=max_df['Temp (C) SEM'], marker='o', color='blue', label="Inyo")
plt.xlabel("Ozone (ppb)")
plt.ylabel("Mean Temperature (C)")
plt.legend()
