# %%
#import dependencies
import pandas as pd
import requests as req
#create separate file with individual log in credentials to be imported
from climatekeys import (user_id_aqs, password_aqs)
import csv
#code for Temperature (62101) and code for pressure (64101)
url = f"https://aqs.epa.gov/api/rawData?user={user_id_aqs}&pw={password_aqs}&format=DMCSV&param=62101&bdate=20110101&edate=20110201&state=06&county=001"
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.90 Safari/537.36'}
response = req.get(url)

# %%
print(response.status_code) #should be 200 if the API worked
# Out:
# 200

# %%
#Response is downloaded as a text (try response.text to see). Csv.reader converts the text file to a bunch of
# lists. These lists need to be put in a 'Master List' to make a list of lists.
#the first list created is stored as a header and every follwing list is append in the 'Master List'
wrapper = csv.reader(response.text.strip().split('\n'))
empty_list = []
header = next(wrapper)
for record in wrapper:
    empty_list.append(record)

# %%
df = pd.DataFrame(empty_list, columns = header)
df.head()
# Out:
#     Latitude    Longitude  Datum Horizontal Accuracy State Code County Code  \
# 0  37.687526  -121.784217  WGS84           109305.56         06         001
# 1  37.687526  -121.784217  WGS84           109305.56         06         001
# 2  37.687526  -121.784217  WGS84           109305.56         06         001
# 3  37.687526  -121.784217  WGS84           109305.56         06         001
# 4  37.687526  -121.784217  WGS84           109305.56         06         001
#
#   Site Num Parameter Code POC        AQS Parameter Desc  \
# 0     0007          88101   1  PM2.5 - Local Conditions
# 1     0007          88101   1  PM2.5 - Local Conditions
# 2     0007          88101   1  PM2.5 - Local Conditions
# 3     0007          88101   1  PM2.5 - Local Conditions
# 4     0007          88101   1  PM2.5 - Local Conditions
#
#                          ...                         Day In Year GMT  \
# 0                        ...                                      18
# 1                        ...                                      16
# 2                        ...                                       3
# 3                        ...                                       9
# 4                        ...                                      29
#
#   Sample Measurement             Units of Measure Sample Duration  \
# 0                6.6  Micrograms/cubic meter (LC)         24 HOUR
# 1               21.9  Micrograms/cubic meter (LC)         24 HOUR
# 2               13.4  Micrograms/cubic meter (LC)         24 HOUR
# 3               13.7  Micrograms/cubic meter (LC)         24 HOUR
# 4                4.8  Micrograms/cubic meter (LC)         24 HOUR
#
#   Sample Frequency Detection Limit Measurement Uncertainty  \
# 0        EVERY DAY               2
# 1        EVERY DAY               2
# 2        EVERY DAY               2
# 3        EVERY DAY               2
# 4        EVERY DAY               2
#
#   Qualifier Description Method Type  \
# 0                         Reference
# 1                         Reference
# 2                         Reference
# 3                         Reference
# 4                         Reference
#
#                                   Method Description
# 0  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 1  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 2  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 3  R & P Model 2025 PM-2.5 Sequential Air Sampler...
# 4  R & P Model 2025 PM-2.5 Sequential Air Sampler...
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Latitude', 'Longitude', 'Datum', 'Horizontal Accuracy', 'State Code',
#        'County Code', 'Site Num', 'Parameter Code', 'POC',
#        'AQS Parameter Desc', 'Date Local', '24 Hour Local', 'Date GMT',
#        '24 Hour GMT', 'Year GMT', 'Day In Year GMT', 'Sample Measurement',
#        'Units of Measure', 'Sample Duration', 'Sample Frequency',
#        'Detection Limit', 'Measurement Uncertainty', 'Qualifier Description',
#        'Method Type', 'Method Description'],
#       dtype='object')

# %%
df_trimmed = df[['Date Local','24 Hour Local','Date GMT','Sample Measurement','Units of Measure','Sample Duration','Sample Frequency']]
df_trimmed.head()
# Out:
#    Date Local 24 Hour Local    Date GMT Sample Measurement  \
# 0  2011-01-18         00:00  2011-01-18                6.6
# 1  2011-01-16         00:00  2011-01-16               21.9
# 2  2011-01-03         00:00  2011-01-03               13.4
# 3  2011-01-09         00:00  2011-01-09               13.7
# 4  2011-01-29         00:00  2011-01-29                4.8
#
#               Units of Measure Sample Duration Sample Frequency
# 0  Micrograms/cubic meter (LC)         24 HOUR        EVERY DAY
# 1  Micrograms/cubic meter (LC)         24 HOUR        EVERY DAY
# 2  Micrograms/cubic meter (LC)         24 HOUR        EVERY DAY
# 3  Micrograms/cubic meter (LC)         24 HOUR        EVERY DAY
# 4  Micrograms/cubic meter (LC)         24 HOUR        EVERY DAY
