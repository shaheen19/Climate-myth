# %%
import pandas as pd
import numpy as np
from datetime import date
import calendar
ozone2010=pd.read_csv("daily_avg_O3_2010.csv",sep=",", dtype=object)
ozone2010.head()
# Out:
#   State Code County Code Site Num Parameter Code POC   Latitude   Longitude  \
# 0          1           3       10          44201   1  30.498001  -87.881412
# 1          1           3       10          44201   1  30.498001  -87.881412
# 2          1           3       10          44201   1  30.498001  -87.881412
# 3          1           3       10          44201   1  30.498001  -87.881412
# 4          1           3       10          44201   1  30.498001  -87.881412
#
#    Datum Parameter Name          Sample Duration         ...         AQI  \
# 0  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR         ...          39
# 1  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR         ...          31
# 2  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR         ...          36
# 3  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR         ...          40
# 4  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR         ...          41
#
#   Method Code Method Name    Local Site Name  \
# ...

# %%
ozone2010cal = ozone2010[(ozone2010['State Name'] == "California")]
ozone2010cal.head()
# Out:
#       State Code County Code Site Num Parameter Code POC   Latitude  \
# 23576          6           1        7          44201   1  37.687526
# 23577          6           1        7          44201   1  37.687526
# 23578          6           1        7          44201   1  37.687526
# 23579          6           1        7          44201   1  37.687526
# 23580          6           1        7          44201   1  37.687526
#
#          Longitude  Datum Parameter Name          Sample Duration  \
# 23576  -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 23577  -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 23578  -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 23579  -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
# 23580  -121.784217  NAD83          Ozone  8-HR RUN AVG BEGIN HOUR
#
#               ...         AQI Method Code Method Name Local Site Name  \
# 23576         ...          15         NaN          -        Livermore
# ...

# %%
ozone2010 = ozone2010[(ozone2010['State Name'] == "California")]

#rename columns from excel2010data
ozone2010df=ozone2010.rename(columns={"Arithmetic Mean":"mean ozone", "1st Max Value":"max ozone"})
#blanks with underscores
ozone2010df.columns=[c.replace(" ", "_") for c in ozone2010df.columns]

#change date-time
ozone2010df["Date_Local"]=pd.to_datetime(ozone2010df["Date_Local"])

# %%
#change date
#ozone2010[[""]]
